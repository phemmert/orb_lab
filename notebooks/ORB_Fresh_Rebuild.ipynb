# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_core import build_orb
from orb_backtester import ORBBacktester
import pandas as pd

# Use the backtester to load data
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-02', end_date='2025-12-02', verbose=False)
bt.load_data()
df = bt.df

dec2 = df[df.index.date == pd.Timestamp('2025-12-02').date()]

orb = build_orb(dec2)
print(f"AAPL Dec 2 ORB: High={orb.session_high:.2f}, Low={orb.session_low:.2f}")
print(f"Expected:       High=284.25, Low=282.63")
print(f"ORB Complete:   {orb.orb_complete}")
print(f"ORB Range:      ${orb.session_high - orb.session_low:.2f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ⚠ Cache stale (17 hours), refreshing...
#   ✓ Fetched 89586 bars, cached for next time
# AAPL Dec 2 ORB: High=284.25, Low=282.63
# Expected:       High=284.25, Low=282.63
# ORB Complete:   True
# ORB Range:      $1.62

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_core import build_orb, update_breakout_state, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load data
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-02', end_date='2025-12-02', verbose=False)
bt.load_data()
df = bt.df
dec2 = df[df.index.date == pd.Timestamp('2025-12-02').date()]

# Build ORB
orb = build_orb(dec2)
print(f"ORB: High={orb.session_high:.2f}, Low={orb.session_low:.2f}\n")

# Process bars after ORB, looking for breakouts
print("Scanning for breakouts (09:35-10:00):")
for ts, bar in dec2.iterrows():
    if is_orb_window(ts):
        continue  # Skip ORB building window
    if ts.hour == 9 and ts.minute <= 59:
        # Use a dummy ATR for now (we'll get real ATR later)
        atr = 0.27  # approximate value
        new_long, new_short = update_breakout_state(bar, orb, atr)
        
        if new_long or new_short:
            direction = "LONG" if new_long else "SHORT"
            print(f"  {ts.strftime('%H:%M')} NEW {direction} BREAKOUT @ {bar['close']:.2f}")
        
        if orb.long_breakout_pending or orb.short_breakout_pending:
            print(f"  {ts.strftime('%H:%M')} pending: long={orb.long_breakout_pending} short={orb.short_breakout_pending}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import sys
#       2 sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
# ----> 3 from orb_core import build_orb, update_breakout_state, is_orb_window
#       4 from orb_backtester import ORBBacktester
#       5 import pandas as pd
#
# ImportError: cannot import name 'update_breakout_state' from 'orb_core' (C:\Users\phemm\orb_lab\src\orb_core.py)

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_core import build_orb, update_breakout_state, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load data
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-02', end_date='2025-12-02', verbose=False)
bt.load_data()
df = bt.df
dec2 = df[df.index.date == pd.Timestamp('2025-12-02').date()]

# Build ORB
orb = build_orb(dec2)
print(f"ORB: High={orb.session_high:.2f}, Low={orb.session_low:.2f}\n")

# Process bars after ORB, looking for breakouts
print("Scanning for breakouts (09:35-10:00):")
for ts, bar in dec2.iterrows():
    if is_orb_window(ts):
        continue  # Skip ORB building window
    if ts.hour == 9 and ts.minute <= 59:
        # Use a dummy ATR for now (we'll get real ATR later)
        atr = 0.27  # approximate value
        new_long, new_short = update_breakout_state(bar, orb, atr)
        
        if new_long or new_short:
            direction = "LONG" if new_long else "SHORT"
            print(f"  {ts.strftime('%H:%M')} NEW {direction} BREAKOUT @ {bar['close']:.2f}")
        
        if orb.long_breakout_pending or orb.short_breakout_pending:
            print(f"  {ts.strftime('%H:%M')} pending: long={orb.long_breakout_pending} short={orb.short_breakout_pending}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 import sys
#       2 sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
# ----> 3 from orb_core import build_orb, update_breakout_state, is_orb_window
#       4 from orb_backtester import ORBBacktester
#       5 import pandas as pd
#
# ImportError: cannot import name 'update_breakout_state' from 'orb_core' (C:\Users\phemm\orb_lab\src\orb_core.py)

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, update_breakout_state, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load data
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-02', end_date='2025-12-02', verbose=False)
bt.load_data()
df = bt.df
dec2 = df[df.index.date == pd.Timestamp('2025-12-02').date()]

# Build ORB
orb = build_orb(dec2)
print(f"ORB: High={orb.session_high:.2f}, Low={orb.session_low:.2f}\n")

# Process bars after ORB, looking for breakouts
print("Scanning for breakouts (09:35-10:00):")
for ts, bar in dec2.iterrows():
    if is_orb_window(ts):
        continue  # Skip ORB building window
    if ts.hour == 9 and ts.minute <= 59:
        # Use a dummy ATR for now
        atr = 0.27
        new_long, new_short = update_breakout_state(bar, orb, atr)
        
        if new_long or new_short:
            direction = "LONG" if new_long else "SHORT"
            print(f"  {ts.strftime('%H:%M')} NEW {direction} BREAKOUT @ {bar['close']:.2f}")
        
        if orb.long_breakout_pending or orb.short_breakout_pending:
            print(f"  {ts.strftime('%H:%M')} pending: long={orb.long_breakout_pending} short={orb.short_breakout_pending}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.1 hours old)
# ORB: High=284.25, Low=282.63
#
# Scanning for breakouts (09:35-10:00):
#   09:12 NEW SHORT BREAKOUT @ 282.60
#   09:12 pending: long=False short=True
#   09:13 pending: long=False short=True
#   09:14 pending: long=False short=True
#   09:17 NEW SHORT BREAKOUT @ 282.56
#   09:17 pending: long=False short=True
#   09:18 pending: long=False short=True
#   09:19 pending: long=False short=True
#   09:20 pending: long=False short=True
#   09:21 pending: long=False short=True
#   09:22 pending: long=False short=True
#   09:23 pending: long=False short=True
#   09:24 pending: long=False short=True
#   09:25 pending: long=False short=True
#   09:26 pending: long=False short=True
#   09:27 pending: long=False short=True
#   09:36 NEW LONG BREAKOUT @ 284.36
#   09:36 pending: long=True short=False
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, pine_long_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load data
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-02', end_date='2025-12-02', verbose=False)
bt.load_data()
df = bt.df
dec2 = df[df.index.date == pd.Timestamp('2025-12-02').date()]

# Build ORB
session_high, session_low = build_orb(dec2)
print(f"ORB: High={session_high:.2f}, Low={session_low:.2f}\n")

# Scan for breakouts
print("Bars where pine_long_breakout() = True:")
atr = 0.27

for ts, bar in dec2.iterrows():
    if is_orb_window(ts):
        continue
    if ts.hour > 10 or (ts.hour == 10 and ts.minute > 30):
        break
    
    is_long = pine_long_breakout(
        o=bar['open'], h=bar['high'], l=bar['low'], c=bar['close'],
        session_low=session_low, session_high=session_high,
        atr=atr
    )
    
    if is_long:
        body = abs(bar['close'] - bar['open'])
        rng = bar['high'] - bar['low']
        ratio = body/rng if rng > 0 else 0
        print(f"  {ts.strftime('%H:%M')} C={bar['close']:.2f} body_ratio={ratio:.2f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.5 hours old)
# ORB: High=284.25, Low=282.63
#
# Bars where pine_long_breakout() = True:
#   09:36 C=284.36 body_ratio=0.75
#   09:49 C=284.47 body_ratio=0.84
#   09:51 C=284.94 body_ratio=0.96

# %%
# Laser focus on 09:49
bar_0949 = dec2[dec2.index.minute == 49]
bar_0949 = bar_0949[bar_0949.index.hour == 9].iloc[0]

print(f"ORB: High={session_high:.2f}, Low={session_low:.2f}")
print(f"\n09:49 bar:")
print(f"  Open:  {bar_0949['open']:.2f}")
print(f"  High:  {bar_0949['high']:.2f}")
print(f"  Low:   {bar_0949['low']:.2f}")
print(f"  Close: {bar_0949['close']:.2f}")

# Check each breakout condition
o, h, l, c = bar_0949['open'], bar_0949['high'], bar_0949['low'], bar_0949['close']
threshold = atr * 0.1

print(f"\nBreakout conditions:")
print(f"  1. open_in_range: {session_low:.2f} <= {o:.2f} <= {session_high:.2f} ? {session_low <= o <= session_high}")
print(f"  2. close > session_high: {c:.2f} > {session_high:.2f} ? {c > session_high}")
print(f"  3. close > session_high + threshold: {c:.2f} > {session_high + threshold:.2f} ? {c > session_high + threshold}")

body = abs(c - o)
rng = h - l
ratio = body/rng if rng > 0 else 0
print(f"  4. body_ratio >= 0.5: {ratio:.2f} >= 0.5 ? {ratio >= 0.5}")

print(f"\nResult: pine_long_breakout = {session_low <= o <= session_high and c > session_high and c > session_high + threshold and ratio >= 0.5}")
# Out:
# ORB: High=284.25, Low=282.63
#
# 09:49 bar:
#   Open:  284.10
#   High:  284.49
#   Low:   284.05
#   Close: 284.47
#
# Breakout conditions:
#   1. open_in_range: 282.63 <= 284.10 <= 284.25 ? True
#   2. close > session_high: 284.47 > 284.25 ? True
#   3. close > session_high + threshold: 284.47 > 284.28 ? True
#   4. body_ratio >= 0.5: 0.84 >= 0.5 ? True
#
# Result: pine_long_breakout = True

# %%
# When does price return fully inside ORB?
print(f"ORB: High={session_high:.2f}, Low={session_low:.2f}")
print(f"\nLooking for latch reset (close fully inside ORB):")

for ts, bar in dec2.iterrows():
    if ts.hour == 9 and 36 <= ts.minute <= 51:
        c = bar['close']
        inside = session_low <= c <= session_high
        status = "<<< RESET" if inside else ""
        print(f"  {ts.strftime('%H:%M')} C={c:.2f} inside={inside} {status}")
# Out:
# ORB: High=284.25, Low=282.63
#
# Looking for latch reset (close fully inside ORB):
#   09:36 C=284.36 inside=False
#   09:37 C=284.62 inside=False
#   09:38 C=283.60 inside=True <<< RESET
#   09:39 C=283.94 inside=True <<< RESET
#   09:40 C=283.70 inside=True <<< RESET
#   09:41 C=284.18 inside=True <<< RESET
#   09:42 C=284.19 inside=True <<< RESET
#   09:43 C=284.31 inside=False
#   09:44 C=284.52 inside=False
#   09:45 C=284.08 inside=True <<< RESET
#   09:46 C=283.82 inside=True <<< RESET
#   09:47 C=283.95 inside=True <<< RESET
#   09:48 C=284.11 inside=True <<< RESET
#   09:49 C=284.47 inside=False
#   09:50 C=284.10 inside=True <<< RESET
#   09:51 C=284.94 inside=False

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, pine_long_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load data
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-02', end_date='2025-12-02', verbose=False)
bt.load_data()
df = bt.df
dec2 = df[df.index.date == pd.Timestamp('2025-12-02').date()]

# Build ORB
session_high, session_low = build_orb(dec2)
print(f"ORB: High={session_high:.2f}, Low={session_low:.2f}\n")

# Simulate the latch
has_broken_out_high = False
atr = 0.27

print(f"{'Time':<6} {'Close':>7} {'Breakout':<10} {'Latch':<8} {'Inside':<8} {'Action'}")
print("-" * 55)

for ts, bar in dec2.iterrows():
    if is_orb_window(ts):
        continue
    if ts.hour > 10 or (ts.hour == 10 and ts.minute > 30):
        break
    
    c = bar['close']
    inside_orb = session_low <= c <= session_high
    
    # Pure breakout check
    is_breakout = pine_long_breakout(
        o=bar['open'], h=bar['high'], l=bar['low'], c=c,
        session_low=session_low, session_high=session_high,
        atr=atr
    )
    
    action = ""
    
    # Apply latch logic
    if is_breakout and not has_broken_out_high:
        has_broken_out_high = True
        action = "🔥 NEW BREAKOUT"
    elif is_breakout and has_broken_out_high:
        action = "(blocked by latch)"
    
    # Reset latch when fully inside
    if inside_orb and has_broken_out_high:
        has_broken_out_high = False
        action = "🔄 LATCH RESET"
    
    # Only print interesting bars
    if action or is_breakout:
        print(f"{ts.strftime('%H:%M'):<6} {c:>7.2f} {str(is_breakout):<10} {str(has_broken_out_high):<8} {str(inside_orb):<8} {action}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.2 hours old)
# ORB: High=284.25, Low=282.63
#
# Time     Close Breakout   Latch    Inside   Action
# -------------------------------------------------------
# 09:36   284.36 True       True     False    🔥 NEW BREAKOUT
# 09:38   283.60 False      False    True     🔄 LATCH RESET
# 09:49   284.47 True       True     False    🔥 NEW BREAKOUT
# 09:50   284.10 False      False    True     🔄 LATCH RESET
# 09:51   284.94 True       True     False    🔥 NEW BREAKOUT
# 09:53   284.23 False      False    True     🔄 LATCH RESET

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, pine_long_breakout, pine_short_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load AAPL December
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-01', end_date='2025-12-31', verbose=False)
bt.load_data()
df = bt.df

# Get unique trading days
trading_days = df[df.index.map(lambda x: x.hour >= 9 and x.hour < 16)].index.date
trading_days = sorted(set(trading_days))

print(f"AAPL December 2025 - Breakout Detection")
print(f"=" * 60)

atr = 0.30  # Approximate ATR for AAPL

for day in trading_days:
    day_df = df[df.index.date == day]
    if day_df.empty:
        continue
    
    session_high, session_low = build_orb(day_df)
    if session_high is None:
        continue
    
    date_str = pd.Timestamp(day).strftime('%m/%d')
    orb_range = session_high - session_low
    print(f"\n{date_str} | ORB: {session_high:.2f}/{session_low:.2f} (${orb_range:.2f})")
    
    # Simulate latch
    has_broken_out_high = False
    has_broken_out_low = False
    
    for ts, bar in day_df.iterrows():
        orb_complete = not is_orb_window(ts)
        if not orb_complete:
            continue
        if ts.hour >= 16:
            break
        
        c = bar['close']
        inside_orb = session_low <= c <= session_high
        
        # Check long breakout
        is_long = pine_long_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=c,
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        # Check short breakout
        is_short = pine_short_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=c,
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        if is_long and not has_broken_out_high:
            has_broken_out_high = True
            print(f"  {ts.strftime('%H:%M')} 🔥 LONG @ {c:.2f}")
        
        if is_short and not has_broken_out_low:
            has_broken_out_low = True
            print(f"  {ts.strftime('%H:%M')} 🔥 SHORT @ {c:.2f}")
        
        # Reset latch when fully inside
        if inside_orb:
            if has_broken_out_high:
                has_broken_out_high = False
                print(f"  {ts.strftime('%H:%M')} 🔄 LONG LATCH RESET (C={c:.2f})")
            if has_broken_out_low:
                has_broken_out_low = False
                print(f"  {ts.strftime('%H:%M')} 🔄 SHORT LATCH RESET (C={c:.2f})")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (6.1 hours old)
# AAPL December 2025 - Breakout Detection
# ...
#
# 07/15 | ORB: 210.49/208.92 ($1.57)
#   08:22 🔥 SHORT @ 208.84
#   08:25 🔄 SHORT LATCH RESET (C=208.98)
#   09:36 🔥 LONG @ 210.55
#   09:37 🔄 LONG LATCH RESET (C=210.36)
#   09:39 🔥 LONG @ 210.58
#   09:40 🔄 LONG LATCH RESET (C=210.49)
#   12:21 🔥 LONG @ 210.54
#   12:26 🔄 LONG LATCH RESET (C=210.44)
#   12:44 🔥 LONG @ 210.54
#   14:57 🔄 LONG LATCH RESET (C=210.47)
#   15:01 🔥 LONG @ 210.62
#   15:15 🔄 LONG LATCH RESET (C=210.49)
#   15:16 🔥 LONG @ 210.56
#   15:19 🔄 LONG LATCH RESET (C=210.39)
#
# 07/16 | ORB: 211.21/210.19 ($1.02)
#   09:16 🔥 SHORT @ 210.00
#   09:19 🔄 SHORT LATCH RESET (C=210.20)
#   09:22 🔥 SHORT @ 210.05
#   09:28 🔄 SHORT LATCH RESET (C=210.37)
#   09:51 🔥 SHORT @ 210.02
#   09:52 🔄 SHORT LATCH RESET (C=210.50)
#   10:10 🔥 LONG @ 211.30
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, pine_long_breakout, pine_short_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load AAPL December
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-01', end_date='2025-12-31', verbose=False)
bt.load_data()
df = bt.df

# Get unique trading days
trading_days = df[df.index.map(lambda x: x.hour >= 9 and x.hour < 16)].index.date
trading_days = sorted(set(trading_days))

print(f"AAPL December 2025 - Breakout Detection (09:35-10:30 only)")
print(f"=" * 60)

atr = 0.30

for day in trading_days:
    day_df = df[df.index.date == day]
    if day_df.empty:
        continue
    
    session_high, session_low = build_orb(day_df)
    if session_high is None:
        continue
    
    date_str = pd.Timestamp(day).strftime('%m/%d')
    orb_range = session_high - session_low
    print(f"\n{date_str} | ORB: {session_high:.2f}/{session_low:.2f} (${orb_range:.2f})")
    
    has_broken_out_high = False
    has_broken_out_low = False
    
    for ts, bar in day_df.iterrows():
        # Filter: 09:35-10:30 only
        if ts.hour == 9 and ts.minute < 35:
            continue
        if ts.hour > 10 or (ts.hour == 10 and ts.minute > 30):
            continue
        
        orb_complete = not is_orb_window(ts)
        c = bar['close']
        inside_orb = session_low <= c <= session_high
        
        is_long = pine_long_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=c,
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        is_short = pine_short_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=c,
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        if is_long and not has_broken_out_high:
            has_broken_out_high = True
            print(f"  {ts.strftime('%H:%M')} 🔥 LONG @ {c:.2f}")
        
        if is_short and not has_broken_out_low:
            has_broken_out_low = True
            print(f"  {ts.strftime('%H:%M')} 🔥 SHORT @ {c:.2f}")
        
        if inside_orb:
            if has_broken_out_high:
                has_broken_out_high = False
                print(f"  {ts.strftime('%H:%M')} 🔄 LONG LATCH RESET (C={c:.2f})")
            if has_broken_out_low:
                has_broken_out_low = False
                print(f"  {ts.strftime('%H:%M')} 🔄 SHORT LATCH RESET (C={c:.2f})")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (6.5 hours old)
# AAPL December 2025 - Breakout Detection (09:35-10:30 only)
# ...
#
# 07/15 | ORB: 210.49/208.92 ($1.57)
#   08:22 🔥 SHORT @ 208.84
#   08:25 🔄 SHORT LATCH RESET (C=208.98)
#   09:36 🔥 LONG @ 210.55
#   09:37 🔄 LONG LATCH RESET (C=210.36)
#   09:39 🔥 LONG @ 210.58
#   09:40 🔄 LONG LATCH RESET (C=210.49)
#
# 07/16 | ORB: 211.21/210.19 ($1.02)
#   09:51 🔥 SHORT @ 210.02
#   09:52 🔄 SHORT LATCH RESET (C=210.50)
#   10:10 🔥 LONG @ 211.30
#   10:11 🔄 LONG LATCH RESET (C=211.10)
#   10:12 🔥 LONG @ 211.47
#
# 07/17 | ORB: 210.92/210.06 ($0.86)
#   08:01 🔥 SHORT @ 209.63
#   08:02 🔄 SHORT LATCH RESET (C=210.49)
#   09:55 🔥 SHORT @ 210.02
#   09:56 🔄 SHORT LATCH RESET (C=210.07)
#   10:11 🔥 SHORT @ 210.02
#
# 07/18 | ORB: 211.01/210.00 ($1.01)
#   10:24 🔥 SHORT @ 209.96
#   10:25 🔄 SHORT LATCH RESET (C=210.06)
#
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, pine_long_breakout, pine_short_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load AAPL December
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-01', end_date='2025-12-31', verbose=False)
bt.load_data()
df = bt.df

# Get unique trading days (RTH only)
trading_days = df[df.index.map(lambda x: x.hour >= 9 and x.hour < 16)].index.date
trading_days = sorted(set(trading_days))

print(f"AAPL December 2025 - Breakout Detection (09:35-10:30 RTH)")
print(f"=" * 60)

atr = 0.30

for day in trading_days:
    day_df = df[df.index.date == day]
    if day_df.empty:
        continue
    
    session_high, session_low = build_orb(day_df)
    if session_high is None:
        continue
    
    date_str = pd.Timestamp(day).strftime('%m/%d')
    orb_range = session_high - session_low
    
    has_broken_out_high = False
    has_broken_out_low = False
    events = []
    
    for ts, bar in day_df.iterrows():
        # STRICT FILTER: 09:35-10:30 only
        if ts.hour == 9 and ts.minute >= 35:
            pass  # OK
        elif ts.hour == 10 and ts.minute <= 30:
            pass  # OK
        else:
            continue  # Skip everything else
        
        orb_complete = not is_orb_window(ts)
        c = bar['close']
        inside_orb = session_low <= c <= session_high
        
        is_long = pine_long_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=c,
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        is_short = pine_short_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=c,
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        if is_long and not has_broken_out_high:
            has_broken_out_high = True
            events.append(f"🔥 LONG {ts.strftime('%H:%M')} @ {c:.2f}")
        
        if is_short and not has_broken_out_low:
            has_broken_out_low = True
            events.append(f"🔥 SHORT {ts.strftime('%H:%M')} @ {c:.2f}")
        
        if inside_orb:
            if has_broken_out_high:
                has_broken_out_high = False
                events.append(f"🔄 L-RST {ts.strftime('%H:%M')}")
            if has_broken_out_low:
                has_broken_out_low = False
                events.append(f"🔄 S-RST {ts.strftime('%H:%M')}")
    
    # Print day on one line
    if events:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | {' | '.join(events)}")
    else:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | No breakouts")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ⚠ Cache stale (17 hours), refreshing...
#   ✓ Fetched 89242 bars, cached for next time
# AAPL December 2025 - Breakout Detection (09:35-10:30 RTH)
# ...
# 07/16 | ORB 211.21/210.19 | 🔥 SHORT 09:51 @ 210.02 | 🔄 S-RST 09:52 | 🔥 LONG 10:10 @ 211.30 | 🔄 L-RST 10:11 | 🔥 LONG 10:12 @ 211.47
# 07/17 | ORB 210.92/210.06 | 🔥 SHORT 09:55 @ 210.02 | 🔄 S-RST 09:56 | 🔥 SHORT 10:11 @ 210.02
# 07/18 | ORB 211.01/210.00 | 🔥 SHORT 10:24 @ 209.96 | 🔄 S-RST 10:25
# 07/21 | ORB 212.94/211.63 | 🔥 LONG 09:36 @ 213.41
# 07/22 | ORB 213.31/212.23 | 🔥 LONG 09:39 @ 213.53 | 🔄 L-RST 09:44 | 🔥 LONG 09:48 @ 213.39 | 🔄 L-RST 09:49 | 🔥 LONG 09:56 @ 213.53 | 🔄 L-RST 10:00 | 🔥 LONG 10:01 @ 213.68 | 🔄 L-RST 10:04 | 🔥 LONG 10:22 @ 213.44 | 🔄 L-RST 10:27
# 07/23 | ORB 215.15/213.90 | 🔥 SHORT 09:40 @ 213.82
# 07/24 | ORB 215.69/213.69 | No breakouts
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, pine_long_breakout, pine_short_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load AAPL December
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-01', end_date='2025-12-31', verbose=False)
bt.load_data()
df = bt.df

# Get unique trading days (RTH only)
trading_days = df[df.index.map(lambda x: x.hour >= 9 and x.hour < 16)].index.date
trading_days = sorted(set(trading_days))

print(f"AAPL December 2025 - Breakout Detection (09:35-10:30 RTH)")
print(f"=" * 60)

atr = 0.30

for day in trading_days:
    day_df = df[df.index.date == day]
    if day_df.empty:
        continue
    
    session_high, session_low = build_orb(day_df)
    if session_high is None:
        continue
    
    date_str = pd.Timestamp(day).strftime('%m/%d')
    orb_range = session_high - session_low
    
    has_broken_out_high = False
    has_broken_out_low = False
    events = []
    
    for ts, bar in day_df.iterrows():
        # STRICT FILTER: 09:35-10:30 only
        if ts.hour == 9 and ts.minute >= 35:
            pass  # OK
        elif ts.hour == 10 and ts.minute <= 30:
            pass  # OK
        else:
            continue  # Skip everything else
        
        orb_complete = not is_orb_window(ts)
        c = bar['close']
        inside_orb = session_low <= c <= session_high
        
        is_long = pine_long_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=c,
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        is_short = pine_short_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=c,
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        if is_long and not has_broken_out_high:
            has_broken_out_high = True
            events.append(f"🔥 LONG {ts.strftime('%H:%M')} @ {c:.2f}")
        
        if is_short and not has_broken_out_low:
            has_broken_out_low = True
            events.append(f"🔥 SHORT {ts.strftime('%H:%M')} @ {c:.2f}")
        
        if inside_orb:
            if has_broken_out_high:
                has_broken_out_high = False
                events.append(f"🔄 L-RST {ts.strftime('%H:%M')}")
            if has_broken_out_low:
                has_broken_out_low = False
                events.append(f"🔄 S-RST {ts.strftime('%H:%M')}")
    
    # Print day on one line
    if events:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | {' | '.join(events)}")
    else:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | No breakouts")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# AAPL December 2025 - Breakout Detection (09:35-10:30 RTH)
# ...
# 07/16 | ORB 211.21/210.19 | 🔥 SHORT 09:51 @ 210.02 | 🔄 S-RST 09:52 | 🔥 LONG 10:10 @ 211.30 | 🔄 L-RST 10:11 | 🔥 LONG 10:12 @ 211.47
# 07/17 | ORB 210.92/210.06 | 🔥 SHORT 09:55 @ 210.02 | 🔄 S-RST 09:56 | 🔥 SHORT 10:11 @ 210.02
# 07/18 | ORB 211.01/210.00 | 🔥 SHORT 10:24 @ 209.96 | 🔄 S-RST 10:25
# 07/21 | ORB 212.94/211.63 | 🔥 LONG 09:36 @ 213.41
# 07/22 | ORB 213.31/212.23 | 🔥 LONG 09:39 @ 213.53 | 🔄 L-RST 09:44 | 🔥 LONG 09:48 @ 213.39 | 🔄 L-RST 09:49 | 🔥 LONG 09:56 @ 213.53 | 🔄 L-RST 10:00 | 🔥 LONG 10:01 @ 213.68 | 🔄 L-RST 10:04 | 🔥 LONG 10:22 @ 213.44 | 🔄 L-RST 10:27
# 07/23 | ORB 215.15/213.90 | 🔥 SHORT 09:40 @ 213.82
# 07/24 | ORB 215.69/213.69 | No breakouts
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, pine_long_breakout, pine_short_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load AAPL December
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-01', end_date='2025-12-31', verbose=False)
bt.load_data()
df = bt.df

# Get unique trading days (RTH only)
trading_days = df[df.index.map(lambda x: x.hour >= 9 and x.hour < 16)].index.date
trading_days = sorted(set(trading_days))

print(f"AAPL December 2025 - Breakout Detection (09:35-10:30 RTH)")
print(f"=" * 60)

atr = 0.30

for day in trading_days:
    day_df = df[df.index.date == day]
    if day_df.empty:
        continue
    
    session_high, session_low = build_orb(day_df)
    if session_high is None:
        continue
    
    date_str = pd.Timestamp(day).strftime('%m/%d')
    orb_range = session_high - session_low
    
    has_broken_out_high = False
    has_broken_out_low = False
    events = []
    
    for ts, bar in day_df.iterrows():
        # STRICT FILTER: 09:35-10:30 only
        if ts.hour == 9 and ts.minute >= 35:
            pass  # OK
        elif ts.hour == 10 and ts.minute <= 30:
            pass  # OK
        else:
            continue  # Skip everything else
        
        orb_complete = not is_orb_window(ts)
        c = bar['close']
        inside_orb = session_low <= c <= session_high
        
        is_long = pine_long_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=c,
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        is_short = pine_short_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=c,
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        if is_long and not has_broken_out_high:
            has_broken_out_high = True
            events.append(f"🔥 LONG {ts.strftime('%H:%M')} @ {c:.2f}")
        
        if is_short and not has_broken_out_low:
            has_broken_out_low = True
            events.append(f"🔥 SHORT {ts.strftime('%H:%M')} @ {c:.2f}")
        
        if inside_orb:
            if has_broken_out_high:
                has_broken_out_high = False
                events.append(f"🔄 L-RST {ts.strftime('%H:%M')}")
            if has_broken_out_low:
                has_broken_out_low = False
                events.append(f"🔄 S-RST {ts.strftime('%H:%M')}")
    
    # Print day on one line
    if events:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | {' | '.join(events)}")
    else:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | No breakouts")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.1 hours old)
# AAPL December 2025 - Breakout Detection (09:35-10:30 RTH)
# ...
# 07/16 | ORB 211.21/210.19 | 🔥 SHORT 09:51 @ 210.02 | 🔄 S-RST 09:52 | 🔥 LONG 10:10 @ 211.30 | 🔄 L-RST 10:11 | 🔥 LONG 10:12 @ 211.47
# 07/17 | ORB 210.92/210.06 | 🔥 SHORT 09:55 @ 210.02 | 🔄 S-RST 09:56 | 🔥 SHORT 10:11 @ 210.02
# 07/18 | ORB 211.01/210.00 | 🔥 SHORT 10:24 @ 209.96 | 🔄 S-RST 10:25
# 07/21 | ORB 212.94/211.63 | 🔥 LONG 09:36 @ 213.41
# 07/22 | ORB 213.31/212.23 | 🔥 LONG 09:39 @ 213.53 | 🔄 L-RST 09:44 | 🔥 LONG 09:48 @ 213.39 | 🔄 L-RST 09:49 | 🔥 LONG 09:56 @ 213.53 | 🔄 L-RST 10:00 | 🔥 LONG 10:01 @ 213.68 | 🔄 L-RST 10:04 | 🔥 LONG 10:22 @ 213.44 | 🔄 L-RST 10:27
# 07/23 | ORB 215.15/213.90 | 🔥 SHORT 09:40 @ 213.82
# 07/24 | ORB 215.69/213.69 | No breakouts
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, pine_long_breakout, pine_short_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load AAPL Dec 17
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-17', end_date='2025-12-17', verbose=False)
bt.load_data()
df = bt.df
dec17 = df[df.index.date == pd.Timestamp('2025-12-17').date()]

# Build ORB
session_high, session_low = build_orb(dec17)
print(f"ORB: High={session_high:.2f}, Low={session_low:.2f}\n")

# Get the 09:40 bar
bar_0940 = dec17[dec17.index.minute == 40]
bar_0940 = bar_0940[bar_0940.index.hour == 9].iloc[0]

print(f"09:40 bar:")
print(f"  O: {bar_0940['open']:.2f}")
print(f"  H: {bar_0940['high']:.2f}")
print(f"  L: {bar_0940['low']:.2f}")
print(f"  C: {bar_0940['close']:.2f}")

atr = 0.30
o, h, l, c = bar_0940['open'], bar_0940['high'], bar_0940['low'], bar_0940['close']

print(f"\nBreakout conditions:")
print(f"  openInRange: {session_low:.2f} <= {o:.2f} <= {session_high:.2f} ? {session_low <= o <= session_high}")
print(f"  closeBelowLow: {c:.2f} < {session_low:.2f} ? {c < session_low}")
threshold = atr * 0.1
print(f"  threshold: {threshold:.4f}")
print(f"  sufficientLow: {c:.2f} < {session_low - threshold:.2f} ? {c < session_low - threshold}")
body = abs(c - o)
rng = h - l
ratio = body/rng if rng > 0 else 0
print(f"  bodyRatio: {ratio:.2f} >= 0.5 ? {ratio >= 0.5}")

is_short = pine_short_breakout(
    o=o, h=h, l=l, c=c,
    session_low=session_low, session_high=session_high,
    atr=atr, orb_complete=True
)
print(f"\npine_short_breakout: {is_short}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.5 hours old)
# ORB: High=276.09, Low=274.83
#
# 09:40 bar:
#   O: 275.81
#   H: 276.15
#   L: 275.53
#   C: 276.12
#
# Breakout conditions:
#   openInRange: 274.83 <= 275.81 <= 276.09 ? True
#   closeBelowLow: 276.12 < 274.83 ? False
#   threshold: 0.0300
#   sufficientLow: 276.12 < 274.80 ? False
#   bodyRatio: 0.51 >= 0.5 ? True
#
# pine_short_breakout: False

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, pine_long_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load AAPL Dec 17
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-17', end_date='2025-12-17', verbose=False)
bt.load_data()
df = bt.df
dec17 = df[df.index.date == pd.Timestamp('2025-12-17').date()]

# Build ORB
session_high, session_low = build_orb(dec17)
print(f"ORB: High={session_high:.2f}, Low={session_low:.2f}\n")

# Get the 09:40 bar
bar_0940 = dec17[dec17.index.minute == 40]
bar_0940 = bar_0940[bar_0940.index.hour == 9].iloc[0]

print(f"09:40 bar:")
print(f"  O: {bar_0940['open']:.2f}")
print(f"  H: {bar_0940['high']:.2f}")
print(f"  L: {bar_0940['low']:.2f}")
print(f"  C: {bar_0940['close']:.2f}")

atr = 0.30
o, h, l, c = bar_0940['open'], bar_0940['high'], bar_0940['low'], bar_0940['close']

print(f"\nLONG Breakout conditions:")
print(f"  openInRange: {session_low:.2f} <= {o:.2f} <= {session_high:.2f} ? {session_low <= o <= session_high}")
print(f"  closeAboveHigh: {c:.2f} > {session_high:.2f} ? {c > session_high}")
threshold = atr * 0.1
print(f"  threshold: {threshold:.4f}")
print(f"  sufficientHigh: {c:.2f} > {session_high + threshold:.4f} ? {c > session_high + threshold}")
body = abs(c - o)
rng = h - l
ratio = body/rng if rng > 0 else 0
print(f"  bodyRatio: {ratio:.2f} >= 0.5 ? {ratio >= 0.5}")

is_long = pine_long_breakout(
    o=o, h=h, l=l, c=c,
    session_low=session_low, session_high=session_high,
    atr=atr, orb_complete=True
)
print(f"\npine_long_breakout: {is_long}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.5 hours old)
# ORB: High=276.09, Low=274.83
#
# 09:40 bar:
#   O: 275.81
#   H: 276.15
#   L: 275.53
#   C: 276.12
#
# LONG Breakout conditions:
#   openInRange: 274.83 <= 275.81 <= 276.09 ? True
#   closeAboveHigh: 276.12 > 276.09 ? True
#   threshold: 0.0300
#   sufficientHigh: 276.12 > 276.1200 ? True
#   bodyRatio: 0.51 >= 0.5 ? True
#
# pine_long_breakout: True

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, pine_long_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

# Load AAPL Dec 17
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-17', end_date='2025-12-17', verbose=False)
bt.load_data()
df = bt.df
dec17 = df[df.index.date == pd.Timestamp('2025-12-17').date()]

# Build ORB
session_high, session_low = build_orb(dec17)
print(f"ORB: High={session_high:.2f}, Low={session_low:.2f}\n")

# Get the 09:40 bar - use actual ATR from data
bar_0940 = dec17[(dec17.index.hour == 9) & (dec17.index.minute == 40)].iloc[0]

print(f"09:40 bar:")
print(f"  O: {bar_0940['open']:.2f}")
print(f"  H: {bar_0940['high']:.2f}")
print(f"  L: {bar_0940['low']:.2f}")
print(f"  C: {bar_0940['close']:.2f}")

# Use actual ATR from the data
atr = bar_0940['atr_rth'] if 'atr_rth' in bar_0940 else bar_0940.get('atr', 0.40)
print(f"  ATR: {atr:.4f}")

o, h, l, c = bar_0940['open'], bar_0940['high'], bar_0940['low'], bar_0940['close']

print(f"\nLONG Breakout conditions:")
print(f"  openInRange: {session_low:.2f} <= {o:.2f} <= {session_high:.2f} ? {session_low <= o <= session_high}")
print(f"  closeAboveHigh: {c:.2f} > {session_high:.2f} ? {c > session_high}")
threshold = atr * 0.1
print(f"  threshold: {threshold:.4f}")
print(f"  sufficientHigh: {c:.2f} > {session_high + threshold:.4f} ? {c > session_high + threshold}")
body = abs(c - o)
rng = h - l
ratio = body/rng if rng > 0 else 0
print(f"  bodyRatio: {ratio:.2f} >= 0.5 ? {ratio >= 0.5}")

is_long = pine_long_breakout(
    o=o, h=h, l=l, c=c,
    session_low=session_low, session_high=session_high,
    atr=atr, orb_complete=True
)
print(f"\npine_long_breakout: {is_long}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.6 hours old)
# ORB: High=276.09, Low=274.83
#
# 09:40 bar:
#   O: 275.81
#   H: 276.15
#   L: 275.53
#   C: 276.12
#   ATR: 0.2410
#
# LONG Breakout conditions:
#   openInRange: 274.83 <= 275.81 <= 276.09 ? True
#   closeAboveHigh: 276.12 > 276.09 ? True
#   threshold: 0.0241
#   sufficientHigh: 276.12 > 276.1141 ? True
#   bodyRatio: 0.51 >= 0.5 ? True
#
# pine_long_breakout: True

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-17', end_date='2025-12-17', verbose=False)
bt.load_data()
df = bt.df
dec17 = df[df.index.date == pd.Timestamp('2025-12-17').date()]

bar_0940 = dec17[(dec17.index.hour == 9) & (dec17.index.minute == 40)].iloc[0]

print("All columns:")
print(dec17.columns.tolist())

print("\nATR-related values at 09:40:")
for col in dec17.columns:
    if 'atr' in col.lower():
        print(f"  {col}: {bar_0940[col]:.4f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.9 hours old)
# All columns:
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import build_orb, pine_long_breakout
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-17', end_date='2025-12-17', verbose=False)
bt.load_data()
df = bt.df
dec17 = df[df.index.date == pd.Timestamp('2025-12-17').date()]

session_high, session_low = build_orb(dec17)
bar_0940 = dec17[(dec17.index.hour == 9) & (dec17.index.minute == 40)].iloc[0]

print(f"ORB: High={session_high:.2f}, Low={session_low:.2f}")
print(f"\n09:40 bar: C={bar_0940['close']:.2f}")
print(f"  atr_rth: {bar_0940['atr_rth']:.4f}")
print(f"  std_atr: {bar_0940['std_atr']:.4f}")
print(f"  Pine rthATR: 0.3968")

# Test with std_atr instead
atr = bar_0940['std_atr']
o, h, l, c = bar_0940['open'], bar_0940['high'], bar_0940['low'], bar_0940['close']
threshold = atr * 0.1

print(f"\nUsing std_atr ({atr:.4f}):")
print(f"  threshold: {threshold:.4f}")
print(f"  sufficientHigh: {c:.2f} > {session_high + threshold:.4f} ? {c > session_high + threshold}")

is_long = pine_long_breakout(o=o, h=h, l=l, c=c,
    session_low=session_low, session_high=session_high,
    atr=atr, orb_complete=True)
print(f"  pine_long_breakout: {is_long}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (6.0 hours old)
# ORB: High=276.09, Low=274.83
#
# 09:40 bar: C=276.12
#   atr_rth: 0.2410
#   std_atr: 0.3719
#   Pine rthATR: 0.3968
#
# Using std_atr (0.3719):
#   threshold: 0.0372
#   sufficientHigh: 276.12 > 276.1272 ? False
#   pine_long_breakout: False

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-17', end_date='2025-12-17', verbose=False)
bt.load_data()
df = bt.df

print(f"Index timezone: {df.index.tz}")
print(f"\nSample timestamps around market close:")
dec17 = df[df.index.date == pd.Timestamp('2025-12-17').date()]
close_bars = dec17[(dec17.index.hour >= 15) & (dec17.index.hour <= 16)]
print(close_bars.index[:10])
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (6.1 hours old)
# Index timezone: US/Eastern
#
# Sample timestamps around market close:
# DatetimeIndex(['2025-12-17 15:00:00-05:00', '2025-12-17 15:01:00-05:00',
#                '2025-12-17 15:02:00-05:00', '2025-12-17 15:03:00-05:00',
#                '2025-12-17 15:04:00-05:00', '2025-12-17 15:05:00-05:00',
#                '2025-12-17 15:06:00-05:00', '2025-12-17 15:07:00-05:00',
#                '2025-12-17 15:08:00-05:00', '2025-12-17 15:09:00-05:00'],
#               dtype='datetime64[ns, US/Eastern]', name='timestamp', freq=None)

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-16', end_date='2025-12-17', verbose=False)
bt.load_data()
df = bt.df

# Check Dec 16 at 15:59 (this should be frozen for Dec 17)
dec16 = df[df.index.date == pd.Timestamp('2025-12-16').date()]
bar_1559 = dec16[(dec16.index.hour == 15) & (dec16.index.minute == 59)]

print("Dec 16 @ 15:59:")
if not bar_1559.empty:
    print(f"  std_atr: {bar_1559.iloc[0]['std_atr']:.4f}")
    print(f"  atr_rth: {bar_1559.iloc[0]['atr_rth']:.4f}")
else:
    print("  No 15:59 bar found!")

# Check Dec 17 @ 09:40
dec17 = df[df.index.date == pd.Timestamp('2025-12-17').date()]
bar_0940 = dec17[(dec17.index.hour == 9) & (dec17.index.minute == 40)].iloc[0]

print("\nDec 17 @ 09:40:")
print(f"  atr_rth: {bar_0940['atr_rth']:.4f}")
print(f"  std_atr: {bar_0940['std_atr']:.4f}")
print(f"  Pine rthATR: 0.3968")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (6.1 hours old)
# Dec 16 @ 15:59:
#   std_atr: 0.2410
#   atr_rth: 0.3043
#
# Dec 17 @ 09:40:
#   atr_rth: 0.2410
#   std_atr: 0.3719
#   Pine rthATR: 0.3968

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-16', end_date='2025-12-16', verbose=False)
bt.load_data()
df = bt.df

dec16 = df[df.index.date == pd.Timestamp('2025-12-16').date()]

# Check ATR values through the day
print("Dec 16 ATR progression (last 30 mins of RTH):")
late_day = dec16[(dec16.index.hour == 15) & (dec16.index.minute >= 30)]
for ts, bar in late_day.iterrows():
    print(f"  {ts.strftime('%H:%M')} std_atr={bar['std_atr']:.4f} tr={bar['tr']:.4f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (6.1 hours old)
# Dec 16 ATR progression (last 30 mins of RTH):
#   15:30 std_atr=0.1326 tr=0.2300
#   15:31 std_atr=0.1279 tr=0.0668
#   15:32 std_atr=0.1259 tr=0.1000
#   15:33 std_atr=0.1223 tr=0.0750
#   15:34 std_atr=0.1285 tr=0.2100
#   15:35 std_atr=0.1344 tr=0.2100
#   15:36 std_atr=0.1371 tr=0.1733
#   15:37 std_atr=0.1391 tr=0.1650
#   15:38 std_atr=0.1381 tr=0.1249
#   15:39 std_atr=0.1404 tr=0.1700
#   15:40 std_atr=0.1411 tr=0.1506
#   15:41 std_atr=0.1446 tr=0.1900
#   15:42 std_atr=0.1414 tr=0.1000
#   15:43 std_atr=0.1420 tr=0.1499
#   15:44 std_atr=0.1476 tr=0.2199
#   15:45 std_atr=0.1463 tr=0.1300
#   15:46 std_atr=0.1480 tr=0.1700
#   15:47 std_atr=0.1546 tr=0.2400
#   15:48 std_atr=0.1560 tr=0.1749
#   15:49 std_atr=0.1545 tr=0.1349
#   15:50 std_atr=0.1899 tr=0.6500
#   15:51 std_atr=0.1985 tr=0.3100
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-01', end_date='2025-12-17', verbose=False)
bt.load_data()
df = bt.df

# RTH only
rth_mask = df.index.map(lambda x: 9*60+30 <= x.hour*60+x.minute < 16*60)
rth_df = df[rth_mask].copy()

# TR
tr = pd.concat([
    rth_df['high'] - rth_df['low'],
    (rth_df['high'] - rth_df['close'].shift(1)).abs(),
    (rth_df['low'] - rth_df['close'].shift(1)).abs()
], axis=1).max(axis=1)

# Wilder ATR
atr = tr.ewm(alpha=1/14, adjust=False).mean()
rth_df['atr'] = atr

# Check Dec 17 @ 09:40
bar = rth_df[(rth_df.index.date == pd.Timestamp('2025-12-17').date()) & 
             (rth_df.index.hour == 9) & (rth_df.index.minute == 40)]
if not bar.empty:
    atr_val = bar.iloc[0]['atr']
    threshold = atr_val * 0.1
    print(f"Python RTH ATR: {atr_val:.4f}")
    print(f"Pine rthATR:    0.3968")
    print(f"Match: {'✓' if abs(atr_val - 0.3968) < 0.01 else '✗'}")
    print(f"\nThreshold: {threshold:.4f}")
    print(f"Close: 276.12, SessionHigh: 276.09")
    print(f"Need: > {276.09 + threshold:.4f}")
    print(f"Breakout: {'Yes' if 276.12 > 276.09 + threshold else 'No'}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ⚠ Cache stale (10 hours), refreshing...
#   ✓ Fetched 89548 bars, cached for next time
# Python RTH ATR: 0.4077
# Pine rthATR:    0.3968
# Match: ✗
#
# Threshold: 0.0408
# Close: 276.12, SessionHigh: 276.09
# Need: > 276.1308
# Breakout: No

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import calc_atr_rth, build_orb, pine_long_breakout, pine_short_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-01', end_date='2025-12-17', verbose=False)
bt.load_data()
df = bt.df

# Add RTH ATR
df['atr'] = calc_atr_rth(df)

print("AAPL December 2025 - Breakout Detection (RTH ATR)")
print("=" * 70)

trading_days = sorted(set(df[df.index.hour >= 9].index.date))

for day in trading_days[-10:]:  # Last 10 days
    day_df = df[df.index.date == day]
    session_high, session_low = build_orb(day_df)
    if session_high is None:
        continue
    
    date_str = pd.Timestamp(day).strftime('%m/%d')
    events = []
    
    for ts, bar in day_df.iterrows():
        if ts.hour == 9 and ts.minute >= 35:
            pass
        elif ts.hour == 10 and ts.minute <= 30:
            pass
        else:
            continue
        
        orb_complete = not is_orb_window(ts)
        atr = bar['atr'] if pd.notna(bar['atr']) else 0.40
        
        is_long = pine_long_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=bar['close'],
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        is_short = pine_short_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=bar['close'],
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        if is_long:
            events.append(f"🔥 LONG {ts.strftime('%H:%M')} @ {bar['close']:.2f}")
        if is_short:
            events.append(f"🔥 SHORT {ts.strftime('%H:%M')} @ {bar['close']:.2f}")
    
    if events:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | {' | '.join(events[:3])}")
    else:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | No breakouts")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# AAPL December 2025 - Breakout Detection (RTH ATR)
# ...
# 12/29 | ORB 274.20/272.35 | No breakouts
# 12/30 | ORB 274.08/272.72 | 🔥 SHORT 09:35 @ 272.54 | 🔥 SHORT 10:24 @ 272.64
# 12/31 | ORB 273.68/272.50 | 🔥 SHORT 09:41 @ 272.40
# 01/02 | ORB 273.39/271.95 | 🔥 LONG 09:36 @ 273.67
# 01/05 | ORB 271.51/268.10 | No breakouts
# 01/06 | ORB 267.55/264.55 | 🔥 SHORT 09:59 @ 264.46 | 🔥 SHORT 10:16 @ 264.47 | 🔥 SHORT 10:18 @ 264.36
# 01/07 | ORB 263.68/262.05 | 🔥 SHORT 09:35 @ 261.98 | 🔥 SHORT 09:50 @ 261.80 | 🔥 SHORT 09:56 @ 261.87
# 01/08 | ORB 257.78/256.25 | 🔥 SHORT 10:01 @ 256.07
# 01/09 | ORB 260.00/258.61 | No breakouts
# 01/12 | ORB 260.27/257.92 | 🔥 LONG 10:27 @ 260.97

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import calc_atr_rth, build_orb, pine_long_breakout, pine_short_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-01', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df

# Add RTH ATR
df['atr'] = calc_atr_rth(df)

dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()]
session_high, session_low = build_orb(dec19)

print(f"AAPL Dec 19 - ORB: {session_high:.2f}/{session_low:.2f}")
print("=" * 60)

for ts, bar in dec19.iterrows():
    if ts.hour == 9 and ts.minute >= 35:
        pass
    elif ts.hour == 10 and ts.minute <= 30:
        pass
    else:
        continue
    
    orb_complete = not is_orb_window(ts)
    atr = bar['atr'] if pd.notna(bar['atr']) else 0.40
    
    is_long = pine_long_breakout(
        o=bar['open'], h=bar['high'], l=bar['low'], c=bar['close'],
        session_low=session_low, session_high=session_high,
        atr=atr, orb_complete=orb_complete
    )
    
    is_short = pine_short_breakout(
        o=bar['open'], h=bar['high'], l=bar['low'], c=bar['close'],
        session_low=session_low, session_high=session_high,
        atr=atr, orb_complete=orb_complete
    )
    
    if is_long or is_short:
        direction = "LONG" if is_long else "SHORT"
        print(f"{ts.strftime('%H:%M')} | 🔥 {direction} @ {bar['close']:.2f} | ATR: {atr:.4f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.9 hours old)
# AAPL Dec 19 - ORB: 272.79/271.57
# ...
# 10:18 | 🔥 SHORT @ 271.35 | ATR: 0.3125
# 10:21 | 🔥 SHORT @ 271.53 | ATR: 0.3028
# 10:30 | 🔥 SHORT @ 271.54 | ATR: 0.2835

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import calc_atr_rth, build_orb, pine_long_breakout, pine_short_breakout, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AMD', start_date='2025-12-01', end_date='2025-12-31', verbose=False)
bt.load_data()
df = bt.df

# Add RTH ATR
df['atr'] = calc_atr_rth(df)

print("AMD December 2025 - Breakout Detection (RTH ATR)")
print("=" * 70)

trading_days = sorted(set(df[df.index.hour >= 9].index.date))

for day in trading_days:
    day_df = df[df.index.date == day]
    session_high, session_low = build_orb(day_df)
    if session_high is None:
        continue
    
    date_str = pd.Timestamp(day).strftime('%m/%d')
    events = []
    
    for ts, bar in day_df.iterrows():
        if ts.hour == 9 and ts.minute >= 35:
            pass
        elif ts.hour == 10 and ts.minute <= 30:
            pass
        else:
            continue
        
        orb_complete = not is_orb_window(ts)
        atr = bar['atr'] if pd.notna(bar['atr']) else 0.40
        
        is_long = pine_long_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=bar['close'],
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        is_short = pine_short_breakout(
            o=bar['open'], h=bar['high'], l=bar['low'], c=bar['close'],
            session_low=session_low, session_high=session_high,
            atr=atr, orb_complete=orb_complete
        )
        
        if is_long:
            events.append(f"🔥 LONG {ts.strftime('%H:%M')} @ {bar['close']:.2f}")
        if is_short:
            events.append(f"🔥 SHORT {ts.strftime('%H:%M')} @ {bar['close']:.2f}")
    
    if events:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | {' | '.join(events[:3])}")
    else:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | No breakouts")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ⚠ Cache stale (4 hours), refreshing...
#   ✓ Fetched 102909 bars, cached for next time
# AMD December 2025 - Breakout Detection (RTH ATR)
# ...
# 07/16 | ORB 156.33/154.83 | 🔥 SHORT 09:41 @ 154.56 | 🔥 SHORT 09:49 @ 154.55 | 🔥 SHORT 10:01 @ 154.78
# 07/17 | ORB 161.96/159.40 | 🔥 SHORT 09:43 @ 159.27
# 07/18 | ORB 160.50/159.41 | 🔥 SHORT 09:40 @ 159.19 | 🔥 SHORT 09:59 @ 159.34 | 🔥 SHORT 10:02 @ 159.25
# 07/21 | ORB 159.60/157.50 | No breakouts
# 07/22 | ORB 156.23/154.40 | 🔥 SHORT 09:37 @ 154.23
# 07/23 | ORB 158.35/156.00 | No breakouts
# 07/24 | ORB 159.59/158.36 | 🔥 LONG 09:35 @ 159.77 | 🔥 LONG 10:15 @ 159.68 | 🔥 LONG 10:18 @ 159.75
# 07/25 | ORB 164.35/162.36 | 🔥 LONG 09:52 @ 164.70
# 07/28 | ORB 171.60/168.67 | No breakouts
# 07/29 | ORB 177.78/174.68 | 🔥 LONG 09:35 @ 178.24
# 07/30 | ORB 176.84/173.80 | No breakouts
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import ORBState, calc_atr_rth, build_orb, check_entry_signal, is_orb_window
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AMD', start_date='2025-12-01', end_date='2025-12-31', verbose=False)
bt.load_data()
df = bt.df
df['atr'] = calc_atr_rth(df)

# Get unique dates and filter to December only
all_dates = pd.Series(df.index.date).unique()
dec_dates = [d for d in all_dates if d.month == 12]

print(f"AMD December 2025 - {len(dec_dates)} trading days")
print("=" * 70)

for day in dec_dates:
    day_df = df[df.index.date == day]
    
    # Initialize state for each day
    state = ORBState()
    session_high, session_low = build_orb(day_df)
    
    if session_high is None:
        continue
        
    state.session_high = session_high
    state.session_low = session_low
    
    date_str = pd.Timestamp(day).strftime('%m/%d')
    entries = []
    
    for ts, bar in day_df.iterrows():
        state.orb_complete = not is_orb_window(ts)
        
        # Only check 09:35-10:30
        mins = ts.hour * 60 + ts.minute
        if not (9*60+35 <= mins <= 10*60+30):
            continue
        
        atr = bar['atr'] if pd.notna(bar['atr']) else 0.40
        
        signal = check_entry_signal(
            state=state,
            ts=ts,
            o=bar['open'], h=bar['high'], l=bar['low'], c=bar['close'],
            atr=atr
        )
        
        if signal:
            entries.append(f"🔥 {signal} {ts.strftime('%H:%M')} @ {bar['close']:.2f}")
            state.enter_position(signal, bar['close'], ts)
    
    if entries:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | {entries[0]}")
    else:
        print(f"{date_str} | ORB {session_high:.2f}/{session_low:.2f} | No entry")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ⚠ Cache stale (18 hours), refreshing...
#   ✓ Fetched 102808 bars, cached for next time
# AMD December 2025 - 22 trading days
# ...
# 12/01 | ORB 215.84/213.50 | 🔥 LONG 09:36 @ 216.22
# 12/02 | ORB 223.79/219.80 | 🔥 LONG 09:36 @ 224.33
# 12/03 | ORB 216.88/213.86 | 🔥 SHORT 09:35 @ 213.28
# 12/04 | ORB 217.37/215.77 | 🔥 SHORT 09:51 @ 215.28
# 12/05 | ORB 221.94/217.00 | 🔥 SHORT 09:41 @ 216.74
# 12/08 | ORB 221.84/218.85 | 🔥 LONG 09:38 @ 221.94
# 12/09 | ORB 221.04/217.91 | 🔥 LONG 10:02 @ 221.59
# 12/10 | ORB 222.00/219.70 | 🔥 SHORT 10:09 @ 219.64
# 12/11 | ORB 217.81/213.33 | 🔥 SHORT 09:49 @ 212.95
# 12/12 | ORB 220.73/218.05 | 🔥 LONG 09:35 @ 220.99
# 12/15 | ORB 214.01/212.15 | 🔥 LONG 09:48 @ 214.46
# 12/16 | ORB 208.58/205.80 | 🔥 LONG 09:36 @ 208.76
# 12/17 | ORB 211.50/208.88 | 🔥 SHORT 09:35 @ 208.56
# 12/18 | ORB 205.99/203.72 | 🔥 SHORT 09:48 @ 203.62
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import (ORBState, calc_atr_rth, build_orb, check_entry_signal, 
                      is_orb_window, calc_initial_stop, check_exit)
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df
df['atr'] = calc_atr_rth(df)

dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()]

# Initialize state
state = ORBState()
session_high, session_low = build_orb(dec19)
state.session_high = session_high
state.session_low = session_low

print(f"AAPL Dec 19 - ORB: {session_high:.2f}/{session_low:.2f}")
print("=" * 70)

trades = []

for ts, bar in dec19.iterrows():
    state.orb_complete = not is_orb_window(ts)
    
    # Only check 09:35-10:30 for entries
    mins = ts.hour * 60 + ts.minute
    in_trading_window = 9*60+35 <= mins <= 10*60+30
    
    atr = bar['atr'] if pd.notna(bar['atr']) else 0.40
    
    # Check exit first (if in position)
    if state.in_position:
        should_exit, exit_reason, exit_price = check_exit(
            state, bar['high'], bar['low'], bar['close']
        )
        if should_exit:
            pnl = exit_price - state.entry_price if state.position_direction == 'LONG' else state.entry_price - exit_price
            risk = abs(state.entry_price - state.initial_stop)
            r_mult = pnl / risk if risk > 0 else 0
            print(f"{ts.strftime('%H:%M')} | EXIT {exit_reason} @ {exit_price:.2f} | PnL: ${pnl:.2f} ({r_mult:.2f}R)")
            trades.append({'exit_reason': exit_reason, 'r_mult': r_mult})
            state.exit_position()
    
    # Check entry (only in trading window, only if not in position)
    if in_trading_window and not state.in_position:
        signal = check_entry_signal(
            state=state, ts=ts,
            o=bar['open'], h=bar['high'], l=bar['low'], c=bar['close'],
            atr=atr
        )
        
        if signal:
            stop = calc_initial_stop(signal, bar['close'], atr)
            print(f"{ts.strftime('%H:%M')} | ENTRY {signal} @ {bar['close']:.2f} | Stop: {stop:.2f}")
            state.enter_position(signal, bar['close'], ts, stop)

print(f"\nTotal trades: {len(trades)}")
for i, t in enumerate(trades, 1):
    print(f"  Trade {i}: {t['exit_reason']} ({t['r_mult']:.2f}R)")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ⚠ Cache stale (19 hours), refreshing...
#   ✓ Fetched 89571 bars, cached for next time
# AAPL Dec 19 - ORB: 272.79/271.57
# ...
# 10:18 | ENTRY SHORT @ 271.35 | Stop: 271.98
# 10:32 | EXIT STOP-LOSS @ 271.98 | PnL: $-0.63 (-1.00R)
#
# Total trades: 1
#   Trade 1: STOP-LOSS (-1.00R)

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import (ORBState, VolState, calc_atr_rth, calc_atr_fast, calc_vol_state,
                      get_rr_for_vol_state, build_orb, check_entry_signal, 
                      is_orb_window, evaluate_best_stop, check_exit)
from orb_backtester import ORBBacktester
import pandas as pd
import numpy as np

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df

# ATR calculations
df['atr'] = calc_atr_rth(df)
df['atr_fast'] = calc_atr_fast(df, period=5)
df['atr_fast_sma'] = df['atr_fast'].rolling(10).mean()

# VWAP
df['cum_vol'] = df.groupby(df.index.date)['volume'].cumsum()
df['cum_vp'] = df.groupby(df.index.date).apply(lambda x: (x['close'] * x['volume']).cumsum()).values
df['vwap'] = df['cum_vp'] / df['cum_vol']

dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()]

state = ORBState()
vol = VolState()
session_high, session_low = build_orb(dec19)
state.session_high = session_high
state.session_low = session_low

print(f"AAPL Dec 19 - ORB: {session_high:.2f}/{session_low:.2f}")
print("=" * 70)

for ts, bar in dec19.iterrows():
    state.orb_complete = not is_orb_window(ts)
    mins = ts.hour * 60 + ts.minute
    in_trading_window = 9*60+35 <= mins <= 10*60+30
    
    atr = bar['atr'] if pd.notna(bar['atr']) else 0.40
    atr_fast = bar['atr_fast'] if pd.notna(bar['atr_fast']) else atr
    atr_fast_sma = bar['atr_fast_sma'] if pd.notna(bar['atr_fast_sma']) else atr_fast
    vwap = bar['vwap'] if pd.notna(bar['vwap']) else bar['close']
    
    # Update vol state
    calc_vol_state(vol, ts, atr_fast, atr_fast_sma)
    
    if state.in_position:
        should_exit, exit_reason, exit_price = check_exit(state, bar['high'], bar['low'], bar['close'])
        if should_exit:
            pnl = exit_price - state.entry_price if state.position_direction == 'LONG' else state.entry_price - exit_price
            risk = abs(state.entry_price - state.initial_stop)
            r_mult = pnl / risk if risk > 0 else 0
            print(f"{ts.strftime('%H:%M')} | EXIT {exit_reason} @ {exit_price:.2f} | PnL: ${pnl:.2f} ({r_mult:.2f}R)")
            state.exit_position()
    
    if in_trading_window and not state.in_position:
        signal = check_entry_signal(state=state, ts=ts, o=bar['open'], h=bar['high'], l=bar['low'], c=bar['close'], atr=atr)
        
        if signal:
            rr_desired = get_rr_for_vol_state(vol.vol_state)
            stop, stop_type, rr = evaluate_best_stop(
                direction=signal, entry_price=bar['close'], atr=atr, vwap=vwap,
                df=df, ts=ts, rr_desired=rr_desired
            )
            print(f"{ts.strftime('%H:%M')} | ENTRY {signal} @ {bar['close']:.2f} | {stop_type} Stop: {stop:.2f} | VF: {vol.vol_factor:.2f} [{vol.vol_state}] | R:R: {rr:.2f}")
            state.enter_position(signal, bar['close'], ts, stop)
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.2 hours old)
# AAPL Dec 19 - ORB: 272.79/271.57
# ...
# 10:18 | ENTRY SHORT @ 271.35 | ATR Stop: 271.98 | VF: 0.68 [LOW] | R:R: 1.50
# 10:32 | EXIT STOP-LOSS @ 271.98 | PnL: $-0.63 (-1.00R)

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import find_swing_high, calc_atr_rth, evaluate_best_stop, get_rr_for_vol_state
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df
df['atr'] = calc_atr_rth(df)

# VWAP
df['cum_vol'] = df.groupby(df.index.date)['volume'].cumsum()
df['cum_vp'] = df.groupby(df.index.date).apply(lambda x: (x['close'] * x['volume']).cumsum()).values
df['vwap'] = df['cum_vp'] / df['cum_vol']

# At 10:18 entry
ts = pd.Timestamp('2025-12-19 10:18:00', tz='America/New_York')
entry = 271.35

# Find actual bar
bar = df[df.index.hour == 10][df.index.minute == 18]
if len(bar) > 0:
    bar = bar.iloc[0]
    atr = bar['atr']
    vwap = bar['vwap']
else:
    atr = 0.31
    vwap = 272.0

print(f"Entry: {entry}")
print(f"ATR: {atr:.4f}")
print(f"VWAP: {vwap:.2f}")

# Vol state would be LOW, so rrDesired = 2.5
rr_desired = get_rr_for_vol_state("LOW", 2.0)
print(f"rrDesired (LOW vol): {rr_desired}")

# Swing high
swing_high = find_swing_high(df, ts, lookback=5)
print(f"Swing High (last 5 RTH bars): {swing_high}")

# Calculate stops
swing_buffer = 0.02
atr_mult = 2.0
vwap_dist = 0.3

atr_stop = entry + (atr * atr_mult)
swing_stop = swing_high + (atr * swing_buffer) if swing_high else atr_stop
vwap_stop = vwap + (atr * vwap_dist)

print(f"\nStop calculations for SHORT @ {entry}:")
print(f"  ATR Stop:   {atr_stop:.2f} (entry + ATR*2.0)")
print(f"  Swing Stop: {swing_stop:.2f} (swing_high + ATR*0.02)")
print(f"  VWAP Stop:  {vwap_stop:.2f} (VWAP + ATR*0.3)")

# Now test evaluate_best_stop
stop, stop_type, rr = evaluate_best_stop(
    direction='SHORT', entry_price=entry, atr=atr, vwap=vwap,
    df=df, ts=ts, rr_desired=rr_desired
)
print(f"\nevaluate_best_stop() selected: {stop_type} @ {stop:.2f}, R:R={rr:.2f}")
print(f"Pine selected: Swing @ 272, R:R=1.53")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.4 hours old)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6268\3146946174.py in ?()
#      21 ts = pd.Timestamp('2025-12-19 10:18:00', tz='America/New_York')
#      22 entry = 271.35
#      23
#      24 # Find actual bar
# ---> 25 bar = df[df.index.hour == 10][df.index.minute == 18]
#      26 if len(bar) > 0:
#      27     bar = bar.iloc[0]
#      28     atr = bar['atr']
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4100             return self.where(key)
#    4101
#    4102         # Do we have a (boolean) 1d indexer?
#    4103         if com.is_bool_indexer(key):
# -> 4104             return self._getitem_bool_array(key)
#    4105
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import (ORBState, VolState, calc_atr_rth, calc_atr_fast, calc_vol_state,
                      get_rr_for_vol_state, build_orb, check_entry_signal, 
                      is_orb_window, calc_all_stops, select_best_stop, check_exit)
from orb_backtester import ORBBacktester
import pandas as pd
import numpy as np

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df

df['atr'] = calc_atr_rth(df)
df['atr_fast'] = calc_atr_fast(df, period=5)
df['atr_fast_sma'] = df['atr_fast'].rolling(10).mean()

# VWAP per day
df['cum_vol'] = df.groupby(df.index.date)['volume'].cumsum()
df['cum_vp'] = df.groupby(df.index.date).apply(lambda x: (x['close'] * x['volume']).cumsum()).values
df['vwap'] = df['cum_vp'] / df['cum_vol']

dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()].copy()

state = ORBState()
vol = VolState()
session_high, session_low = build_orb(dec19)
state.session_high = session_high
state.session_low = session_low

print(f"AAPL Dec 19 - ORB: {session_high:.2f}/{session_low:.2f}")
print("=" * 70)

for i, (ts, bar) in enumerate(dec19.iterrows()):
    state.orb_complete = not is_orb_window(ts)
    mins = ts.hour * 60 + ts.minute
    in_trading_window = 9*60+35 <= mins <= 10*60+30
    
    atr = bar['atr'] if pd.notna(bar['atr']) else 0.40
    atr_fast = bar['atr_fast'] if pd.notna(bar['atr_fast']) else atr
    atr_fast_sma = bar['atr_fast_sma'] if pd.notna(bar['atr_fast_sma']) else atr_fast
    vwap = bar['vwap'] if pd.notna(bar['vwap']) else bar['close']
    
    calc_vol_state(vol, ts, atr_fast, atr_fast_sma)
    
    if state.in_position:
        should_exit, exit_reason, exit_price = check_exit(state, bar['high'], bar['low'], bar['close'])
        if should_exit:
            pnl = exit_price - state.entry_price if state.position_direction == 'LONG' else state.entry_price - exit_price
            risk = abs(state.entry_price - state.initial_stop)
            r_mult = pnl / risk if risk > 0 else 0
            print(f"{ts.strftime('%H:%M')} | EXIT {exit_reason} @ {exit_price:.2f} | PnL: ${pnl:.2f} ({r_mult:.2f}R)")
            state.exit_position()
    
    if in_trading_window and not state.in_position:
        signal = check_entry_signal(state=state, ts=ts, o=bar['open'], h=bar['high'], l=bar['low'], c=bar['close'], atr=atr)
        
        if signal:
            is_long = signal == 'LONG'
            rr_desired = get_rr_for_vol_state(vol.vol_state)
            
            stops = calc_all_stops(
                entry=bar['close'], atr=atr, vwap=vwap, is_long=is_long,
                day_df=dec19, bar_idx=i
            )
            stop, stop_type, rr = select_best_stop(stops, bar['close'], atr, rr_desired)
            
            print(f"{ts.strftime('%H:%M')} | ENTRY {signal} @ {bar['close']:.2f} | {stop_type} Stop: {stop:.2f} | VF: {vol.vol_factor:.2f} [{vol.vol_state}] | R:R: {rr:.2f}")
            state.enter_position(signal, bar['close'], ts, stop)
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.5 hours old)
# AAPL Dec 19 - ORB: 272.79/271.57
# ...
# 10:18 | ENTRY SHORT @ 271.35 | ATR Stop: 271.98 | VF: 0.68 [LOW] | R:R: 1.50
# 10:32 | EXIT STOP-LOSS @ 271.98 | PnL: $-0.63 (-1.00R)

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import calc_swing_stop, calc_all_stops, calc_achievable_rr, calc_atr_rth
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df
df['atr'] = calc_atr_rth(df)

dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()].copy()

# Find bar index for 10:18
bar_idx = None
for i, (ts, bar) in enumerate(dec19.iterrows()):
    if ts.hour == 10 and ts.minute == 18:
        bar_idx = i
        entry = bar['close']
        atr = bar['atr']
        break

print(f"Bar index: {bar_idx}")
print(f"Entry: {entry}")
print(f"ATR: {atr:.4f}")

# Calculate swing stop for SHORT (is_long=False)
swing_stop = calc_swing_stop(dec19, bar_idx, is_long=False, atr=atr)
print(f"\nSwing Stop (for SHORT): {swing_stop:.2f}")

# What's the swing high it found?
swing_high = swing_stop - (atr * 0.02)  # reverse the buffer
print(f"Implied Swing High: {swing_high:.2f}")

# Show last 5 RTH bars before 10:18
print("\nLast 5 RTH bars before 10:18:")
count = 0
for j in range(1, 20):
    if bar_idx - j < 0:
        break
    bar_ts = dec19.index[bar_idx - j]
    mins = bar_ts.hour * 60 + bar_ts.minute
    if 9*60+30 <= mins < 16*60:
        high = dec19['high'].iloc[bar_idx - j]
        print(f"  {bar_ts.strftime('%H:%M')} high={high:.2f}")
        count += 1
        if count >= 5:
            break

# Now show all stops
stops = calc_all_stops(entry=entry, atr=atr, vwap=272.0, is_long=False, day_df=dec19, bar_idx=bar_idx)
print(f"\nAll stops:")
print(f"  ATR:   {stops['atr_stop']:.2f}")
print(f"  Swing: {stops['swing_stop']:.2f} (valid={stops['swing_valid']})")
print(f"  VWAP:  {stops['vwap_stop']:.2f} (valid={stops['vwap_valid']})")

# Calculate R:R for each
rr_desired = 2.5  # LOW vol
print(f"\nR:R calculations (rr_desired={rr_desired}):")
atr_rr = calc_achievable_rr(entry, stops['atr_stop'], atr, rr_desired)
swing_rr = calc_achievable_rr(entry, stops['swing_stop'], atr, rr_desired)
print(f"  ATR R:R:   {atr_rr:.3f}")
print(f"  Swing R:R: {swing_rr:.3f}")
print(f"\nPine shows: Swing @ 272 with R:R 1.53:1")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.6 hours old)
# Bar index: 180
# Entry: 271.35
# ATR: 0.3125
#
# Swing Stop (for SHORT): 272.00
# Implied Swing High: 271.99
#
# Last 5 RTH bars before 10:18:
#   10:17 high=271.86
#   10:16 high=271.99
#   10:15 high=271.92
#   10:14 high=271.83
#   10:13 high=271.64
#
# All stops:
#   ATR:   271.98
#   Swing: 272.00 (valid=True)
#   VWAP:  272.09 (valid=True)
#
# R:R calculations (rr_desired=2.5):
#   ATR R:R:   1.500
#   Swing R:R: 1.451
#
# Pine shows: Swing @ 272 with R:R 1.53:1

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import calc_atr_rth, calc_all_stops, select_best_stop, get_rr_for_vol_state
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df
df['atr'] = calc_atr_rth(df)

dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()].copy()

# Find 10:17 and 10:18
for ts, bar in dec19.iterrows():
    if ts.hour == 10 and ts.minute in [17, 18]:
        print(f"{ts.strftime('%H:%M')} ATR: {bar['atr']:.4f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.7 hours old)
# 10:17 ATR: 0.3032
# 10:18 ATR: 0.3066

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import calc_atr_rth
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df
df['atr'] = calc_atr_rth(df)

dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()].copy()

for ts, bar in dec19.iterrows():
    if ts.hour == 10 and ts.minute in [17, 18]:
        print(f"{ts.strftime('%H:%M')} ATR: {bar['atr']:.4f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.8 hours old)
# 10:17 ATR: 0.3032
# 10:18 ATR: 0.3066

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df

dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()].copy()

for ts, bar in dec19.iterrows():
    if ts.hour == 10 and ts.minute in [17, 18]:
        print(f"{ts.strftime('%H:%M')} atr_rth: {bar['atr_rth']:.4f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.8 hours old)
# 10:17 atr_rth: 0.2306
# 10:18 atr_rth: 0.2306

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df

# Filter to RTH
rth_mask = df.index.map(lambda x: 9*60+30 <= x.hour*60+x.minute < 16*60)
rth_df = df[rth_mask].copy()

# Show the last 20 RTH bars before 10:18
dec19_rth = rth_df[rth_df.index.date == pd.Timestamp('2025-12-19').date()]
bars_before_1018 = dec19_rth[dec19_rth.index <= pd.Timestamp('2025-12-19 10:18')]

print("Last 20 RTH bars:")
for ts, bar in bars_before_1018.tail(20).iterrows():
    print(f"{ts.strftime('%H:%M')} H={bar['high']:.2f} L={bar['low']:.2f} C={bar['close']:.2f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.0 hours old)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:559, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     558 try:
# --> 559     self._check_compatible_with(other)
#     560 except (TypeError, IncompatibleFrequency) as err:
#     561     # e.g. tzawareness mismatch
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:542, in DatetimeArray._check_compatible_with(self, other)
#     541     return
# --> 542 self._assert_tzawareness_compat(other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:788, in DatetimeArray._assert_tzawareness_compat(self, other)
#     787 elif other_tz is None:
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df

# Filter to RTH
rth_mask = df.index.map(lambda x: 9*60+30 <= x.hour*60+x.minute < 16*60)
rth_df = df[rth_mask].copy()

# Show Dec 19 RTH bars from 10:00 to 10:20
dec19_rth = rth_df[rth_df.index.date == pd.Timestamp('2025-12-19').date()]

print("RTH bars 10:00-10:20:")
for ts, bar in dec19_rth.iterrows():
    if 10*60 <= ts.hour*60+ts.minute <= 10*60+20:
        print(f"{ts.strftime('%H:%M')} H={bar['high']:.2f} L={bar['low']:.2f} C={bar['close']:.2f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.7 hours old)
# RTH bars 10:00-10:20:
# 10:00 H=272.18 L=271.65 C=271.88
# 10:01 H=271.90 L=271.48 C=271.69
# 10:02 H=271.70 L=271.54 C=271.55
# 10:03 H=271.73 L=271.36 C=271.45
# 10:04 H=271.47 L=271.11 C=271.40
# 10:05 H=271.45 L=271.21 C=271.28
# 10:06 H=271.30 L=271.11 C=271.24
# 10:07 H=271.31 L=270.96 C=270.97
# 10:08 H=271.23 L=270.95 C=271.23
# 10:09 H=271.53 L=271.20 C=271.51
# 10:10 H=271.57 L=271.33 C=271.52
# 10:11 H=271.68 L=271.45 C=271.59
# 10:12 H=271.66 L=271.45 C=271.55
# 10:13 H=271.64 L=271.44 C=271.46
# 10:14 H=271.83 L=271.34 C=271.83
# 10:15 H=271.92 L=271.75 C=271.88
# 10:16 H=271.99 L=271.77 C=271.85
# 10:17 H=271.86 L=271.51 C=271.67
# 10:18 H=271.66 L=271.28 C=271.35
# 10:19 H=271.62 L=271.26 C=271.59
# 10:20 H=271.71 L=271.55 C=271.68

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_backtester import ORBBacktester
import pandas as pd
import numpy as np

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df

# Filter to RTH only
rth_mask = df.index.map(lambda x: 9*60+30 <= x.hour*60+x.minute < 16*60)
rth_df = df[rth_mask].copy()

# True Range
rth_df['prev_close'] = rth_df['close'].shift(1)
rth_df['tr'] = pd.concat([
    rth_df['high'] - rth_df['low'],
    (rth_df['high'] - rth_df['prev_close']).abs(),
    (rth_df['low'] - rth_df['prev_close']).abs()
], axis=1).max(axis=1)

# Wilder RMA (ATR)
period = 14
rth_df['atr'] = rth_df['tr'].ewm(alpha=1/period, adjust=False).mean()

# Show Dec 19
dec19 = rth_df[rth_df.index.date == pd.Timestamp('2025-12-19').date()]
for ts, bar in dec19.iterrows():
    if ts.hour == 10 and ts.minute in [17, 18, 19]:
        print(f"{ts.strftime('%H:%M')} ATR: {bar['atr']:.4f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.7 hours old)
# 10:17 ATR: 0.3066
# 10:18 ATR: 0.3125
# 10:19 ATR: 0.3157

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_backtester import ORBBacktester
import pandas as pd
import numpy as np

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df

# Filter to RTH only
rth_mask = df.index.map(lambda x: 9*60+30 <= x.hour*60+x.minute < 16*60)
rth_df = df[rth_mask].copy()

# True Range
rth_df['prev_close'] = rth_df['close'].shift(1)
rth_df['tr'] = pd.concat([
    rth_df['high'] - rth_df['low'],
    (rth_df['high'] - rth_df['prev_close']).abs(),
    (rth_df['low'] - rth_df['prev_close']).abs()
], axis=1).max(axis=1)

# WMA (Weighted Moving Average)
period = 14
weights = np.arange(1, period + 1)  # 1, 2, 3, ... 14
rth_df['atr_wma'] = rth_df['tr'].rolling(period).apply(lambda x: np.sum(weights * x) / weights.sum(), raw=True)

# Show Dec 19
dec19 = rth_df[rth_df.index.date == pd.Timestamp('2025-12-19').date()]
for ts, bar in dec19.iterrows():
    if ts.hour == 10 and ts.minute in [17, 18, 19]:
        print(f"{ts.strftime('%H:%M')} ATR (WMA): {bar['atr_wma']:.4f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.8 hours old)
# 10:17 ATR (WMA): 0.2748
# 10:18 ATR (WMA): 0.2900
# 10:19 ATR (WMA): 0.3004

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import calc_atr_rth, calc_all_stops, select_best_stop
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df
df['atr'] = calc_atr_rth(df)

# At 10:18 entry SHORT @ 271.35
entry_ts = df[df.index.date == pd.Timestamp('2025-12-19').date()]
bar_1018 = entry_ts[entry_ts.index.map(lambda x: x.hour==10 and x.minute==18)].iloc[0]

print(f"ATR at 10:18: {bar_1018['atr']:.4f}")
print(f"Entry: 271.35 SHORT")

# ORB range
orb_high, orb_low = 272.79, 271.57

stops = calc_all_stops(
    entry_price=271.35,
    is_long=False,
    atr=bar_1018['atr'],
    orb_high=orb_high,
    orb_low=orb_low,
    day_df=entry_ts,
    bar_idx=180,
    vwap=None
)
print(f"\nStops: {stops}")

best = select_best_stop(stops, rr_desired=2.5, atr=bar_1018['atr'])
print(f"\nBest stop: {best}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.0 hours old)
# ATR at 10:18: 0.3066
# Entry: 271.35 SHORT
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 25
#      22 # ORB range
#      23 orb_high, orb_low = 272.79, 271.57
# ---> 25 stops = calc_all_stops(
#      26     entry_price=271.35,
#      27     is_long=False,
#      28     atr=bar_1018['atr'],
#      29     orb_high=orb_high,
#      30     orb_low=orb_low,
#      31     day_df=entry_ts,
#      32     bar_idx=180,
#      33     vwap=None
#      34 )
#      35 print(f"\nStops: {stops}")
#      37 best = select_best_stop(stops, rr_desired=2.5, atr=bar_1018['atr'])
#
# TypeError: calc_all_stops() got an unexpected keyword argument 'entry_price'

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_core
importlib.reload(orb_core)
from orb_core import calc_atr_rth, calc_all_stops, select_best_stop
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df
df['atr'] = calc_atr_rth(df)

# At 10:18 entry SHORT @ 271.35
entry_ts = df[df.index.date == pd.Timestamp('2025-12-19').date()]
bar_1018 = entry_ts[entry_ts.index.map(lambda x: x.hour==10 and x.minute==18)].iloc[0]

print(f"ATR at 10:18: {bar_1018['atr']:.4f}")
print(f"Entry: 271.35 SHORT")

stops = calc_all_stops(
    entry=271.35,
    is_long=False,
    atr=bar_1018['atr'],
    vwap=272.0,  # approximate
    day_df=entry_ts,
    bar_idx=48  # 10:18 is about 48 bars into RTH
)
print(f"\nStops: {stops}")

best = select_best_stop(stops, entry=271.35, atr=bar_1018['atr'], rr_desired=2.5)
print(f"\nBest stop: {best}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.0 hours old)
# ATR at 10:18: 0.3066
# Entry: 271.35 SHORT
#
# Stops: {'atr_stop': np.float64(271.96313216120006), 'swing_stop': np.float64(271.40613132161195), 'vwap_stop': np.float64(272.09196982418), 'swing_valid': np.True_, 'vwap_valid': np.True_}
#
# Best stop: (np.float64(271.40613132161195), 'SWING', 2.5)

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

if 'orb_core' in sys.modules:
    del sys.modules['orb_core']

from orb_core import calc_atr_rth, calc_all_stops, select_best_stop
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df
df['atr'] = calc_atr_rth(df)

# Get Dec 19 data
dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()].copy()

# Use 10:17's ATR (lagged) for 10:18 entry
bar_1017 = dec19[dec19.index.map(lambda x: x.hour==10 and x.minute==17)].iloc[0]
atr_lagged = bar_1017['atr']

print(f"ATR (lagged from 10:17): {atr_lagged:.4f}")
print(f"Entry: 271.35 SHORT")

# Find bar_idx for 10:18
for i, (ts, bar) in enumerate(dec19.iterrows()):
    if ts.hour == 10 and ts.minute == 18:
        bar_idx = i
        break

stops = calc_all_stops(
    entry=271.35,
    is_long=False,
    atr=atr_lagged,
    vwap=272.0,
    day_df=dec19,
    bar_idx=bar_idx
)
print(f"\nStops: {stops}")

best = select_best_stop(stops, entry=271.35, atr=atr_lagged, rr_desired=2.5)
print(f"\nBest stop: {best}")

# Manual R:R check for Swing @ 272
swing_stop = 272.0
risk = swing_stop - 271.35  # 0.65
target = 271.35 - (risk * 2.5)  # target for 2.5 R:R
print(f"\nManual check - Swing @ 272:")
print(f"  Risk: {risk:.2f}")
print(f"  Max target (3 ATR): {3 * atr_lagged:.4f}")
print(f"  Achievable R:R: {(3 * atr_lagged) / risk:.2f}")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.1 hours old)
# ATR (lagged from 10:17): 0.3032
# Entry: 271.35 SHORT
#
# Stops: {'atr_stop': np.float64(271.9564500197539), 'swing_stop': np.float64(271.99596450019754), 'vwap_stop': np.float64(272.0909675029631), 'swing_valid': np.True_, 'vwap_valid': np.True_}
#
# Best stop: (np.float64(271.9564500197539), 'ATR', np.float64(1.5000000000000249))
#
# Manual check - Swing @ 272:
#   Risk: 0.65
#   Max target (3 ATR): 0.9097
#   Achievable R:R: 1.40

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
from orb_backtester import ORBBacktester
import pandas as pd
import numpy as np

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df

# Filter to RTH only
rth_mask = df.index.map(lambda x: 9*60+30 <= x.hour*60+x.minute < 16*60)
rth_df = df[rth_mask].copy()

# True Range
rth_df['prev_close'] = rth_df['close'].shift(1)
rth_df['tr'] = pd.concat([
    rth_df['high'] - rth_df['low'],
    (rth_df['high'] - rth_df['prev_close']).abs(),
    (rth_df['low'] - rth_df['prev_close']).abs()
], axis=1).max(axis=1)

# WMA
period = 14
weights = np.arange(1, period + 1)
rth_df['atr_wma'] = rth_df['tr'].rolling(period).apply(lambda x: np.sum(weights * x) / weights.sum(), raw=True)

# Map back to full df
df['atr'] = np.nan
df.loc[rth_df.index, 'atr'] = rth_df['atr_wma']
df['atr'] = df['atr'].ffill()

# Now use 10:17's ATR for 10:18 entry (1-bar lag)
dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()].copy()
bar_1017 = dec19[dec19.index.map(lambda x: x.hour==10 and x.minute==17)].iloc[0]
atr_lagged = bar_1017['atr']

print(f"ATR (WMA, lagged from 10:17): {atr_lagged:.4f}")

# Manual R:R calc for Swing @ 272
entry = 271.35
swing_stop = 272.0
risk = swing_stop - entry
max_target_atr = 3.0
achievable_rr = (max_target_atr * atr_lagged) / risk

print(f"Entry: {entry} SHORT")
print(f"Swing Stop: {swing_stop}")
print(f"Risk: {risk:.2f}")
print(f"Achievable R:R: {achievable_rr:.2f}")
print(f"\nPine shows: Swing @ 272, R:R 1.64:1")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# ATR (WMA, lagged from 10:17): 0.2748
# Entry: 271.35 SHORT
# Swing Stop: 272.0
# Risk: 0.65
# Achievable R:R: 1.27
#
# Pine shows: Swing @ 272, R:R 1.64:1

# %%
# With 10:18's ATR (no lag)
atr_1018 = 0.2900  # WMA at 10:18
risk = 0.65
achievable_rr = (3.0 * atr_1018) / risk
print(f"R:R with 10:18 ATR (0.29): {achievable_rr:.2f}")

# What ATR would give 1.64 R:R?
target_rr = 1.64
needed_atr = (target_rr * risk) / 3.0
print(f"ATR needed for 1.64 R:R: {needed_atr:.4f}")
# Out:
# R:R with 10:18 ATR (0.29): 1.34
# ATR needed for 1.64 R:R: 0.3553

# %%
# Quick check - with RMA ATR = 0.3127, which stop wins?
entry = 271.35
atr = 0.3127

# ATR stop (for SHORT)
atr_stop = entry + (atr * 2.0)  # 271.35 + 0.625 = 271.975
atr_risk = atr_stop - entry  # 0.625

# Swing stop  
swing_stop = 272.0
swing_risk = swing_stop - entry  # 0.65

# R:R (capped at 3 ATR target)
atr_rr = (3.0 * atr) / atr_risk
swing_rr = (3.0 * atr) / swing_risk

print(f"ATR Stop: {atr_stop:.3f}, R:R: {atr_rr:.2f}")
print(f"Swing Stop: {swing_stop:.3f}, R:R: {swing_rr:.2f}")
print(f"Winner: {'ATR' if atr_rr > swing_rr else 'SWING'}")
# Out:
# ATR Stop: 271.975, R:R: 1.50
# Swing Stop: 272.000, R:R: 1.44
# Winner: ATR

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

# Force fresh import
if 'orb_core' in sys.modules:
    del sys.modules['orb_core']

from orb_core import calc_atr_rth
from orb_backtester import ORBBacktester
import pandas as pd

bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df
df['atr'] = calc_atr_rth(df)

# Show 10:17, 10:18, 10:19
dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()]
for ts, bar in dec19.iterrows():
    if ts.hour == 10 and ts.minute in [17, 18, 19]:
        print(f"{ts.strftime('%H:%M')} ATR (RMA): {bar['atr']:.4f}")

print("\nCompare to your standalone ATR indicator (RMA mode) on RTH chart")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.7 hours old)
# 10:17 ATR (RMA): 0.3066
# 10:18 ATR (RMA): 0.3125
# 10:19 ATR (RMA): 0.3157
#
# Compare to your standalone ATR indicator (RMA mode) on RTH chart

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import pandas as pd
from orb_backtester import ORBBacktester
from orb_core import calc_atr_rth, calc_all_stops, select_best_stop

# Load data
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df

dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()]

# Find 10:18 bar (the entry we're debugging)
entry_time = pd.Timestamp('2025-12-19 10:18', tz='US/Eastern')
bar_idx = dec19.index.get_loc(entry_time)
bar = dec19.iloc[bar_idx]

# Get ATR at entry
atr_series = calc_atr_rth(df, period=14)
atr = atr_series.loc[entry_time]
atr_lagged = atr_series.shift(1).loc[entry_time]  # Pine 1-bar lag

# Get VWAP
vwap = bar['vwap']

# Assume LONG entry at close
entry_price = bar['close']
is_long = True

print(f"=== AAPL Dec 19 @ 10:18 ===")
print(f"Entry: {entry_price:.2f}")
print(f"ATR (current): {atr:.4f}")
print(f"ATR (lagged): {atr_lagged:.4f}")
print(f"VWAP: {vwap:.2f}")
print()

# Calculate all stops
stops = calc_all_stops(
    entry=entry_price, 
    atr=atr_lagged,  # Use lagged to match Pine
    vwap=vwap, 
    is_long=is_long,
    day_df=dec19, 
    bar_idx=bar_idx
)

print(f"ATR Stop: {stops['atr_stop']:.2f}")
print(f"Swing Stop: {stops['swing_stop']:.2f} (valid={stops['swing_valid']})")
print(f"VWAP Stop: {stops['vwap_stop']:.2f} (valid={stops['vwap_valid']})")
print()

# Select best
stop_price, stop_type, rr = select_best_stop(stops, entry_price, atr_lagged, rr_desired=2.0)
print(f"SELECTED: {stop_type} @ {stop_price:.2f} (R:R = {rr:.2f})")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.1 hours old)
# === AAPL Dec 19 @ 10:18 ===
# Entry: 271.35
# ATR (current): 0.3125
# ATR (lagged): 0.3066
# VWAP: 272.14
#
# ATR Stop: 270.74
# Swing Stop: 270.74 (valid=False)
# VWAP Stop: 270.74 (valid=False)
#
# SELECTED: ATR @ 270.74 (R:R = 1.50)

# %%
"""
Test Dec 19 AAPL SHORT stop calculation
Compare Python to Pine debug output
"""
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import pandas as pd
from orb_backtester import ORBBacktester
from orb_core import calc_atr_rth, calc_all_stops, select_best_stop, calc_swing_stop

# Load data
bt = ORBBacktester(symbol='AAPL', start_date='2025-12-19', end_date='2025-12-19', verbose=False)
bt.load_data()
df = bt.df

dec19 = df[df.index.date == pd.Timestamp('2025-12-19').date()]

# Find entry bar - the SHORT was at 271.35
# Check 10:18 and 10:19 to find the right bar
for check_time in ['10:18', '10:19']:
    ts = pd.Timestamp(f'2025-12-19 {check_time}', tz='US/Eastern')
    if ts in dec19.index:
        bar = dec19.loc[ts]
        print(f"{check_time}: O={bar['open']:.2f} H={bar['high']:.2f} L={bar['low']:.2f} C={bar['close']:.2f}")

print()

# Use 10:18 (entry at 271.35)
entry_time = pd.Timestamp('2025-12-19 10:18', tz='US/Eastern')
bar_idx = dec19.index.get_loc(entry_time)
bar = dec19.iloc[bar_idx]

# Get ATR - use lagged like Pine does
atr_series = calc_atr_rth(df, period=14)
atr_current = atr_series.loc[entry_time]
atr_lagged = atr_series.shift(1).loc[entry_time]

# Get VWAP
vwap = bar['vwap']

# SHORT entry at close
entry_price = bar['close']
is_long = False  # SHORT!

print(f"=== AAPL Dec 19 SHORT @ 10:18 ===")
print(f"Entry: {entry_price:.2f}")
print(f"ATR (current): {atr_current:.4f}")
print(f"ATR (lagged): {atr_lagged:.4f}")
print(f"VWAP: {vwap:.2f}")
print()

# Calculate swing high for SHORT
swing_val = calc_swing_stop(dec19, bar_idx, is_long=False, atr=atr_lagged, swing_lookback=5, swing_buffer=0.02)
print(f"Swing Stop (from calc_swing_stop): {swing_val:.2f}")

# Show the RTH bars used for swing calculation
print(f"\nRTH bars used for swing high (lookback=5):")
valid_bars = 0
for j in range(1, 16):
    if bar_idx - j < 0:
        break
    bar_ts = dec19.index[bar_idx - j]
    mins = bar_ts.hour * 60 + bar_ts.minute
    is_rth = 9*60+30 <= mins < 16*60
    if is_rth:
        bar_high = dec19['high'].iloc[bar_idx - j]
        valid_bars += 1
        marker = " <-- used" if valid_bars <= 5 else ""
        print(f"  {bar_ts.strftime('%H:%M')} H={bar_high:.2f}{marker}")
        if valid_bars >= 5:
            break

print()

# Calculate all stops
stops = calc_all_stops(
    entry=entry_price, 
    atr=atr_lagged,
    vwap=vwap, 
    is_long=is_long,  # SHORT
    day_df=dec19, 
    bar_idx=bar_idx
)

print(f"=== STOP VALUES ===")
print(f"ATR Stop: {stops['atr_stop']:.2f}")
print(f"Swing Stop: {stops['swing_stop']:.2f} (valid={stops['swing_valid']})")
print(f"VWAP Stop: {stops['vwap_stop']:.2f} (valid={stops['vwap_valid']})")
print()

# Validity check details
min_stop_dist = atr_lagged * 0.15
print(f"=== VALIDITY CHECK ===")
print(f"minStopDist = ATR * 0.15 = {atr_lagged:.4f} * 0.15 = {min_stop_dist:.4f}")
print(f"For SHORT, swing valid if: swingStop > entry + minStopDist")
print(f"  {stops['swing_stop']:.2f} > {entry_price:.2f} + {min_stop_dist:.4f} = {entry_price + min_stop_dist:.2f}")
print(f"  Result: {stops['swing_stop']:.2f} > {entry_price + min_stop_dist:.2f} = {stops['swing_valid']}")
print()

# Select best
stop_price, stop_type, rr = select_best_stop(stops, entry_price, atr_lagged, rr_desired=2.0)
print(f"=== SELECTED ===")
print(f"Type: {stop_type}")
print(f"Stop: {stop_price:.2f}")
print(f"R:R: {rr:.2f}")
print()

# Compare to Pine
print(f"=== PINE VALUES (from debug) ===")
print(f"Entry: 271.59 (10:19)")
print(f"ATR (lagged): 0.3155")
print(f"SwingLow: 271.28")  
print(f"Swing Stop: 271.27")
print(f"swingValid: true")
print(f"Selected: SWING @ 271.27, R:R 2.0")
# Out:
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.5 hours old)
# 10:18: O=271.65 H=271.66 L=271.28 C=271.35
# 10:19: O=271.32 H=271.62 L=271.26 C=271.59
#
# === AAPL Dec 19 SHORT @ 10:18 ===
# Entry: 271.35
# ATR (current): 0.3125
# ATR (lagged): 0.3066
# VWAP: 272.14
#
# Swing Stop (from calc_swing_stop): 272.00
#
# RTH bars used for swing high (lookback=5):
#   10:17 H=271.86 <-- used
#   10:16 H=271.99 <-- used
#   10:15 H=271.92 <-- used
#   10:14 H=271.83 <-- used
#   10:13 H=271.64 <-- used
#
# === STOP VALUES ===
# ATR Stop: 271.96
# Swing Stop: 272.00 (valid=True)
# VWAP Stop: 272.23 (valid=True)
#
# === VALIDITY CHECK ===
# minStopDist = ATR * 0.15 = 0.3066 * 0.15 = 0.0460
# For SHORT, swing valid if: swingStop > entry + minStopDist
#   272.00 > 271.35 + 0.0460 = 271.40
#   Result: 272.00 > 271.40 = True
#
# === SELECTED ===
# Type: ATR
# Stop: 271.96
# R:R: 1.50
#
# ...

# %%
df.head()
df.tail()
df.index.tz
df.between_time("09:30", "09:34").head()
# Out:
#                               open    high     low    close    volume  \
# timestamp
# 2025-07-17 09:30:00-04:00  210.570  210.91  210.45  210.800  930051.0
# 2025-07-17 09:31:00-04:00  210.810  210.85  210.46  210.625  225982.0
# 2025-07-17 09:32:00-04:00  210.610  210.92  210.34  210.730  197495.0
# 2025-07-17 09:33:00-04:00  210.730  210.74  210.25  210.290  131806.0
# 2025-07-17 09:34:00-04:00  210.279  210.57  210.06  210.530  275404.0
#
#                                  vwap  trades    tr  is_rth   std_atr  ...  \
# timestamp                                                              ...
# 2025-07-17 09:30:00-04:00  210.720000   10732  0.46    True  0.204015  ...
# 2025-07-17 09:31:00-04:00  210.705339    3407  0.39    True  0.217300  ...
# 2025-07-17 09:32:00-04:00  210.699210    2806  0.58    True  0.243207  ...
# 2025-07-17 09:33:00-04:00  210.675025    2082  0.49    True  0.260835  ...
# 2025-07-17 09:34:00-04:00  210.629922    4135  0.51    True  0.278632  ...
#
# ...

# %%
import pandas as pd
import numpy as np

from stop_engine import StopState
from trade_stop_manager import TradeStopManager

# --- Synthetic intraday dataframe ---
idx = pd.date_range(
    "2025-01-07 09:30",
    periods=40,
    freq="1min",
    tz="US/Eastern",
)

np.random.seed(42)

df = pd.DataFrame(
    {
        "open": 100 + np.random.randn(len(idx)) * 0.2,
        "high": 100.5 + np.random.randn(len(idx)) * 0.2,
        "low": 99.5 + np.random.randn(len(idx)) * 0.2,
        "close": 100 + np.random.randn(len(idx)) * 0.2,
        "vwap": 100 + np.random.randn(len(idx)) * 0.1,
    },
    index=idx,
)

# --- Simulated entry context ---
entry_price = 100.00
atr = 1.00
direction = "LONG"
rr_desired = 2.0
entry_bar_idx = 10
vwap = df["vwap"].iloc[entry_bar_idx]

# --- Initialize manager ---
mgr = TradeStopManager(stop_state=StopState())

mgr.enter_trade(
    direction=direction,
    entry_price=entry_price,
    atr=atr,
    rr_desired=rr_desired,
    day_df=df,
    bar_idx=entry_bar_idx,
    vwap=vwap,
)

print("Stop type selected:", mgr.stop_type)
print("Achievable RR:", round(mgr.achievable_rr, 2))
print("Initial stop:", mgr.stop_state.current_stop)

# --- Walk bars forward ---
for i in range(entry_bar_idx + 1, len(df)):
    bar = df.iloc[i]

    should_exit, reason, px = mgr.process_bar(
        bar_high=bar["high"],
        bar_low=bar["low"],
        break_even_rr=0.5,
    )

    if should_exit:
        print(f"EXIT @ bar {i} ({df.index[i]})")
        print("  Reason:", reason)
        print("  Exit price:", px)
        break
else:
    print("Trade still open at end of data")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       1 import pandas as pd
#       2 import numpy as np
# ----> 4 from stop_engine import StopState
#       5 from trade_stop_manager import TradeStopManager
#       7 # --- Synthetic intraday dataframe ---
#
# ModuleNotFoundError: No module named 'stop_engine'
