# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from Orb_Optimizer_Final import PhasedOptimizer
print("✓ Import successful")
# Out:
# ✓ Import successful

# %%
# Phase 1 - Exit Geometry
# Confluence OFF, testing trade management with all breakouts
# ~30-45 minutes for 200 trials

opt = PhasedOptimizer(
    symbol='AMD',
    phase=1,
    n_trials=200,
    verbose=True
)

print("🚀 Starting Phase 1: Exit Geometry")
print("   This will take 30-45 minutes...")
print("   Open Optuna Dashboard to watch progress")
print()

results = opt.run()
# Out:
# 🚀 Starting Phase 1: Exit Geometry
#    This will take 30-45 minutes...
#    Open Optuna Dashboard to watch progress
#
#
# ======================================================================
#   ORB PHASED OPTIMIZER v3: AMD
#   Phase 1: Exit Geometry
# ======================================================================
#
#   Trade management foundation - how we exit
#
#   Training: 2025-08-29 to 2025-11-15
#   Testing:  2025-11-16 to 2026-01-27
#   Trials:   200
#   Objective: robust
#   Min Trades: 30
#
#   Searching 16 params:
#     • break_even_rr
#     • profit_target_rr
#     • trailing_stop_distance
#     • ema_tighten_zone
#     • tightened_trail_distance
#     • ema_confirmation_bars
#     • atr_stop_mult
#     • min_stop_atr
#     • swing_lookback
#     • min_acceptable_rr
#     • ema_period
#     • vwap_stop_distance
#     • max_target_atr
#     • breakout_threshold_mult
#     • min_body_strength
#     • trading_end_minutes
#
#   Fixed from previous phases: 9 params
#
# ──────────────────────────────────────────────────────────────────────
#   OPTIMIZATION IN PROGRESS...
# ──────────────────────────────────────────────────────────────────────
# [I 2026-02-05 18:49:13,117] A new study created in RDB with name: ORB_AMD_phase1_v3
#   0%|          | 0/200 [00:00<?, ?it/s]
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ⚠ Cache stale (23 hours), refreshing...
#   ✓ Fetched 101362 bars, cached for next time
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:49:36,143] Trial 0 finished with value: -6.047416775896091 and parameters: {'break_even_rr': 0.5, 'profit_target_rr': 3.0, 'trailing_stop_distance': 1.7000000000000002, 'ema_tighten_zone': 0.4, 'tightened_trail_distance': 0.25, 'ema_confirmation_bars': 1, 'atr_stop_mult': 1.5, 'min_stop_atr': 0.25, 'swing_lookback': 6, 'min_acceptable_rr': 1.75, 'ema_period': 7, 'vwap_stop_distance': 0.5, 'max_target_atr': 3.75, 'breakout_threshold_mult': 0.07500000000000001, 'min_body_strength': 0.3, 'trading_end_minutes': 615}. Best is trial 0 with value: -6.047416775896091.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:49:54,361] Trial 1 finished with value: -2.557830881858995 and parameters: {'break_even_rr': 0.4, 'profit_target_rr': 2.25, 'trailing_stop_distance': 1.3, 'ema_tighten_zone': 0.30000000000000004, 'tightened_trail_distance': 0.4, 'ema_confirmation_bars': 1, 'atr_stop_mult': 2.0, 'min_stop_atr': 0.15000000000000002, 'swing_lookback': 5, 'min_acceptable_rr': 1.75, 'ema_period': 8, 'vwap_stop_distance': 0.35000000000000003, 'max_target_atr': 3.5, 'breakout_threshold_mult': 0.05, 'min_body_strength': 0.6000000000000001, 'trading_end_minutes': 615}. Best is trial 1 with value: -2.557830881858995.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:50:11,930] Trial 2 finished with value: -inf and parameters: {'break_even_rr': 0.3, 'profit_target_rr': 3.0, 'trailing_stop_distance': 2.0, 'ema_tighten_zone': 0.45, 'tightened_trail_distance': 0.30000000000000004, 'ema_confirmation_bars': 1, 'atr_stop_mult': 2.5, 'min_stop_atr': 0.15000000000000002, 'swing_lookback': 3, 'min_acceptable_rr': 1.5, 'ema_period': 7, 'vwap_stop_distance': 0.5, 'max_target_atr': 2.75, 'breakout_threshold_mult': 0.125, 'min_body_strength': 0.4, 'trading_end_minutes': 645}. Best is trial 1 with value: -2.557830881858995.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:50:30,846] Trial 3 finished with value: -0.2116791883025112 and parameters: {'break_even_rr': 0.6000000000000001, 'profit_target_rr': 1.75, 'trailing_stop_distance': 2.0, 'ema_tighten_zone': 0.45, 'tightened_trail_distance': 0.5, 'ema_confirmation_bars': 3, 'atr_stop_mult': 2.5, 'min_stop_atr': 0.25, 'swing_lookback': 3, 'min_acceptable_rr': 1.0, 'ema_period': 7, 'vwap_stop_distance': 0.30000000000000004, 'max_target_atr': 3.0, 'breakout_threshold_mult': 0.07500000000000001, 'min_body_strength': 0.7, 'trading_end_minutes': 630}. Best is trial 3 with value: -0.2116791883025112.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:50:40,391] Trial 4 finished with value: -inf and parameters: {'break_even_rr': 0.4, 'profit_target_rr': 2.25, 'trailing_stop_distance': 0.9, 'ema_tighten_zone': 0.45, 'tightened_trail_distance': 0.2, 'ema_confirmation_bars': 3, 'atr_stop_mult': 2.75, 'min_stop_atr': 0.1, 'swing_lookback': 3, 'min_acceptable_rr': 2.0, 'ema_period': 11, 'vwap_stop_distance': 0.45, 'max_target_atr': 3.75, 'breakout_threshold_mult': 0.05, 'min_body_strength': 0.4, 'trading_end_minutes': 600}. Best is trial 3 with value: -0.2116791883025112.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:50:57,698] Trial 5 finished with value: -inf and parameters: {'break_even_rr': 0.8, 'profit_target_rr': 2.5, 'trailing_stop_distance': 1.2000000000000002, 'ema_tighten_zone': 0.2, 'tightened_trail_distance': 0.30000000000000004, 'ema_confirmation_bars': 1, 'atr_stop_mult': 2.75, 'min_stop_atr': 0.2, 'swing_lookback': 7, 'min_acceptable_rr': 1.5, 'ema_period': 7, 'vwap_stop_distance': 0.4, 'max_target_atr': 3.75, 'breakout_threshold_mult': 0.1, 'min_body_strength': 0.6000000000000001, 'trading_end_minutes': 645}. Best is trial 3 with value: -0.2116791883025112.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:51:15,197] Trial 6 finished with value: -1.428501883744162 and parameters: {'break_even_rr': 0.6000000000000001, 'profit_target_rr': 2.0, 'trailing_stop_distance': 0.8, 'ema_tighten_zone': 0.2, 'tightened_trail_distance': 0.2, 'ema_confirmation_bars': 2, 'atr_stop_mult': 2.0, 'min_stop_atr': 0.2, 'swing_lookback': 7, 'min_acceptable_rr': 1.25, 'ema_period': 9, 'vwap_stop_distance': 0.45, 'max_target_atr': 2.75, 'breakout_threshold_mult': 0.05, 'min_body_strength': 0.4, 'trading_end_minutes': 615}. Best is trial 3 with value: -0.2116791883025112.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:51:24,299] Trial 7 finished with value: -inf and parameters: {'break_even_rr': 0.8, 'profit_target_rr': 2.75, 'trailing_stop_distance': 1.6, 'ema_tighten_zone': 0.5, 'tightened_trail_distance': 0.45, 'ema_confirmation_bars': 1, 'atr_stop_mult': 3.0, 'min_stop_atr': 0.2, 'swing_lookback': 7, 'min_acceptable_rr': 2.0, 'ema_period': 8, 'vwap_stop_distance': 0.2, 'max_target_atr': 2.75, 'breakout_threshold_mult': 0.1, 'min_body_strength': 0.7, 'trading_end_minutes': 690}. Best is trial 3 with value: -0.2116791883025112.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:51:42,362] Trial 8 finished with value: -inf and parameters: {'break_even_rr': 0.3, 'profit_target_rr': 2.25, 'trailing_stop_distance': 1.3, 'ema_tighten_zone': 0.25, 'tightened_trail_distance': 0.2, 'ema_confirmation_bars': 2, 'atr_stop_mult': 3.0, 'min_stop_atr': 0.15000000000000002, 'swing_lookback': 5, 'min_acceptable_rr': 1.75, 'ema_period': 9, 'vwap_stop_distance': 0.5, 'max_target_atr': 4.0, 'breakout_threshold_mult': 0.07500000000000001, 'min_body_strength': 0.5, 'trading_end_minutes': 630}. Best is trial 3 with value: -0.2116791883025112.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:52:01,317] Trial 9 finished with value: -inf and parameters: {'break_even_rr': 0.4, 'profit_target_rr': 1.5, 'trailing_stop_distance': 1.5, 'ema_tighten_zone': 0.35000000000000003, 'tightened_trail_distance': 0.2, 'ema_confirmation_bars': 1, 'atr_stop_mult': 3.0, 'min_stop_atr': 0.1, 'swing_lookback': 3, 'min_acceptable_rr': 1.5, 'ema_period': 12, 'vwap_stop_distance': 0.25, 'max_target_atr': 3.5, 'breakout_threshold_mult': 0.125, 'min_body_strength': 0.4, 'trading_end_minutes': 675}. Best is trial 3 with value: -0.2116791883025112.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:52:18,397] Trial 10 finished with value: -1.033641958507964 and parameters: {'break_even_rr': 0.6000000000000001, 'profit_target_rr': 1.5, 'trailing_stop_distance': 2.0, 'ema_tighten_zone': 0.5, 'tightened_trail_distance': 0.5, 'ema_confirmation_bars': 3, 'atr_stop_mult': 2.25, 'min_stop_atr': 0.25, 'swing_lookback': 4, 'min_acceptable_rr': 1.0, 'ema_period': 10, 'vwap_stop_distance': 0.30000000000000004, 'max_target_atr': 3.0, 'breakout_threshold_mult': 0.15, 'min_body_strength': 0.7, 'trading_end_minutes': 660}. Best is trial 3 with value: -0.2116791883025112.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:52:35,476] Trial 11 finished with value: -1.033641958507964 and parameters: {'break_even_rr': 0.6000000000000001, 'profit_target_rr': 1.5, 'trailing_stop_distance': 2.0, 'ema_tighten_zone': 0.5, 'tightened_trail_distance': 0.5, 'ema_confirmation_bars': 3, 'atr_stop_mult': 2.25, 'min_stop_atr': 0.25, 'swing_lookback': 4, 'min_acceptable_rr': 1.0, 'ema_period': 10, 'vwap_stop_distance': 0.30000000000000004, 'max_target_atr': 3.0, 'breakout_threshold_mult': 0.15, 'min_body_strength': 0.7, 'trading_end_minutes': 660}. Best is trial 3 with value: -0.2116791883025112.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:52:53,477] Trial 12 finished with value: -0.23846523969562536 and parameters: {'break_even_rr': 0.7, 'profit_target_rr': 1.75, 'trailing_stop_distance': 1.8, 'ema_tighten_zone': 0.4, 'tightened_trail_distance': 0.5, 'ema_confirmation_bars': 3, 'atr_stop_mult': 2.25, 'min_stop_atr': 0.25, 'swing_lookback': 4, 'min_acceptable_rr': 1.0, 'ema_period': 10, 'vwap_stop_distance': 0.30000000000000004, 'max_target_atr': 3.25, 'breakout_threshold_mult': 0.15, 'min_body_strength': 0.7, 'trading_end_minutes': 660}. Best is trial 3 with value: -0.2116791883025112.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:53:11,297] Trial 13 finished with value: -3.816258800059157 and parameters: {'break_even_rr': 0.7, 'profit_target_rr': 1.75, 'trailing_stop_distance': 1.8, 'ema_tighten_zone': 0.4, 'tightened_trail_distance': 0.4, 'ema_confirmation_bars': 3, 'atr_stop_mult': 2.0, 'min_stop_atr': 0.25, 'swing_lookback': 4, 'min_acceptable_rr': 1.25, 'ema_period': 11, 'vwap_stop_distance': 0.30000000000000004, 'max_target_atr': 3.25, 'breakout_threshold_mult': 0.07500000000000001, 'min_body_strength': 0.6000000000000001, 'trading_end_minutes': 660}. Best is trial 3 with value: -0.2116791883025112.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:53:28,206] Trial 14 finished with value: 0.1858868248348649 and parameters: {'break_even_rr': 0.7, 'profit_target_rr': 1.75, 'trailing_stop_distance': 1.8, 'ema_tighten_zone': 0.4, 'tightened_trail_distance': 0.45, 'ema_confirmation_bars': 2, 'atr_stop_mult': 2.5, 'min_stop_atr': 0.25, 'swing_lookback': 4, 'min_acceptable_rr': 1.0, 'ema_period': 8, 'vwap_stop_distance': 0.2, 'max_target_atr': 2.5, 'breakout_threshold_mult': 0.125, 'min_body_strength': 0.7, 'trading_end_minutes': 630}. Best is trial 14 with value: 0.1858868248348649.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:53:45,891] Trial 15 finished with value: -inf and parameters: {'break_even_rr': 0.7, 'profit_target_rr': 2.0, 'trailing_stop_distance': 1.8, 'ema_tighten_zone': 0.35000000000000003, 'tightened_trail_distance': 0.45, 'ema_confirmation_bars': 2, 'atr_stop_mult': 2.5, 'min_stop_atr': 0.2, 'swing_lookback': 3, 'min_acceptable_rr': 1.25, 'ema_period': 8, 'vwap_stop_distance': 0.2, 'max_target_atr': 2.5, 'breakout_threshold_mult': 0.125, 'min_body_strength': 0.6000000000000001, 'trading_end_minutes': 630}. Best is trial 14 with value: 0.1858868248348649.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:54:03,620] Trial 16 finished with value: -3.644074734166289 and parameters: {'break_even_rr': 0.5, 'profit_target_rr': 1.75, 'trailing_stop_distance': 1.9000000000000001, 'ema_tighten_zone': 0.45, 'tightened_trail_distance': 0.4, 'ema_confirmation_bars': 2, 'atr_stop_mult': 2.5, 'min_stop_atr': 0.25, 'swing_lookback': 4, 'min_acceptable_rr': 1.0, 'ema_period': 8, 'vwap_stop_distance': 0.25, 'max_target_atr': 2.5, 'breakout_threshold_mult': 0.1, 'min_body_strength': 0.5, 'trading_end_minutes': 630}. Best is trial 14 with value: 0.1858868248348649.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:54:20,562] Trial 17 finished with value: -inf and parameters: {'break_even_rr': 0.7, 'profit_target_rr': 2.0, 'trailing_stop_distance': 1.6, 'ema_tighten_zone': 0.30000000000000004, 'tightened_trail_distance': 0.45, 'ema_confirmation_bars': 2, 'atr_stop_mult': 1.75, 'min_stop_atr': 0.2, 'swing_lookback': 5, 'min_acceptable_rr': 1.25, 'ema_period': 7, 'vwap_stop_distance': 0.25, 'max_target_atr': 3.0, 'breakout_threshold_mult': 0.07500000000000001, 'min_body_strength': 0.7, 'trading_end_minutes': 600}. Best is trial 14 with value: 0.1858868248348649.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-05 18:54:37,843] Trial 18 finished with value: -inf and parameters: {'break_even_rr': 0.8, 'profit_target_rr': 1.75, 'trailing_stop_distance': 1
and parameters: {'break_even_rr': 0.6000000000000001, 'profit_target_rr': 3.0, 'trailing_stop_distance': 0.9, 'ema_tighten_zone': 0.35000000000000003, 'tightened_trail_distance': 0.5, 'ema_confirmation_bars': 2, 'atr_stop_mult': 2.75, 'min_stop_atr': 0.1, 'swing_lookback': 4, 'min_acceptable_rr': 1.0, 'ema_period': 12, 'vwap_stop_distance': 0.25, 'max_target_atr': 4.0, 'breakout_threshold_mult': 0.07500000000000001, 'min_body_strength': 0.7, 'trading_end_minutes': 615}. Best is trial 139 with value: 0.8688045277766372.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.9 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.9 hours old)
# [I 2026-02-05 19:44:35,068] Trial 199 finished with value: 0.8688045277766372 and parameters: {'break_even_rr': 0.6000000000000001, 'profit_target_rr': 3.0, 'trailing_stop_distance': 1.0, 'ema_tighten_zone': 0.35000000000000003, 'tightened_trail_distance': 0.5, 'ema_confirmation_bars': 2, 'atr_stop_mult': 2.75, 'min_stop_atr': 0.1, 'swing_lookback': 4, 'min_acceptable_rr': 1.0, 'ema_period': 10, 'vwap_stop_distance': 0.25, 'max_target_atr': 4.0, 'breakout_threshold_mult': 0.07500000000000001, 'min_body_strength': 0.7, 'trading_end_minutes': 615}. Best is trial 139 with value: 0.8688045277766372.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.9 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.9 hours old)
#
# ──────────────────────────────────────────────────────────────────────
#   PHASE 1 COMPLETE: Exit Geometry
# ──────────────────────────────────────────────────────────────────────
#
#   Best robust score: 0.8688
#
#   Best parameters found:
#     atr_stop_mult: 2.75
#     break_even_rr: 0.6000000000000001
#     breakout_threshold_mult: 0.07500000000000001
#     ema_confirmation_bars: 2
#     ema_period: 10
#     ema_tighten_zone: 0.35000000000000003
#     max_target_atr: 4.0
#     min_acceptable_rr: 1.0
#     min_body_strength: 0.7
#     min_stop_atr: 0.1
#     profit_target_rr: 3.0
#     swing_lookback: 4
#     tightened_trail_distance: 0.5
#     trading_end_minutes: 615
#     trailing_stop_distance: 1.0
#     vwap_stop_distance: 0.25
#
#   Metric                   Training      Testing
#   --------------------------------------------
#   Total Trades                   45           38
#   Win Rate                    57.9%        58.6%
#   Total R                    +11.70        +6.49
#   Avg R/Trade                +0.260       +0.171
#   Profit Factor                1.67         1.65
#   Max Drawdown                 4.40         2.60
#
#   ✓ Results saved to: C:\Users\phemm\orb_lab\results\AMD_phase1.json
#
#   Next: Review results, then run Phase 2
#
# ======================================================================

# %%
from Orb_Optimizer_Final import PhasedOptimizer

opt = PhasedOptimizer(symbol='AMD', phase=2, n_trials=200)
results = opt.run()
# Out:
# [I 2026-02-05 20:14:48,654] A new study created in RDB with name: ORB_AMD_phase2_v3
# ======================================================================
#   ORB PHASED OPTIMIZER v3: AMD
#   Phase 2: Volatility Regime
# ======================================================================
#
#   When to adjust behavior by market conditions
#
#   Training: 2025-08-29 to 2025-11-15
#   Testing:  2025-11-16 to 2026-01-27
#   Trials:   200
#   Objective: robust
#   Min Trades: 30
#
#   Searching 5 params:
#     • low_vol_threshold
#     • high_vol_threshold
#     • extreme_vol_threshold
#     • skip_low_vol_c_grades
#     • low_vol_min_rr
#
#   Fixed from previous phases: 24 params
#
# ──────────────────────────────────────────────────────────────────────
#   OPTIMIZATION IN PROGRESS...
# ──────────────────────────────────────────────────────────────────────
#   0%|          | 0/200 [00:00<?, ?it/s]
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.4 hours old)
# [I 2026-02-05 20:15:05,809] Trial 0 finished with value: 0.4138721905803816 and parameters: {'low_vol_threshold': 0.7, 'high_vol_threshold': 1.5, 'extreme_vol_threshold': 2.3, 'skip_low_vol_c_grades': True, 'low_vol_min_rr': 1.5}. Best is trial 0 with value: 0.4138721905803816.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.4 hours old)
# [I 2026-02-05 20:15:23,039] Trial 1 finished with value: 0.8688045277766372 and parameters: {'low_vol_threshold': 0.6, 'high_vol_threshold': 1.5, 'extreme_vol_threshold': 2.2, 'skip_low_vol_c_grades': True, 'low_vol_min_rr': 2.5}. Best is trial 1 with value: 0.8688045277766372.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.4 hours old)
# [I 2026-02-05 20:15:39,899] Trial 2 finished with value: 0.8688045277766372 and parameters: {'low_vol_threshold': 0.9, 'high_vol_threshold': 1.2000000000000002, 'extreme_vol_threshold': 1.9000000000000001, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.0}. Best is trial 1 with value: 0.8688045277766372.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.4 hours old)
# [I 2026-02-05 20
finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 2.5, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:02:11,863] Trial 177 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.9, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 2.4000000000000004, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:02:26,978] Trial 178 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 2.3, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.25}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:02:41,943] Trial 179 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 2.5, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:02:57,035] Trial 180 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 2.2, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.0}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:03:12,356] Trial 181 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.8, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:03:27,517] Trial 182 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.8, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:03:42,644] Trial 183 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.8, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:03:57,805] Trial 184 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.8, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:04:12,781] Trial 185 finished with value: 0.48635431859881995 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.8, 'skip_low_vol_c_grades': True, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:04:27,823] Trial 186 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 2.5, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:04:42,860] Trial 187 finished with value: 0.8688045277766372 and parameters: {'low_vol_threshold': 0.6, 'high_vol_threshold': 1.5, 'extreme_vol_threshold': 2.5, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:04:58,067] Trial 188 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.9, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 2.4000000000000004, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:05:13,471] Trial 189 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 2.3, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.25}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:05:29,158] Trial 190 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.7, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 2.5, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:05:44,542] Trial 191 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.9000000000000001, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:06:00,150] Trial 192 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.8, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:06:15,516] Trial 193 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.8, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:06:30,716] Trial 194 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.8, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:06:45,839] Trial 195 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.9000000000000001, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:07:00,793] Trial 196 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.8, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 1.75}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-05 21:07:15,896] Trial 197 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 1.9000000000000001, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 1.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [I 2026-02-05 21:07:30,786] Trial 198 finished with value: 0.48635431859881995 and parameters: {'low_vol_threshold': 0.8, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 2.5, 'skip_low_vol_c_grades': True, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [I 2026-02-05 21:07:45,690] Trial 199 finished with value: 0.8840586079979122 and parameters: {'low_vol_threshold': 0.9, 'high_vol_threshold': 1.1, 'extreme_vol_threshold': 2.4000000000000004, 'skip_low_vol_c_grades': False, 'low_vol_min_rr': 2.5}. Best is trial 5 with value: 0.8840586079979122.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
#
# ──────────────────────────────────────────────────────────────────────
#   PHASE 2 COMPLETE: Volatility Regime
# ──────────────────────────────────────────────────────────────────────
#
#   Best robust score: 0.8841
#
#   Best parameters found:
#     extreme_vol_threshold: 1.8
#     high_vol_threshold: 1.1
#     low_vol_min_rr: 2.5
#     low_vol_threshold: 0.8
#     skip_low_vol_c_grades: False
#
#   Metric                   Training      Testing
#   --------------------------------------------
#   Total Trades                   45           37
#   Win Rate                    57.9%        58.6%
#   Total R                    +11.70        +6.77
#   Avg R/Trade                +0.260       +0.183
#   Profit Factor                1.67         1.68
#   Max Drawdown                 4.40         2.60
#
#   ✓ Results saved to: C:\Users\phemm\orb_lab\results\AMD_phase2.json
#
#   Next: Review results, then run Phase 3
#
# ======================================================================

# %%
from Orb_Optimizer_Final import PhasedOptimizer

opt = PhasedOptimizer(symbol='AMD', phase=3, n_trials=200)
results = opt.run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from Orb_Optimizer_Final import PhasedOptimizer
#       3 opt = PhasedOptimizer(symbol='AMD', phase=3, n_trials=200)
#       4 results = opt.run()
#
# ModuleNotFoundError: No module named 'Orb_Optimizer_Final'

# %%
from Orb_Optimizer_Final import PhasedOptimizer

opt = PhasedOptimizer(symbol='AMD', phase=3, n_trials=200)
results = opt.run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from Orb_Optimizer_Final import PhasedOptimizer
#       3 opt = PhasedOptimizer(symbol='AMD', phase=3, n_trials=200)
#       4 results = opt.run()
#
# ModuleNotFoundError: No module named 'Orb_Optimizer_Final'

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from Orb_Optimizer_Final
finished with value: 1.279757764735823 and parameters: {'min_confluence': 3}. Best is trial 138 with value: 1.279757764735823.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.3 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.3 hours old)
# [I 2026-02-06 00:12:07,165] Trial 186 finished with value: 1.279757764735823 and parameters: {'min_confluence': 3}. Best is trial 138 with value: 1.279757764735823.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.3 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.3 hours old)
# [I 2026-02-06 00:13:42,683] Trial 187 finished with value: 1.279757764735823 and parameters: {'min_confluence': 3}. Best is trial 138 with value: 1.279757764735823.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.4 hours old)
# [I 2026-02-06 00:15:15,018] Trial 188 finished with value: 1.279757764735823 and parameters: {'min_confluence': 3}. Best is trial 138 with value: 1.279757764735823.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.4 hours old)
# [I 2026-02-06 00:16:46,652] Trial 189 finished with value: 1.279757764735823 and parameters: {'min_confluence': 3}. Best is trial 138 with value: 1.279757764735823.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.4 hours old)
# [I 2026-02-06 00:18:23,364] Trial 190 finished with value: 1.279757764735823 and parameters: {'min_confluence': 3}. Best is trial 138 with value: 1.279757764735823.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.4 hours old)
# [I 2026-02-06 00:20:01,625] Trial 191 finished with value: 1.279757764735823 and parameters: {'min_confluence': 3}. Best is trial 138 with value: 1.279757764735823.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.5 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.5 hours old)
# [I 2026-02-06 00:21:41,113] Trial 192 finished with value: 1.279757764735823 and parameters: {'min_confluence': 3}. Best is trial 138 with value: 1.279757764735823.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.5 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.5 hours old)
# [I 2026-02-06 00:23:18,779] Trial 193 finished with value: 1.279757764735823 and parameters: {'min_confluence': 3}. Best is trial 138 with value: 1.279757764735823.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.5 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.5 hours old)
# [I 2026-02-06 00:25:02,962] Trial 194 finished with value: 1.279757764735823 and parameters: {'min_confluence': 3}. Best is trial 138 with value: 1.279757764735823.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (5.5 hours old)
# [W 2026-02-06 00:25:53,786] Trial 195 failed with parameters: {'min_confluence': 3} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "C:\Users\phemm\anaconda3\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\phemm\orb_lab\src\Orb_Optimizer_Final.py", line 422, in _objective
#     train_results = bt_train.run()
#   File "C:\Users\phemm\orb_lab\src\orb_backtester.py", line 1466, in run
#     self._process_day(date_str)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "C:\Users\phemm\orb_lab\src\orb_backtester.py", line 1172, in _process_day
#     new_long, new_short = self._check_breakout(bar)
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^
#   File "C:\Users\phemm\orb_lab\src\orb_backtester.py", line 789, in _check_breakout
#     candle_body = abs(bar['close'] - bar['open'])
#                       ~~~^^^^^^^^^
#   File "C:\Users\phemm\anaconda3\Lib\site-packages\pandas\core\series.py", line 1133, in __getitem__
#     return self._get_value(key)
#            ~~~~~~~~~~~~~~~^^^^^
#   File "C:\Users\phemm\anaconda3\Lib\site-packages\pandas\core\series.py", line 1232, in _get_value
#     def _get_value(self, label, takeable: bool = False):
#
# KeyboardInterrupt
# [W 2026-02-06 00:25:53,791] Trial 195 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 from Orb_Optimizer_Final import PhasedOptimizer
#       6 opt = PhasedOptimizer(symbol='AMD', phase=3, n_trials=200)
# ----> 7 results = opt.run()
#
# File ~\orb_lab\src\Orb_Optimizer_Final.py:494, in PhasedOptimizer.run(self)
#     491     optuna.logging.set_verbosity(optuna.logging.WARNING)
#     493 # Run optimization
# --> 494 self.study.optimize(
#     495     self._objective,
#     496     n_trials=self.n_trials,
#     497     show_progress_bar=self.verbose
#     498 )
#     500 # Get best params for this phase's search space
#     501 best_trial = self.study.best_trial
#
# File ~\anaconda3\Lib\site-packages\optuna\study\study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:67, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      65 try:
#      66     if n_jobs == 1:
# ---> 67         _optimize_sequential(
#      68             study,
#      69             func,
#      70             n_trials,
#      71             timeout,
#      72             catch,
#      73             callbacks,
#      74             gc_after_trial,
#      75             reseed_sampler_rng=False,
#      76             time_start=None,
#      77             progress_bar=progress_bar,
#      78         )
#      79     else:
#      80         if n_jobs == -1:
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:164, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161         break
#     163 try:
# --> 164     frozen_trial_id = _run_trial(study, func, catch)
#     165 finally:
#     166     # The following line mitigates memory problems that can be occurred in some
#     167     # environments (e.g., services that use computing containers such as GitHub Actions).
#     168     # Please refer to the following PR for further details:
#     169     # https://github.com/optuna/optuna/pull/325.
#     170     if gc_after_trial:
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:262, in _run_trial(study, func, catch)
#     255         assert False, "Should not reach."
#     257 if (
#     258     updated_state == TrialState.FAIL
#     259     and func_err is not None
#     260     and not isinstance(func_err, catch)
#     261 ):
# --> 262     raise func_err
#     263 return trial._trial_id
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:205, in _run_trial(study, func, catch)
#     203 with get_heartbeat_thread(trial._trial_id, study._storage):
#     204     try:
# --> 205         value_or_values = func(trial)
#     206     except exceptions.TrialPruned as e:
#     207         # TODO(mamu): Handle multi-objective cases.
#     208         state = TrialState.PRUNED
#
# File ~\orb_lab\src\Orb_Optimizer_Final.py:422, in PhasedOptimizer._objective(self, trial)
#     414 try:
#     415     bt_train = ORBBacktester(
#     416         symbol=self.symbol,
#     417         start_date=self.train_start,
#    (...)    420         **params
#     421     )
# --> 422     train_results = bt_train.run()
#     423 except Exception as e:
#     424     if self.verbose:
#
# File ~\orb_lab\src\orb_backtester.py:1466, in ORBBacktester.run(self)
#    1464 for date in trading_dates:
#    1465     date_str = str(date)
# -> 1466     self._process_day(date_str)
#    1468 # Calculate summary statistics
#    1469 results = self._calc_summary()
#
# File ~\orb_lab\src\orb_backtester.py:1172, in ORBBacktester._process_day(self, date_str)
#    1169 pending_long_this_bar = False
#    1170 pending_short_this_bar = False
# -> 1172 new_long, new_short = self._check_breakout(bar)
#    1174 if new_long and not self.orb.has_broken_out_high:
#    1175     self.orb.long_breakout_pending = True
#
# File ~\orb_lab\src\orb_backtester.py:789, in ORBBacktester._check_breakout(self, bar)
#     786 atr = bar['atr_rth']
#     787 threshold = atr * self.breakout_threshold_mult
# --> 789 candle_body = abs(bar['close'] - bar['open'])
#     790 candle_range = bar['high'] - bar['low']
#     791 body_ratio = candle_body / candle_range if candle_range > 0 else 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1232, in Series._get_value(self, label, takeable)
#    1229     new_mgr = self._mgr.get_rows_with_mask(indexer)
#    1230     return self._constructor_from_mgr(new_mgr, axes=new_mgr.axes).__finalize__(self)
# -> 1232 def _get_value(self, label, takeable: bool = False):
#    1233     """
#    1234     Quickly retrieve single value at passed index label.
#    1235
#    (...)   1243     scalar value
#    1244     """
#    1245     if takeable:
#
# KeyboardInterrupt:

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

import json
import os
from datetime import datetime

# Phase 3 results based on optimization
phase3_results = {
    "symbol": "AMD",
    "phase": 3,
    "phase_name": "Confluence Gating",
    "optimization_date": datetime.now().isoformat(),
    "optimizer_version": "v3_phased",
    "objective": "robust_pf",
    "train_period": {"start": "2025-08-29", "end": "2025-11-15"},
    "test_period": {"start": "2025-11-16", "end": "2026-01-27"},
    "n_trials": 200,
    "best_score": 1.279757764735823,
    "best_params": {
        "min_confluence": 3
    },
    "fixed_params": {},  # Will be populated from phases 1 & 2 when loaded
    "train_results": {},
    "test_results": {}
}

# Save it
results_dir = r'C:\Users\phemm\orb_lab\results'
output_path = os.path.join(results_dir, 'AMD_phase3.json')

with open(output_path, 'w') as f:
    json.dump(phase3_results, f, indent=2)

print(f"✓ Phase 3 saved to: {output_path}")
print(f"  Best param: min_confluence = 3")
print(f"  Score: 1.28")
# Out:
# ✓ Phase 3 saved to: C:\Users\phemm\orb_lab\results\AMD_phase3.json
#   Best param: min_confluence = 3
#   Score: 1.28

# %%
import optuna

optuna.delete_study(
    study_name='ORB_AMD_phase3_v3',
    storage=r'sqlite:///C:\Users\phemm\orb_lab\orb_optuna_v3.db'
)
print("Phase 3 study deleted")
# Out:
# Phase 3 study deleted

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from Orb_Optimizer_Final import PhasedOptimizer

opt = PhasedOptimizer(symbol='AMD', phase=4, n_trials=50)
results = opt.run()
# Out:
# [I 2026-02-06 12:05:59,527] A new study created in RDB with name: ORB_AMD_phase4_v3
# ======================================================================
#   ORB PHASED OPTIMIZER v3: AMD
#   Phase 4: Boolean Polish
# ======================================================================
#
#   Execution style fine-tuning
#
#   Training: 2025-08-29 to 2025-11-15
#   Testing:  2025-11-16 to 2026-01-27
#   Trials:   50
#   Objective: sortino
#   Min Trades: 45
#
#   Searching 3 params:
#     • use_adaptive_be
#     • use_ema_exit
#     • use_aggressive_trailing
#
#   Fixed from previous phases: 28 params
#
# ──────────────────────────────────────────────────────────────────────
#   OPTIMIZATION IN PROGRESS...
# ──────────────────────────────────────────────────────────────────────
#   0%|          | 0/50 [00:00<?, ?it/s]
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ⚠ Cache stale (17 hours), refreshing...
#   ✓ Fetched 101941 bars, cached for next time
# [I 2026-02-06 12:07:00,464] Trial 0 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-06 12:07:52,845] Trial 1 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-06 12:08:42,120] Trial 2 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-06 12:09:32,242] Trial 3 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-06 12:10:28,842] Trial 4 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-06 12:11:23,059] Trial 5 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# [I 2026-02-06 12:12:18,327] Trial 6 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.1 hours old)
# [I 2026-02-06 12:13:06,294] Trial 7 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.1 hours old)
# [I 2026-02-06 12:13:56,146] Trial 8 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.1 hours old)
# [I 2026-02-06 12:14:45,081] Trial 9 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.1 hours old)
# [I 2026-02-06 12:15:33,913] Trial 10 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.1 hours old)
# [I 2026-02-06 12:16:24,632] Trial 11 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.1 hours old)
# [I 2026-02-06 12:17:15,412] Trial 12 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.1 hours old)
# [I 2026-02-06 12:18:04,011] Trial 13 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.1 hours old)
# [I 2026-02-06 12:18:50,793] Trial 14 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.2 hours old)
# [I 2026-02-06 12:19:36,725] Trial 15 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.2 hours old)
# [I 2026-02-06 12:20:23,599] Trial 16 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.2 hours old)
# [I 2026-02-06 12:21:10,469] Trial 17 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.2 hours old)
# [I 2026-02-06 12:21:59,272] Trial 18 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.2 hours old)
# [I 2026-02-06 12:22:50,066] Trial 19 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.2 hours old)
# [I 2026-02-06 12:23:39,091] Trial 20 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.2 hours old)
# [I 2026-02-06 12:24:27,604] Trial 21 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.3 hours old)
# [I 2026-02-06 12:25:15,611] Trial 22 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.3 hours old)
# [I 2026-02-06 12:26:03,543] Trial 23 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.3 hours old)
# [I 2026-02-06 12:26:51,008] Trial 24 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.3 hours old)
# [I 2026-02-06 12:27:42,049] Trial 25 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.3 hours old)
# [I 2026-02-06 12:28:32,911] Trial 26 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.3 hours old)
# [I 2026-02-06 12:29:22,274] Trial 27 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.3 hours old)
# [I 2026-02-06 12:30:11,144] Trial 28 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.4 hours old)
# [I 2026-02-06 12:30:57,874] Trial 29 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.4 hours old)
# [I 2026-02-06 12:31:44,112] Trial 30 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.4 hours old)
# [I 2026-02-06 12:32:31,788] Trial 31 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.4 hours old)
# [I 2026-02-06 12:33:17,490] Trial 32 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.4 hours old)
# [I 2026-02-06 12:34:02,934] Trial 33 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.4 hours old)
# [I 2026-02-06 12:34:48,372] Trial 34 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.4 hours old)
# [I 2026-02-06 12:35:35,012] Trial 35 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.4 hours old)
# [I 2026-02-06 12:36:21,486] Trial 36 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.5 hours old)
# [I 2026-02-06 12:37:10,255] Trial 37 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.5 hours old)
# [I 2026-02-06 12:38:00,213] Trial 38 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.5 hours old)
# [I 2026-02-06 12:38:48,483] Trial 39 finished with value: -inf and parameters: {'use_adaptive_be': True, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.5 hours old)
# [I 2026-02-06 12:39:36,365] Trial 40 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.5 hours old)
# [I 2026-02-06 12:40:24,151] Trial 41 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.5 hours old)
# [I 2026-02-06 12:41:10,861] Trial 42 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.5 hours old)
# [I 2026-02-06 12:41:59,851] Trial 43 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.5 hours old)
# [I 2026-02-06 12:42:46,707] Trial 44 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.6 hours old)
# [I 2026-02-06 12:43:33,243] Trial 45 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.6 hours old)
# [I 2026-02-06 12:44:19,717] Trial 46 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.6 hours old)
# [I 2026-02-06 12:45:06,767] Trial 47 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.6 hours old)
# [I 2026-02-06 12:45:53,501] Trial 48 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.6 hours old)
# [I 2026-02-06 12:46:41,303] Trial 49 finished with value: -inf and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 0 with value: -inf.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.6 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.6 hours old)
#
# ──────────────────────────────────────────────────────────────────────
#   PHASE 4 COMPLETE: Boolean Polish
# ──────────────────────────────────────────────────────────────────────
#
#   Best sortino score: -inf
#
#   Best parameters found:
#     use_adaptive_be: False
#     use_aggressive_trailing: True
#     use_ema_exit: True
#
#   Metric                   Training      Testing
#   --------------------------------------------
#   Total Trades                   39           34
#   Win Rate                    60.0%        63.0%
#   Total R                    +11.34        +8.77
#   Avg R/Trade                +0.291       +0.258
#   Profit Factor                1.66         1.90
#   Max Drawdown                 3.40         2.60
#
#   ✓ Results saved to: C:\Users\phemm\orb_lab\results\AMD_phase4.json
#
#   ✓ All phases complete! Run validation to confirm.
#
# ======================================================================

# %%
import optuna
storage = 'sqlite:///C:\\Users\\phemm\\orb_lab\\orb_optuna_v3.db'
optuna.delete_study(study_name='ORB_AMD_phase4_v3', storage=storage)

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from Orb_Optimizer_Final import PhasedOptimizer

opt = PhasedOptimizer(symbol='AMD', phase=4, n_trials=50)
results = opt.run()
# Out:
# ======================================================================
#   ORB PHASED OPTIMIZER v3: AMD
#   Phase 4: Boolean Polish
# ======================================================================
#
#   Execution style fine-tuning
#
#   Training: 2025-08-29 to 2025-11-15
#   Testing:  2025-11-16 to 2026-01-27
#   Trials:   50
#   Objective: sortino
#   Min Trades: 20
#
#   Searching 3 params:
#     • use_adaptive_be
#     • use_ema_exit
#     • use_aggressive_trailing
#
#   Fixed from previous phases: 28 params
#
# ──────────────────────────────────────────────────────────────────────
#   OPTIMIZATION IN PROGRESS...
# ──────────────────────────────────────────────────────────────────────
# [I 2026-02-06 13:09:33,529] A new study created in RDB with name: ORB_AMD_phase4_v3
#   0%|          | 0/50 [00:00<?, ?it/s]
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.0 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (1.0 hours old)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:217, in _run_trial(study, func, catch)
#     216 try:
# --> 217     updated_state, values, warning_message = _tell_with_warning(
#     218         study=study,
#     219         trial=trial,
#     220         value_or_values=value_or_values,
#     221         state=state,
#     222         suppress_warning=True,
#     223     )
#     224 except Exception:
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_tell.py:106, in _tell_with_warning(study, trial, value_or_values, state, skip_if_finished, suppress_warning)
#     105 # Validate the trial argument.
# --> 106 frozen_trial = _get_frozen_trial(study, trial)
#     107 if frozen_trial.state.is_finished() and skip_if_finished:
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_tell.py:40, in _get_frozen_trial(study, trial)
#      38     raise TypeError("Trial must be a trial object or trial number.")
# ---> 40 return study._storage.get_trial(trial_id)
#
# File ~\anaconda3\Lib\site-packages\optuna\storages\_cached_storage.py:214, in _CachedStorage.get_trial(self, trial_id)
#     212         return trial
# --> 214 return self._backend.get_trial(trial_id)
#
# File ~\anaconda3\Lib\site-packages\optuna\storages\_rdb\storage.py:794, in RDBStorage.get_trial(self, trial_id)
#     793 with _create_scoped_session(self.scoped_session) as session:
# --> 794     trial_model = models.TrialModel.find_or_raise_by_id(trial_id, session)
#     795     frozen_trial = self._build_frozen_trial_from_trial_model(trial_model)
#
# File ~\anaconda3\Lib\site-packages\optuna\storages\_rdb\models.py:272, in TrialModel.find_or_raise_by_id(cls, trial_id, session, for_update)
#     271 if trial is None:
# --> 272     raise KeyError(NOT_FOUND_MSG)
#     274 return trial
#
# KeyError: 'Record does not exist.'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:225, in _run_trial(study, func, catch)
#     224 except Exception:
# --> 225     frozen_trial = study._storage.get_trial(trial._trial_id)
#     226     updated_state = frozen_trial.state
#
# File ~\anaconda3\Lib\site-packages\optuna\storages\_cached_storage.py:214, in _CachedStorage.get_trial(self, trial_id)
#     212         return trial
# --> 214 return self._backend.get_trial(trial_id)
#
# File ~\anaconda3\Lib\site-packages\optuna\storages\_rdb\storage.py:794, in RDBStorage.get_trial(self, trial_id)
#     793 with _create_scoped_session(self.scoped_session) as session:
# --> 794     trial_model = models.TrialModel.find_or_raise_by_id(trial_id, session)
#     795     frozen_trial = self._build_frozen_trial_from_trial_model(trial_model)
#
# File ~\anaconda3\Lib\site-packages\optuna\storages\_rdb\models.py:272, in TrialModel.find_or_raise_by_id(cls, trial_id, session, for_update)
#     271 if trial is None:
# --> 272     raise KeyError(NOT_FOUND_MSG)
#     274 return trial
#
# KeyError: 'Record does not exist.'
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 from Orb_Optimizer_Final import PhasedOptimizer
#       6 opt = PhasedOptimizer(symbol='AMD', phase=4, n_trials=50)
# ----> 7 results = opt.run()
#
# File ~\orb_lab\src\Orb_Optimizer_Final.py:494, in PhasedOptimizer.run(self)
#     491     optuna.logging.set_verbosity(optuna.logging.WARNING)
#     493 # Run optimization
# --> 494 self.study.optimize(
#     495     self._objective,
#     496     n_trials=self.n_trials,
#     497     show_progress_bar=self.verbose
#     498 )
#     500 # Get best params for this phase's search space
#     501 best_trial = self.study.best_trial
#
# File ~\anaconda3\Lib\site-packages\optuna\study\study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:67, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      65 try:
#      66     if n_jobs == 1:
# ---> 67         _optimize_sequential(
#      68             study,
#      69             func,
#      70             n_trials,
#      71             timeout,
#      72             catch,
#      73             callbacks,
#      74             gc_after_trial,
#      75             reseed_sampler_rng=False,
#      76             time_start=None,
#      77             progress_bar=progress_bar,
#      78         )
#      79     else:
#      80         if n_jobs == -1:
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:164, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161         break
#     163 try:
# --> 164     frozen_trial_id = _run_trial(study, func, catch)
#     165 finally:
#     166     # The following line mitigates memory problems that can be occurred in some
#     167     # environments (e.g., services that use computing containers such as GitHub Actions).
#     168     # Please refer to the following PR for further details:
#     169     # https://github.com/optuna/optuna/pull/325.
#     170     if gc_after_trial:
#
# File ~\anaconda3\Lib\site-packages\optuna\study\_optimize.py:231, in _run_trial(study, func, catch)
#     229     raise
#     230 finally:
# --> 231     if updated_state == TrialState.COMPLETE:
#     232         assert values is not None
#     233         study._log_completed_trial(values, trial.number, trial.params)
#
# UnboundLocalError: cannot access local variable 'updated_state' where it is not associated with a value

# %%
import optuna
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

# Step 1: Delete stale Phase 4 study
storage = r'sqlite:///C:\Users\phemm\orb_lab\orb_optuna_v3.db'
optuna.delete_study(study_name='ORB_AMD_phase4_v3', storage=storage)
print("✓ Stale Phase 4 study deleted")

# Step 2: Re-run Phase 4 with corrected min_trades
from Orb_Optimizer_Final import PhasedOptimizer
opt = PhasedOptimizer(symbol='AMD', phase=4, n_trials=50)
results = opt.run()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 7
#       5 # Step 1: Delete stale Phase 4 study
#       6 storage = r'sqlite:///C:\Users\phemm\orb_lab\orb_optuna_v3.db'
# ----> 7 optuna.delete_study(study_name='ORB_AMD_phase4_v3', storage=storage)
#       8 print("✓ Stale Phase 4 study deleted")
#      10 # Step 2: Re-run Phase 4 with corrected min_trades
#
# File ~\anaconda3\Lib\site-packages\optuna\_convert_positional_args.py:135, in convert_positional_args.<locals>.converter_decorator.<locals>.converter_wrapper(*args, **kwargs)
#     129     raise TypeError(
#     130         f"{func.__name__}() got multiple values for arguments {duplicated_kwds}."
#     131     )
#     133 kwargs.update(inferred_kwargs)
# --> 135 return func(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\optuna\study\study.py:1466, in delete_study(study_name, storage)
#    1423 """Delete a :class:`~optuna.study.Study` object.
#    1424
#    1425 Example:
#    (...)   1462
#    1463 """
#    1465 storage = storages.get_storage(storage)
# -> 1466 study_id = storage.get_study_id_from_name(study_name)
#    1467 storage.delete_study(study_id)
#
# File ~\anaconda3\Lib\site-packages\optuna\storages\_cached_storage.py:107, in _CachedStorage.get_study_id_from_name(self, study_name)
#     106 def get_study_id_from_name(self, study_name: str) -> int:
# --> 107     return self._backend.get_study_id_from_name(study_name)
#
# File ~\anaconda3\Lib\site-packages\optuna\storages\_rdb\storage.py:340, in RDBStorage.get_study_id_from_name(self, study_name)
#     338 def get_study_id_from_name(self, study_name: str) -> int:
#     339     with _create_scoped_session(self.scoped_session) as session:
# --> 340         study = models.StudyModel.find_or_raise_by_name(study_name, session)
#     341         study_id = study.study_id
#     343     return study_id
#
# File ~\anaconda3\Lib\site-packages\optuna\storages\_rdb\models.py:87, in StudyModel.find_or_raise_by_name(cls, study_name, session)
#      85 study = cls.find_by_name(study_name, session)
#      86 if study is None:
# ---> 87     raise KeyError(NOT_FOUND_MSG)
#      89 return study
#
# KeyError: 'Record does not exist.'

# %%
import optuna

storage = r'sqlite:///C:\Users\phemm\orb_lab\orb_optuna_v3.db'
studies = optuna.study.get_all_study_summaries(storage=storage)
for s in studies:
    print(f"  {s.study_name}  ({s.n_trials} trials)")
# Out:
#   ORB_AMD_phase1_v3  (200 trials)
#   ORB_AMD_phase2_v3  (200 trials)

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from Orb_Optimizer_Final
parameters: {'use_adaptive_be': True, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.2 hours old)
# [I 2026-02-06 14:24:30,257] Trial 38 finished with value: 4.499476288267495 and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [I 2026-02-06 14:26:00,207] Trial 39 finished with value: 4.770876172860337 and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [I 2026-02-06 14:27:30,714] Trial 40 finished with value: 4.594520991975126 and parameters: {'use_adaptive_be': True, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [I 2026-02-06 14:29:01,134] Trial 41 finished with value: 4.770876172860337 and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.3 hours old)
# [I 2026-02-06 14:30:32,327] Trial 42 finished with value: 4.770876172860337 and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.4 hours old)
# [I 2026-02-06 14:32:02,031] Trial 43 finished with value: 4.770876172860337 and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.4 hours old)
# [I 2026-02-06 14:33:31,424] Trial 44 finished with value: 4.770876172860337 and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.4 hours old)
# [I 2026-02-06 14:35:00,824] Trial 45 finished with value: 4.770876172860337 and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.4 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.4 hours old)
# [I 2026-02-06 14:36:33,082] Trial 46 finished with value: 4.770876172860337 and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': True}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.5 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.5 hours old)
# [I 2026-02-06 14:38:02,245] Trial 47 finished with value: 4.770876172860337 and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.5 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.5 hours old)
# [I 2026-02-06 14:39:31,309] Trial 48 finished with value: 4.499476288267495 and parameters: {'use_adaptive_be': False, 'use_ema_exit': True, 'use_aggressive_trailing': True}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.5 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.5 hours old)
# [I 2026-02-06 14:41:01,186] Trial 49 finished with value: 4.770876172860337 and parameters: {'use_adaptive_be': False, 'use_ema_exit': False, 'use_aggressive_trailing': False}. Best is trial 1 with value: 4.770876172860337.
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.5 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (2.5 hours old)
#
# ──────────────────────────────────────────────────────────────────────
#   PHASE 4 COMPLETE: Boolean Polish
# ──────────────────────────────────────────────────────────────────────
#
#   Best sortino score: 4.7709
#
#   Best parameters found:
#     use_adaptive_be: False
#     use_aggressive_trailing: False
#     use_ema_exit: False
#
#   Metric                   Training      Testing
#   --------------------------------------------
#   Total Trades                   39           34
#   Win Rate                    44.0%        41.2%
#   Total R                    +17.81       +13.53
#   Avg R/Trade                +0.457       +0.398
#   Profit Factor                2.16         2.33
#   Max Drawdown                 4.00         3.02
#
#   ✓ Results saved to: C:\Users\phemm\orb_lab\results\AMD_phase4.json
#
#   ✓ All phases complete! Run validation to confirm.
#
# ======================================================================

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from Orb_Optimizer_Final import run_full_validation
run_full_validation(symbol='AMD')
# Out:
# ======================================================================
#   FULL VALIDATION: AMD
#   All 4 phases combined
# ======================================================================
#
#   Complete parameter set (31 params):
#     atr_stop_mult: 2.75
#     break_even_rr: 0.6000000000000001
#     breakout_threshold_mult: 0.07500000000000001
#     ema_confirmation_bars: 2
#     ema_period: 10
#     ema_tighten_zone: 0.35000000000000003
#     extreme_vol_threshold: 1.8
#     high_vol_threshold: 1.1
#     low_vol_min_rr: 2.5
#     low_vol_threshold: 0.8
#     max_target_atr: 4.0
#     min_acceptable_rr: 1.0
#     min_body_strength: 0.7
#     min_confluence: 3
#     min_stop_atr: 0.1
#     profit_target_rr: 3.0
#     skip_low_vol_c_grades: False
#     swing_lookback: 4
#     tightened_trail_distance: 0.5
#     trading_end_minutes: 615
#     trading_start_minutes: 570
#     trailing_stop_distance: 1.0
#     use_adaptive_be: False
#     use_aggressive_trailing: False
#     use_break_even: True
#     use_ema_exit: False
#     use_qqe_momentum: True
#     use_ssl_momentum: True
#     use_trailing_stop: True
#     use_wae_acceleration: True
#     vwap_stop_distance: 0.25
#
#   Running validation backtests...
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.1 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.2 hours old)
#
#   Metric                   Training      Testing
#   --------------------------------------------
#   Total Trades                   39           34
#   Win Rate                    44.0%        41.2%
#   Total R                    +17.81       +13.53
#   Avg R/Trade                +0.457       +0.398
#   Profit Factor                2.16         2.33
#   Max Drawdown                 4.00         3.02
#
#   ✓ Validation saved to: C:\Users\phemm\orb_lab\results\AMD_FINAL_validation.json
#
# ======================================================================
# {'symbol': 'AMD',
#  'validation_date': '2026-02-06T15:19:31.736333',
#  'all_params': {'use_break_even': True,
#   'use_trailing_stop': True,
#   'use_ssl_momentum': True,
#   'use_wae_acceleration': True,
#   'use_qqe_momentum': True,
#   'trading_start_minutes': 570,
#   'break_even_rr': 0.6000000000000001,
#   'profit_target_rr': 3.0,
#   'trailing_stop_distance': 1.0,
#   'ema_tighten_zone': 0.35000000000000003,
#   'tightened_trail_distance': 0.5,
#   'ema_confirmation_bars': 2,
#   'atr_stop_mult': 2.75,
#   'min_stop_atr': 0.1,
#   'swing_lookback': 4,
#   'min_acceptable_rr': 1.0,
#   'ema_period': 10,
#   'vwap_stop_distance': 0.25,
#   'max_target_atr': 4.0,
#   'breakout_threshold_mult': 0.07500000000000001,
#   'min_body_strength': 0.7,
#   'trading_end_minutes': 615,
#   'low_vol_threshold': 0.8,
#   'high_vol_threshold': 1.1,
#   'extreme_vol_threshold': 1.8,
#   'skip_low_vol_c_grades': False,
#   'low_vol_min_rr': 2.5,
#   'min_confluence': 3,
#   'use_adaptive_be': False,
#   'use_ema_exit': False,
#   'use_aggressive_trailing': False},
#  'train_period': {'start': '2025-08-29', 'end': '2025-11-15'},
#  'test_period': {'start': '2025-11-16', 'end': '2026-01-27'},
#  'train_results': {'total_trades': 39,
#   'win_rate': 44.0,
#   'total_r': np.float64(17.811517499638022),
#   'avg_r_per_trade': np.float64(0.45670557691379543),
#   'profit_factor': np.float64(2.161763825002515),
#   'max_drawdown_r': np.float64(4.0)},
#  'test_results': {'total_trades': 34,
#   'win_rate': 41.17647058823529,
#   'total_r': np.float64(13.529645128744487),
#   'avg_r_per_trade': np.float64(0.39793073908072024),
#   'profit_factor': np.float64(2.3282033445173336),
#   'max_drawdown_r': np.float64(3.0205683889644073)}}

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from Orb_Optimizer_Final import run_full_validation, ALWAYS_FIXED
from orb_backtester import ORBBacktester
import json
import os

# Load the final validated params
results_dir = r'C:\Users\phemm\orb_lab\results'
with open(os.path.join(results_dir, 'AMD_FINAL_validation.json'), 'r') as f:
    validated = json.load(f)

# Override EMA exit to True
params_ema_on = validated['all_params'].copy()
params_ema_on['use_ema_exit'] = True

print("=" * 70)
print("  A/B TEST: EMA Exit ON vs OFF")
print("=" * 70)

# Run both periods with EMA ON
bt_train = ORBBacktester(symbol='AMD', start_date='2025-08-29', end_date='2025-11-15', verbose=False, **params_ema_on)
train_on = bt_train.run()

bt_test = ORBBacktester(symbol='AMD', start_date='2025-11-16', end_date='2026-01-27', verbose=False, **params_ema_on)
test_on = bt_test.run()

# Original EMA OFF results from validation
train_off = validated['train_results']
test_off = validated['test_results']

print(f"\n  {'TRAINING PERIOD':^50}")
print(f"  {'Metric':<20} {'EMA OFF':>12} {'EMA ON':>12} {'Delta':>10}")
print(f"  {'-'*54}")
print(f"  {'Total Trades':<20} {train_off['total_trades']:>12} {train_on['total_trades']:>12} {train_on['total_trades']-train_off['total_trades']:>+10}")
print(f"  {'Win Rate':<20} {train_off['win_rate']:>11.1f}% {train_on['win_rate']:>11.1f}% {train_on['win_rate']-train_off['win_rate']:>+9.1f}%")
print(f"  {'Total R':<20} {train_off['total_r']:>+12.2f} {train_on['total_r']:>+12.2f} {train_on['total_r']-train_off['total_r']:>+10.2f}")
print(f"  {'Avg R/Trade':<20} {train_off['avg_r_per_trade']:>+12.3f} {train_on['avg_r_per_trade']:>+12.3f} {train_on['avg_r_per_trade']-train_off['avg_r_per_trade']:>+10.3f}")
print(f"  {'Profit Factor':<20} {train_off['profit_factor']:>12.2f} {train_on['profit_factor']:>12.2f} {train_on['profit_factor']-train_off['profit_factor']:>+10.2f}")
print(f"  {'Max Drawdown':<20} {train_off['max_drawdown_r']:>12.2f} {train_on['max_drawdown_r']:>12.2f} {train_on['max_drawdown_r']-train_off['max_drawdown_r']:>+10.2f}")

print(f"\n  {'TESTING PERIOD':^50}")
print(f"  {'Metric':<20} {'EMA OFF':>12} {'EMA ON':>12} {'Delta':>10}")
print(f"  {'-'*54}")
print(f"  {'Total Trades':<20} {test_off['total_trades']:>12} {test_on['total_trades']:>12} {test_on['total_trades']-test_off['total_trades']:>+10}")
print(f"  {'Win Rate':<20} {test_off['win_rate']:>11.1f}% {test_on['win_rate']:>11.1f}% {test_on['win_rate']-test_off['win_rate']:>+9.1f}%")
print(f"  {'Total R':<20} {test_off['total_r']:>+12.2f} {test_on['total_r']:>+12.2f} {test_on['total_r']-test_off['total_r']:>+10.2f}")
print(f"  {'Avg R/Trade':<20} {test_off['avg_r_per_trade']:>+12.3f} {test_on['avg_r_per_trade']:>+12.3f} {test_on['avg_r_per_trade']-test_off['avg_r_per_trade']:>+10.3f}")
print(f"  {'Profit Factor':<20} {test_off['profit_factor']:>12.2f} {test_on['profit_factor']:>12.2f} {test_on['profit_factor']-test_off['profit_factor']:>+10.2f}")
print(f"  {'Max Drawdown':<20} {test_off['max_drawdown_r']:>12.2f} {test_on['max_drawdown_r']:>12.2f} {test_on['max_drawdown_r']-test_off['max_drawdown_r']:>+10.2f}")

print(f"\n{'='*70}")
# Out:
# ======================================================================
#   A/B TEST: EMA Exit ON vs OFF
# ======================================================================
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.2 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.2 hours old)
#
#                    TRAINING PERIOD
#   Metric                    EMA OFF       EMA ON      Delta
#   ------------------------------------------------------
#   Total Trades                   39           39         +0
#   Win Rate                    44.0%        60.0%     +16.0%
#   Total R                    +17.81       +11.34      -6.47
#   Avg R/Trade                +0.457       +0.291     -0.166
#   Profit Factor                2.16         1.66      -0.50
#   Max Drawdown                 4.00         3.40      -0.60
#
#                     TESTING PERIOD
#   Metric                    EMA OFF       EMA ON      Delta
#   ------------------------------------------------------
#   Total Trades                   34           34         +0
#   Win Rate                    41.2%        63.0%     +21.8%
#   Total R                    +13.53        +8.77      -4.76
#   Avg R/Trade                +0.398       +0.258     -0.140
#   Profit Factor                2.33         1.90      -0.43
#   Max Drawdown                 3.02         2.60      -0.42
#
# ======================================================================

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from orb_walk_forward import run_full_robustness_suite
results = run_full_robustness_suite(symbol='AMD')
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[7], line 4
#     from orb_walk_forward import run_full_robustness_suite
#
#   File ~\orb_lab\src\orb_walk_forward.py:1
#     """
#     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 488-489: truncated \UXXXXXXXX escape

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

# Fix the file first
file_path = r'C:\Users\phemm\orb_lab\src\orb_walk_forward.py'
with open(file_path, 'r') as f:
    content = f.read()

content = content.replace(r"r'C:\Users\phemm\orb_lab\src'", r"r'C:/Users/phemm/orb_lab/src'")

with open(file_path, 'w') as f:
    f.write(content)

print("Fixed. Now import again.")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[8], line 7
#       5 file_path = r'C:\Users\phemm\orb_lab\src\orb_walk_forward.py'
#       6 with open(file_path, 'r') as f:
# ----> 7     content = f.read()
#       9 content = content.replace(r"r'C:\Users\phemm\orb_lab\src'", r"r'C:/Users/phemm/orb_lab/src'")
#      11 with open(file_path, 'w') as f:
#
# File ~\anaconda3\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 1361: character maps to <undefined>

# %%
# %%writefile C:/Users/phemm/orb_lab/src/orb_walk_forward.py
"""
ORB Walk-Forward Analysis
=========================
Post-validation robustness testing for optimized ORB parameters.
"""

import json
import os
import numpy as np
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from typing import Dict, Any, Optional, List
from collections import defaultdict
import sys

sys.path.insert(0, os.path.dirname(os.path.abspath(__file__)))

from orb_backtester import ORBBacktester

PROJECT_ROOT = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))


class WalkForwardAnalysis:
    """
    Rolling-window walk-forward analysis.
    Tests locked params across sequential train/test folds.
    """

    def __init__(
        self,
        symbol='AMD',
        data_start='2025-08-29',
        data_end='2026-01-27',
        train_months=2,
        test_months=1,
        step_months=1,
        anchored=False,
        params_file=None,
        results_dir=None,
        verbose=True,
    ):
        self.symbol = symbol
        self.data_start = datetime.strptime(data_start, '%Y-%m-%d')
        self.data_end = datetime.strptime(data_end, '%Y-%m-%d')
        self.train_months = train_months
        self.test_months = test_months
        self.step_months = step_months
        self.anchored = anchored
        self.results_dir = results_dir or os.path.join(PROJECT_ROOT, 'results')
        self.verbose = verbose
        self.params = self._load_params(params_file)
        self.folds = self._generate_folds()

    def _load_params(self, params_file=None):
        if params_file is None:
            params_file = os.path.join(
                self.results_dir, f'{self.symbol}_FINAL_validation.json'
            )
        if not os.path.exists(params_file):
            raise FileNotFoundError(f"Validation file not found: {params_file}")
        with open(params_file, 'r') as f:
            data = json.load(f)
        return data['all_params']

    def _generate_folds(self):
        folds = []
        fold_num = 1
        train_start = self.data_start

        while True:
            if self.anchored:
                fold_train_start = self.data_start
            else:
                fold_train_start = train_start

            fold_train_end = fold_train_start + relativedelta(months=self.train_months) - timedelta(days=1)
            fold_test_start = fold_train_end + timedelta(days=1)
            fold_test_end = fold_test_start + relativedelta(months=self.test_months) - timedelta(days=1)

            if fold_test_start >= self.data_end:
                break
            if fold_test_end > self.data_end:
                fold_test_end = self.data_end

            folds.append({
                'fold': fold_num,
                'train_start': fold_train_start.strftime('%Y-%m-%d'),
                'train_end': fold_train_end.strftime('%Y-%m-%d'),
                'test_start': fold_test_start.strftime('%Y-%m-%d'),
                'test_end': fold_test_end.strftime('%Y-%m-%d'),
            })

            fold_num += 1
            train_start += relativedelta(months=self.step_months)

        return folds

    def run_fixed(self):
        if self.verbose:
            print(f"\n{'='*70}")
            print(f"  WALK-FORWARD ANALYSIS: {self.symbol}")
            print(f"  Mode: {'Anchored' if self.anchored else 'Rolling'} | Folds: {len(self.folds)}")
            print(f"{'='*70}")

        fold_results = []

        for fold in self.folds:
            if self.verbose:
                print(f"\n  Fold {fold['fold']}: Train {fold['train_start']} to {fold['train_end']}")
                print(f"          Test  {fold['test_start']} to {fold['test_end']}")

            try:
                bt_train = ORBBacktester(
                    symbol=self.symbol,
                    start_date=fold['train_start'],
                    end_date=fold['train_end'],
                    verbose=False,
                    **self.params
                )
                train_results = bt_train.run()
            except Exception as e:
                print(f"    Train failed: {e}")
                continue

            try:
                bt_test = ORBBacktester(
                    symbol=self.symbol,
                    start_date=fold['test_start'],
                    end_date=fold['test_end'],
                    verbose=False,
                    **self.params
                )
                test_results = bt_test.run()
            except Exception as e:
                print(f"    Test failed: {e}")
                continue

            fold_data = {
                'fold': fold['fold'],
                'windows': fold,
                'train': {
                    'total_trades': train_results['total_trades'],
                    'win_rate': train_results['win_rate'],
                    'total_r': float(train_results['total_r']),
                    'avg_r_per_trade': float(train_results['avg_r_per_trade']),
                    'profit_factor': float(train_results['profit_factor']),
                    'max_drawdown_r': float(train_results['max_drawdown_r']),
                },
                'test': {
                    'total_trades': test_results['total_trades'],
                    'win_rate': test_results['win_rate'],
                    'total_r': float(test_results['total_r']),
                    'avg_r_per_trade': float(test_results['avg_r_per_trade']),
                    'profit_factor': float(test_results['profit_factor']),
                    'max_drawdown_r': float(test_results['max_drawdown_r']),
                }
            }
            fold_results.append(fold_data)

            if self.verbose:
                t = fold_data['test']
                print(f"    OOS: {t['total_trades']} trades | "
                      f"WR {t['win_rate']:.1f}% | "
                      f"R {t['total_r']:+.2f} | "
                      f"PF {t['profit_factor']:.2f} | "
                      f"DD {t['max_drawdown_r']:.2f}")

        summary = self._compute_summary(fold_results)

        output = {
            'symbol': self.symbol,
            'analysis_date': datetime.now().isoformat(),
            'mode': 'anchored' if self.anchored else 'rolling',
            'n_folds': len(fold_results),
            'params_used': self.params,
            'folds': fold_results,
            'summary': summary,
        }

        output_path = os.path.join(self.results_dir, f'{self.symbol}_walk_forward.json')
        with open(output_path, 'w') as f:
            json.dump(output, f, indent=2, default=str)

        if self.verbose:
            self._print_summary(fold_results, summary)
            print(f"\n  Saved to: {output_path}")

        return output

    def _compute_summary(self, fold_results):
        if not fold_results:
            return {}

        oos_total_r = [f['test']['total_r'] for f in fold_results]
        oos_avg_r = [f['test']['avg_r_per_trade'] for f in fold_results]
        oos_wr = [f['test']['win_rate'] for f in fold_results]
        oos_pf = [f['test']['profit_factor'] for f in fold_results]
        oos_dd = [f['test']['max_drawdown_r'] for f in fold_results]
        oos_trades = [f['test']['total_trades'] for f in fold_results]

        profitable_folds = sum(1 for r in oos_total_r if r > 0)

        degradation_ratios = []
        for f in fold_results:
            if f['train']['total_r'] > 0:
                degradation_ratios.append(f['test']['total_r'] / f['train']['total_r'])

        pct = 100 * profitable_folds / len(fold_results)
        avg_r_mean = float(np.mean(oos_avg_r))
        pf_mean = float(np.mean(oos_pf))

        if pct >= 80 and avg_r_mean > 0.2 and pf_mean > 1.5:
            verdict = "STRONG PASS - System is robust across time periods"
        elif pct >= 60 and avg_r_mean > 0.1 and pf_mean > 1.2:
            verdict = "PASS - System shows consistent edge, some variance"
        elif pct >= 50 and avg_r_mean > 0:
            verdict = "MARGINAL - Edge exists but inconsistent"
        else:
            verdict = "FAIL - System does not generalize, likely overfit"

        summary = {
            'oos_total_r_sum': float(sum(oos_total_r)),
            'oos_total_r_mean': float(np.mean(oos_total_r)),
            'oos_total_r_std': float(np.std(oos_total_r)),
            'oos_avg_r_mean': avg_r_mean,
            'oos_win_rate_mean': float(np.mean(oos_wr)),
            'oos_pf_mean': pf_mean,
            'oos_worst_dd': float(max(oos_dd)),
            'oos_total_trades': sum(oos_trades),
            'profitable_folds': profitable_folds,
            'total_folds': len(fold_results),
            'profitable_pct': pct,
            'degradation_ratio': float(np.mean(degradation_ratios)) if degradation_ratios else None,
            'verdict': verdict,
        }
        return summary

    def _print_summary(self, fold_results, summary):
        print(f"\n{'='*70}")
        print(f"  WALK-FORWARD SUMMARY: {self.symbol}")
        print(f"{'='*70}")

        print(f"\n  {'Fold':<6} {'Period':<24} {'Trades':>7} {'WR':>7} "
              f"{'Total R':>9} {'PF':>7} {'DD':>7}")
        print(f"  {'-'*68}")

        for f in fold_results:
            t = f['test']
            period = f"{f['windows']['test_start']} to {f['windows']['test_end']}"
            print(f"  {f['fold']:<6} {period:<24} {t['total_trades']:>7} "
                  f"{t['win_rate']:>6.1f}% {t['total_r']:>+9.2f} "
                  f"{t['profit_factor']:>7.2f} {t['max_drawdown_r']:>7.2f}")

        s = summary
        print(f"\n  AGGREGATE OOS:")
        print(f"    Total Trades:       {s['oos_total_trades']}")
        print(f"    Combined R:         {s['oos_total_r_sum']:+.2f}")
        print(f"    Mean R/Fold:        {s['oos_total_r_mean']:+.2f} (std {s['oos_total_r_std']:.2f})")
        print(f"    Mean Avg R/Trade:   {s['oos_avg_r_mean']:+.3f}")
        print(f"    Mean Win Rate:      {s['oos_win_rate_mean']:.1f}%")
        print(f"    Mean PF:            {s['oos_pf_mean']:.2f}")
        print(f"    Worst DD:           {s['oos_worst_dd']:.2f}R")
        print(f"    Profitable Folds:   {s['profitable_folds']}/{s['total_folds']} ({s['profitable_pct']:.0f}%)")
        if s['degradation_ratio'] is not None:
            print(f"    Degradation Ratio:  {s['degradation_ratio']:.2f}x")
        print(f"\n  VERDICT: {s['verdict']}")
        print(f"\n{'='*70}")


class MonteCarloAnalysis:
    """
    Monte Carlo stress test using trade-level resampling.
    """

    def __init__(
        self,
        symbol='AMD',
        start_date='2025-08-29',
        end_date='2026-01-27',
        params_file=None,
        results_dir=None,
        verbose=True,
    ):
        self.symbol = symbol
        self.start_date = start_date
        self.end_date = end_date
        self.results_dir = results_dir or os.path.join(PROJECT_ROOT, 'results')
        self.verbose = verbose
        self.params = self._load_params(params_file)
        self.trades = self._get_trades()

    def _load_params(self, params_file=None):
        if params_file is None:
            params_file = os.path.join(
                self.results_dir, f'{self.symbol}_FINAL_validation.json'
            )
        with open(params_file, 'r') as f:
            data = json.load(f)
        return data['all_params']

    def _get_trades(self):
        bt = ORBBacktester(
            symbol=self.symbol,
            start_date=self.start_date,
            end_date=self.end_date,
            verbose=False,
            **self.params
        )
        results = bt.run()
        return [t['r_multiple'] for t in results['trades']]

    def run(self, n_simulations=5000, n_trades=None, seed=42):
        if not self.trades:
            raise ValueError("No trades to simulate.")

        rng = np.random.default_rng(seed)
        trade_array = np.array(self.trades)
        sim_length = n_trades or len(trade_array)

        if self.verbose:
            print(f"\n{'='*70}")
            print(f"  MONTE CARLO ANALYSIS: {self.symbol}")
            print(f"{'='*70}")
            print(f"  Source: {len(trade_array)} trades | "
                  f"Avg R: {np.mean(trade_array):+.3f} | "
                  f"WR: {100*np.sum(trade_array>0)/len(trade_array):.1f}%")
            print(f"  Running {n_simulations:,} simulations of {sim_length} trades...")

        sim_trades = rng.choice(trade_array, size=(n_simulations, sim_length), replace=True)
        equity_curves = np.cumsum(sim_trades, axis=1)
        final_equity = equity_curves[:, -1]

        running_max = np.maximum.accumulate(equity_curves, axis=1)
        drawdowns = running_max - equity_curves
        max_drawdowns = np.max(drawdowns, axis=1)

        results = {
            'equity': {
                'mean': float(np.mean(final_equity)),
                'median': float(np.median(final_equity)),
                'std': float(np.std(final_equity)),
                'p5': float(np.percentile(final_equity, 5)),
                'p10': float(np.percentile(final_equity, 10)),
                'p25': float(np.percentile(final_equity, 25)),
                'p75': float(np.percentile(final_equity, 75)),
                'p90': float(np.percentile(final_equity, 90)),
                'p95': float(np.percentile(final_equity, 95)),
                'worst': float(np.min(final_equity)),
                'best': float(np.max(final_equity)),
            },
            'drawdown': {
                'mean': float(np.mean(max_drawdowns)),
                'median': float(np.median(max_drawdowns)),
                'p75': float(np.percentile(max_drawdowns, 75)),
                'p90': float(np.percentile(max_drawdowns, 90)),
                'p95': float(np.percentile(max_drawdowns, 95)),
                'p99': float(np.percentile(max_drawdowns, 99)),
                'worst': float(np.max(max_drawdowns)),
            },
            'risk': {
                'prob_losing': float(100 * np.mean(final_equity < 0)),
                'prob_dd_5r': float(100 * np.mean(max_drawdowns > 5)),
                'prob_dd_8r': float(100 * np.mean(max_drawdowns > 8)),
                'prob_dd_10r': float(100 * np.mean(max_drawdowns > 10)),
                'prob_dd_15r': float(100 * np.mean(max_drawdowns > 15)),
            },
        }

        output = {
            'symbol': self.symbol,
            'analysis_date': datetime.now().isoformat(),
            'source_trades': len(trade_array),
            **results,
        }

        output_path = os.path.join(self.results_dir, f'{self.symbol}_monte_carlo.json')
        with open(output_path, 'w') as f:
            json.dump(output, f, indent=2)

        if self.verbose:
            self._print_results(results, sim_length)
            print(f"\n  Saved to: {output_path}")

        return output

    def _print_results(self, results, sim_length):
        eq = results['equity']
        dd = results['drawdown']
        risk = results['risk']

        print(f"\n  EQUITY DISTRIBUTION ({sim_length} trades)")
        print(f"  {'-'*50}")
        print(f"    Best:           {eq['best']:>+8.2f} R")
        print(f"    95th pct:       {eq['p95']:>+8.2f} R")
        print(f"    75th pct:       {eq['p75']:>+8.2f} R")
        print(f"    Median:         {eq['median']:>+8.2f} R")
        print(f"    Mean:           {eq['mean']:>+8.2f} R")
        print(f"    25th pct:       {eq['p25']:>+8.2f} R")
        print(f"    10th pct:       {eq['p10']:>+8.2f} R")
        print(f"    5th pct:        {eq['p5']:>+8.2f} R")
        print(f"    Worst:          {eq['worst']:>+8.2f} R")

        print(f"\n  MAX DRAWDOWN DISTRIBUTION")
        print(f"  {'-'*50}")
        print(f"    Median:         {dd['median']:>8.2f} R")
        print(f"    Mean:           {dd['mean']:>8.2f} R")
        print(f"    90th pct:       {dd['p90']:>8.2f} R")
        print(f"    95th pct:       {dd['p95']:>8.2f} R")
        print(f"    99th pct:       {dd['p99']:>8.2f} R")
        print(f"    Worst:          {dd['worst']:>8.2f} R")

        print(f"\n  RISK PROBABILITIES")
        print(f"  {'-'*50}")
        print(f"    P(losing money):  {risk['prob_losing']:>6.1f}%")
        print(f"    P(DD > 5R):       {risk['prob_dd_5r']:>6.1f}%")
        print(f"    P(DD > 8R):       {risk['prob_dd_8r']:>6.1f}%")
        print(f"    P(DD > 10R):      {risk['prob_dd_10r']:>6.1f}%")
        print(f"    P(DD > 15R):      {risk['prob_dd_15r']:>6.1f}%")
        print(f"\n{'='*70}")


def run_full_robustness_suite(symbol='AMD', results_dir=None):
    results_dir = results_dir or os.path.join(PROJECT_ROOT, 'results')
    all_results = {}

    print(f"\n{'='*70}")
    print(f"  FULL ROBUSTNESS SUITE: {symbol}")
    print(f"{'='*70}")

    print(f"\n  Stage 1: Rolling Walk-Forward")
    wfa_rolling = WalkForwardAnalysis(symbol=symbol, anchored=False, results_dir=results_dir)
    all_results['rolling'] = wfa_rolling.run_fixed()

    print(f"\n  Stage 2: Anchored Walk-Forward")
    wfa_anchored = WalkForwardAnalysis(symbol=symbol, anchored=True, results_dir=results_dir)
    all_results['anchored'] = wfa_anchored.run_fixed()

    print(f"\n  Stage 3: Monte Carlo")
    mc = MonteCarloAnalysis(symbol=symbol, results_dir=results_dir)
    all_results['monte_carlo'] = mc.run(n_simulations=10000)

    print(f"\n{'='*70}")
    print(f"  SUITE COMPLETE: {symbol}")
    print(f"  Rolling:  {all_results['rolling']['summary']['verdict']}")
    print(f"  Anchored: {all_results['anchored']['summary']['verdict']}")
    print(f"  MC P(loss): {all_results['monte_carlo']['risk']['prob_losing']:.1f}%")
    print(f"{'='*70}\n")

    return all_results
# Out:
# Writing C:/Users/phemm/orb_lab/src/orb_walk_forward.py

# %%
from orb_walk_forward import run_full_robustness_suite
results = run_full_robustness_suite(symbol='AMD')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from orb_walk_forward import run_full_robustness_suite
#       2 results = run_full_robustness_suite(symbol='AMD')
#
# ModuleNotFoundError: No module named 'orb_walk_forward'

# %%
import importlib
import orb_walk_forward
importlib.reload(orb_walk_forward)

from orb_walk_forward import run_full_robustness_suite
results = run_full_robustness_suite(symbol='AMD')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import importlib
# ----> 2 import orb_walk_forward
#       3 importlib.reload(orb_walk_forward)
#       5 from orb_walk_forward import run_full_robustness_suite
#
# ModuleNotFoundError: No module named 'orb_walk_forward'

# %%
---------------------------------------------------------------------------
ModuleNotFoundError                       Traceback (most recent call last)
Cell In[2], line 2
      1 import importlib
----> 2 import orb_walk_forward
      3 importlib.reload(orb_walk_forward)
      5 from orb_walk_forward import run_full_robustness_suite

ModuleNotFoundError: No module named 'orb_walk_forward'
# Out:
#   Cell In[3], line 1
#     ---------------------------------------------------------------------------
#                                                                                ^
# SyntaxError: invalid syntax

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
import importlib
import orb_walk_forward
importlib.reload(orb_walk_forward)
from orb_walk_forward import run_full_robustness_suite
results = run_full_robustness_suite(symbol='AMD')
# Out:
# ======================================================================
#   FULL ROBUSTNESS SUITE: AMD
# ======================================================================
#
#   Stage 1: Rolling Walk-Forward
#
# ======================================================================
#   WALK-FORWARD ANALYSIS: AMD
#   Mode: Rolling | Folds: 3
# ======================================================================
#
#   Fold 1: Train 2025-08-29 to 2025-10-28
#           Test  2025-10-29 to 2025-11-28
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.6 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.6 hours old)
#     OOS: 14 trades | WR 16.7% | R -1.23 | PF 0.54 | DD 3.00
#
#   Fold 2: Train 2025-09-29 to 2025-11-28
#           Test  2025-11-29 to 2025-12-28
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.6 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.6 hours old)
#     OOS: 15 trades | WR 37.5% | R +5.84 | PF 2.77 | DD 2.00
#
#   Fold 3: Train 2025-10-29 to 2025-12-28
#           Test  2025-12-29 to 2026-01-27
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.6 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.7 hours old)
#     OOS: 11 trades | WR 50.0% | R +5.92 | PF 1.78 | DD 3.00
#
# ======================================================================
#   WALK-FORWARD SUMMARY: AMD
# ======================================================================
#
#   Fold   Period                    Trades      WR   Total R      PF      DD
#   --------------------------------------------------------------------
#   1      2025-10-29 to 2025-11-28      14   16.7%     -1.23    0.54    3.00
#   2      2025-11-29 to 2025-12-28      15   37.5%     +5.84    2.77    2.00
#   3      2025-12-29 to 2026-01-27      11   50.0%     +5.92    1.78    3.00
#
#   AGGREGATE OOS:
#     Total Trades:       40
#     Combined R:         +10.53
#     Mean R/Fold:        +3.51 (std 3.35)
#     Mean Avg R/Trade:   +0.280
#     Mean Win Rate:      34.7%
#     Mean PF:            1.69
#     Worst DD:           3.00R
#     Profitable Folds:   2/3 (67%)
#     Degradation Ratio:  0.64x
#
#   VERDICT: PASS - System shows consistent edge, some variance
#
# ======================================================================
#
#   Saved to: C:\Users\phemm\orb_lab\results\AMD_walk_forward.json
#
#   Stage 2: Anchored Walk-Forward
#
# ======================================================================
#   WALK-FORWARD ANALYSIS: AMD
#   Mode: Anchored | Folds: 3
# ======================================================================
#
#   Fold 1: Train 2025-08-29 to 2025-10-28
#           Test  2025-10-29 to 2025-11-28
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.7 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.7 hours old)
#     OOS: 14 trades | WR 16.7% | R -1.23 | PF 0.54 | DD 3.00
#
#   Fold 2: Train 2025-08-29 to 2025-11-28
#           Test  2025-11-29 to 2025-12-28
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.7 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.7 hours old)
#     OOS: 15 trades | WR 37.5% | R +5.84 | PF 2.77 | DD 2.00
#
#   Fold 3: Train 2025-08-29 to 2025-12-28
#           Test  2025-12-29 to 2026-01-27
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.7 hours old)
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.7 hours old)
#     OOS: 11 trades | WR 50.0% | R +5.92 | PF 1.78 | DD 3.00
#
# ======================================================================
#   WALK-FORWARD SUMMARY: AMD
# ======================================================================
#
#   Fold   Period                    Trades      WR   Total R      PF      DD
#   --------------------------------------------------------------------
#   1      2025-10-29 to 2025-11-28      14   16.7%     -1.23    0.54    3.00
#   2      2025-11-29 to 2025-12-28      15   37.5%     +5.84    2.77    2.00
#   3      2025-12-29 to 2026-01-27      11   50.0%     +5.92    1.78    3.00
#
#   AGGREGATE OOS:
#     Total Trades:       40
#     Combined R:         +10.53
#     Mean R/Fold:        +3.51 (std 3.35)
#     Mean Avg R/Trade:   +0.280
#     Mean Win Rate:      34.7%
#     Mean PF:            1.69
#     Worst DD:           3.00R
#     Profitable Folds:   2/3 (67%)
#     Degradation Ratio:  0.16x
#
#   VERDICT: PASS - System shows consistent edge, some variance
#
# ======================================================================
#
#   Saved to: C:\Users\phemm\orb_lab\results\AMD_walk_forward.json
#
#   Stage 3: Monte Carlo
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (3.7 hours old)
#
# ======================================================================
#   MONTE CARLO ANALYSIS: AMD
# ======================================================================
#   Source: 73 trades | Avg R: +0.429 | WR: 24.7%
#   Running 10,000 simulations of 73 trades...
#
#   EQUITY DISTRIBUTION (73 trades)
#   --------------------------------------------------
#     Best:             +85.74 R
#     95th pct:         +54.00 R
#     75th pct:         +40.35 R
#     Median:           +31.11 R
#     Mean:             +31.32 R
#     25th pct:         +21.72 R
#     10th pct:         +14.20 R
#     5th pct:           +9.80 R
#     Worst:            -15.02 R
#
#   MAX DRAWDOWN DISTRIBUTION
#   --------------------------------------------------
#     Median:             5.03 R
#     Mean:               5.82 R
#     90th pct:           9.00 R
#     95th pct:          10.22 R
#     99th pct:          13.51 R
#     Worst:             22.04 R
#
#   RISK PROBABILITIES
#   --------------------------------------------------
#     P(losing money):     0.8%
#     P(DD > 5R):         52.6%
#     P(DD > 8R):         14.6%
#     P(DD > 10R):         5.9%
#     P(DD > 15R):         0.4%
#
# ======================================================================
#
#   Saved to: C:\Users\phemm\orb_lab\results\AMD_monte_carlo.json
#
# ======================================================================
#   SUITE COMPLETE: AMD
#   Rolling:  PASS - System shows consistent edge, some variance
#   Anchored: PASS - System shows consistent edge, some variance
#   MC P(loss): 0.8%
# ======================================================================
