# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from orb_backtester import ORBBacktester

bt = ORBBacktester(
    symbol='AMD',
    start_date='2025-10-01',
    end_date='2025-12-31',
    verbose=True
)
results = bt.run()
# Out:
# ======================================================================
#   ORB BACKTESTER: AMD
#   2025-10-01 to 2025-12-31
# ======================================================================
#
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 180 days, extended)...
#   ✓ Loading from cache (0.0 hours old)
# ✓ Loaded 103459 bars for AMD
# Processing 64 trading days...
#
#   ❌ LONG 2025-10-01 09:44→09:48: $-0.77 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-01 09:55→09:58: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-10-02 09:35→09:38: $-1.25 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-02 09:41→09:58: $-1.44 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-03 09:40→09:46: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-10-03 09:50→09:52: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-10-06 09:43→10:04: $+4.47 (+0.72R) - EMA EXIT
#   ✅ SHORT 2025-10-07 09:50→11:14: $+2.58 (+1.06R) - EMA EXIT
#   ✅ LONG 2025-10-08 09:35→09:55: $+8.07 (+6.85R) - TRAILING STOP
#   ✅ SHORT 2025-10-10 09:38→09:53: $+1.65 (+1.11R) - EMA EXIT
#   ❌ SHORT 2025-10-13 09:35→09:42: $-1.72 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-13 10:11→10:12: $-1.03 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-10-13 10:22→10:39: $+0.20 (+0.14R) - EMA EXIT
#   ❌ SHORT 2025-10-14 09:35→09:38: $-1.82 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-14 10:28→10:31: $-1.53 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-10-15 09:50→10:00: $+2.94 (+1.43R) - TRAILING STOP
#   ❌ SHORT 2025-10-16 09:49→09:52: $-2.12 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-16 10:15→10:29: $-1.91 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-10-17 09:39→09:48: $+0.60 (+0.38R) - EMA EXIT
#   ❌ SHORT 2025-10-17 10:00→10:01: $-0.55 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-17 10:11→10:16: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-10-20 09:42→09:49: $-1.76 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-10-20 09:58→10:08: $+0.88 (+0.54R) - EMA EXIT
#   ❌ LONG 2025-10-21 09:37→09:40: $-1.22 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-10-21 09:48→10:14: $+1.00 (+0.71R) - EMA EXIT
#   ✅ LONG 2025-10-22 09:49→10:06: $+0.79 (+0.69R) - EMA EXIT
#   ✅ SHORT 2025-10-22 10:26→10:33: $+2.52 (+2.13R) - TRAILING STOP
#   ✅ LONG 2025-10-23 09:39→09:59: $+2.70 (+2.09R) - TRAILING STOP
#   ✅ LONG 2025-10-24 09:55→10:05: $+0.70 (+0.33R) - EMA EXIT
#   ✅ SHORT 2025-10-27 09:45→10:25: $+1.90 (+1.01R) - EMA EXIT
#   ❌ LONG 2025-10-28 09:38→09:48: $-1.56 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-10-28 09:56→10:09: $+2.00 (+1.89R) - TRAILING STOP
#   ❌ SHORT 2025-10-29 09:37→09:45: $-2.19 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-30 09:51→10:09: $-1.88 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-31 09:51→09:54: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-11-03 09:38→10:02: $+2.27 (+1.25R) - EMA EXIT
#   ✅ LONG 2025-11-04 09:39→10:03: $+3.41 (+1.42R) - EMA EXIT
#   ❌ LONG 2025-11-05 10:05→10:16: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-11-07 10:28→10:36: $+0.46 (+0.27R) - EMA EXIT
#   ✅ LONG 2025-11-10 09:44→10:09: $+1.68 (+0.96R) - EMA EXIT
#   ❌ LONG 2025-11-11 09:46→09:49: $-1.44 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-11-11 10:13→10:25: $+0.68 (+0.49R) - EMA EXIT
#   ❌ SHORT 2025-11-12 09:46→10:05: $-3.46 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-11-12 10:10→10:31: $+1.29 (+0.52R) - EMA EXIT
#   ❌ SHORT 2025-11-13 09:43→09:51: $-2.25 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-11-13 09:55→10:02: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-11-13 10:03→10:19: $+3.04 (+2.18R) - TRAILING STOP
#   ✅ LONG 2025-11-14 09:41→10:07: $+6.17 (+2.17R) - TRAILING STOP
#   ✅ LONG 2025-11-17 09:37→09:53: $+1.67 (+0.84R) - EMA EXIT
#   ✅ LONG 2025-11-17 10:10→10:17: $+1.06 (+1.07R) - TRAILING STOP
#   ❌ LONG 2025-11-17 10:20→10:32: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-11-19 09:53→10:05: $+0.38 (+0.21R) - EMA EXIT
#   ❌ SHORT 2025-11-20 09:44→09:46: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-11-20 09:57→10:18: $+0.64 (+0.39R) - EMA EXIT
#   ✅ SHORT 2025-11-21 09:38→09:48: $+0.38 (+0.18R) - EMA EXIT
#   ❌ LONG 2025-11-24 09:36→09:50: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-11-25 09:45→09:52: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-11-25 09:56→09:58: $-1.46 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-11-25 10:02→10:18: $+0.35 (+0.21R) - EMA EXIT
#   ❌ LONG 2025-11-26 09:35→09:38: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-11-26 09:47→09:50: $-1.35 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-26 09:55→10:02: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-11-26 10:05→10:06: $-0.61 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-11-28 09:48→10:38: $-1.48 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-01 09:36→09:43: $-1.33 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-12-01 09:44→09:51: $+1.97 (+1.39R) - TRAILING STOP
#   ✅ LONG 2025-12-02 09:36→09:46: $+0.38 (+0.26R) - EMA EXIT
#   ❌ SHORT 2025-12-03 09:35→09:41: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-12-03 10:17→10:20: $-1.05 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-04 09:51→10:22: $-1.43 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-05 09:41→09:45: $-1.51 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-05 10:25→10:27: $-0.57 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-08 09:38→09:46: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-12-08 09:51→09:56: $-1.07 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-12-09 10:02→10:17: $+0.54 (+0.41R) - EMA EXIT
#   ✅ SHORT 2025-12-10 10:09→10:43: $+0.14 (+0.15R) - EMA EXIT
#   ✅ SHORT 2025-12-11 09:49→10:03: $+1.33 (+0.82R) - EMA EXIT
#   ❌ LONG 2025-12-12 09:35→09:39: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-12-12 10:03→10:12: $+0.60 (+0.48R) - EMA EXIT
#   ❌ LONG 2025-12-15 09:48→09:53: $-1.53 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-16 09:36→09:41: $-1.41 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-16 09:50→10:16: $-1.48 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-12-17 09:35→09:52: $+1.19 (+1.04R) - EMA EXIT
#   ❌ SHORT 2025-12-18 09:48→09:52: $-1.59 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-18 10:16→10:22: $-0.78 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-18 10:28→10:33: $-1.08 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-12-19 09:39→10:05: $+3.61 (+2.15R) - TRAILING STOP
#   ✅ SHORT 2025-12-22 09:58→10:15: $+0.83 (+0.68R) - EMA EXIT
#   ✅ SHORT 2025-12-26 09:43→10:02: $+0.37 (+0.33R) - EMA EXIT
#   ✅ LONG 2025-12-29 09:36→09:45: $+0.72 (+0.55R) - EMA EXIT
#   ✅ LONG 2025-12-29 10:15→10:38: $+2.15 (+3.99R) - TRAILING STOP
#   ❌ SHORT 2025-12-30 10:25→10:51: $-0.39 (-1.00R) - INITIAL STOP
#
# ======================================================================
#   BACKTEST SUMMARY: AMD
#   2025-10-01 to 2025-12-31
# ======================================================================
#
#   Total Trades:    92
#   Wins/Losses:     41W / 51L
#   Win Rate:        44.6%
#
#   Total P/L:       $+20.27
#   Total R:         +10.49R
#   Avg R/Trade:     +0.114R
#
#   Avg Win:         $1.71 (1.11R)
#   Avg Loss:        $-0.98 (-0.69R)
#   Profit Factor:   1.41
#   Max Drawdown:    11.24R
#
# ======================================================================

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from orb_backtester import ORBBacktester

bt = ORBBacktester(
    symbol='NVDA',
    start_date='2025-10-01',
    end_date='2025-12-31',
    verbose=True
)
results = bt.run()
# Out:
# ======================================================================
#   ORB BACKTESTER: NVDA
#   2025-10-01 to 2025-12-31
# ======================================================================
#
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching NVDA (1-min bars, 180 days, extended)...
#   ✓ Fetched 118368 bars, cached for next time
# ✓ Loaded 118368 bars for NVDA
# Processing 64 trading days...
#
#   ❌ SHORT 2025-10-01 09:38→09:53: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-10-01 10:26→10:39: $+0.83 (+1.53R) - TRAILING STOP
#   ❌ LONG 2025-10-02 09:35→09:37: $-0.79 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-10-02 09:40→09:54: $+0.34 (+0.30R) - EMA EXIT
#   ❌ LONG 2025-10-03 09:37→09:41: $-0.59 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-03 09:58→10:04: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-10-03 10:21→10:26: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-10-06 09:44→09:50: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-10-06 09:58→10:07: $-0.67 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-10-07 09:43→09:58: $+1.12 (+2.14R) - TRAILING STOP
#   ❌ LONG 2025-10-08 09:39→09:43: $-0.86 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-08 09:45→09:51: $-0.59 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-09 09:36→09:44: $-0.96 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-10-09 09:47→09:55: $+0.54 (+0.56R) - EMA EXIT
#   ✅ LONG 2025-10-10 09:56→10:16: $+0.52 (+0.80R) - EMA EXIT
#   ❌ SHORT 2025-10-13 09:41→09:43: $-0.94 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-13 09:58→10:21: $-0.90 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-10-15 09:38→09:51: $+0.44 (+0.38R) - EMA EXIT
#   ❌ SHORT 2025-10-15 10:18→10:22: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-10-16 09:45→09:48: $-0.62 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-16 10:17→10:26: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-10-16 10:29→10:38: $+0.42 (+1.30R) - TRAILING STOP
#   ✅ LONG 2025-10-17 09:48→09:58: $+0.23 (+0.25R) - EMA EXIT
#   ✅ LONG 2025-10-20 10:21→10:31: $+0.95 (+1.94R) - TRAILING STOP
#   ✅ SHORT 2025-10-21 09:41→09:51: $+0.15 (+0.27R) - EMA EXIT
#   ✅ LONG 2025-10-22 09:42→09:55: $+1.41 (+2.54R) - TRAILING STOP
#   ❌ SHORT 2025-10-23 09:42→09:45: $-0.51 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-10-23 09:48→09:59: $+0.40 (+0.58R) - EMA EXIT
#   ✅ LONG 2025-10-23 10:12→10:14: $+0.11 (+0.43R) - EMA EXIT
#   ❌ LONG 2025-10-24 09:36→10:08: $-0.79 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-27 09:40→10:09: $-0.72 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-10-27 10:10→10:24: $+0.49 (+0.78R) - EMA EXIT
#   ❌ LONG 2025-10-29 09:59→10:04: $-1.28 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-30 09:35→09:38: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-10-30 10:10→10:14: $-0.88 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-10-30 10:17→10:26: $+0.31 (+0.31R) - EMA EXIT
#   ❌ LONG 2025-10-31 09:42→09:46: $-0.81 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-03 09:50→10:23: $-1.01 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-11-04 09:53→10:08: $-1.09 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-05 09:36→09:38: $-1.04 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-11-05 09:46→09:55: $+0.26 (+0.24R) - EMA EXIT
#   ❌ SHORT 2025-11-07 09:37→09:40: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-11-07 09:49→09:53: $-1.01 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-11-07 09:59→10:08: $+0.40 (+0.44R) - EMA EXIT
#   ❌ SHORT 2025-11-10 09:50→09:58: $-0.98 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-11-10 10:05→10:19: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-11-11 09:41→09:56: $+0.71 (+0.79R) - EMA EXIT
#   ✅ SHORT 2025-11-13 09:35→09:48: $+1.09 (+1.10R) - EMA EXIT
#   ✅ SHORT 2025-11-13 10:17→10:39: $+1.59 (+1.97R) - TRAILING STOP
#   ✅ LONG 2025-11-14 09:36→09:50: $+2.32 (+1.44R) - EMA EXIT
#   ✅ LONG 2025-11-17 09:36→09:54: $+0.81 (+0.59R) - EMA EXIT
#   ✅ SHORT 2025-11-18 09:46→10:05: $+0.96 (+0.71R) - EMA EXIT
#   ❌ SHORT 2025-11-21 09:35→09:40: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-11-21 09:44→09:48: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-11-21 10:10→10:19: $+0.57 (+0.50R) - EMA EXIT
#   ❌ LONG 2025-11-24 09:35→09:39: $-1.07 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-24 09:46→09:52: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-11-24 09:54→10:00: $-0.73 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-24 10:25→10:38: $-0.91 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-11-25 09:39→09:50: $+1.30 (+1.12R) - EMA EXIT
#   ✅ SHORT 2025-11-26 09:42→10:03: $+1.41 (+1.21R) - EMA EXIT
#   ❌ SHORT 2025-11-28 09:39→09:42: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-11-28 09:44→09:48: $-0.58 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-28 09:52→09:56: $-0.58 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-11-28 09:58→10:13: $+0.18 (+0.39R) - EMA EXIT
#   ❌ LONG 2025-12-01 09:35→09:43: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-12-02 09:36→09:40: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-12-03 09:39→09:41: $-0.98 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-04 09:36→09:44: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-12-04 09:48→09:52: $+0.19 (+0.41R) - EMA EXIT
#   ✅ SHORT 2025-12-05 09:35→09:43: $+1.38 (+1.96R) - TRAILING STOP
#   ❌ SHORT 2025-12-10 09:35→09:39: $-0.59 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-12-10 09:49→09:59: $+0.12 (+0.33R) - EMA EXIT
#   ✅ SHORT 2025-12-11 09:46→10:02: $+0.59 (+0.70R) - EMA EXIT
#   ✅ SHORT 2025-12-11 10:29→10:45: $+0.71 (+2.87R) - TRAILING STOP
#   ✅ SHORT 2025-12-12 09:48→10:11: $+0.64 (+0.73R) - EMA EXIT
#   ✅ SHORT 2025-12-15 09:38→09:43: $+0.05 (+0.06R) - EMA EXIT
#   ❌ SHORT 2025-12-15 10:00→10:05: $-0.42 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-12-15 10:15→10:30: $+0.97 (+1.79R) - TRAILING STOP
#   ❌ SHORT 2025-12-16 09:35→09:36: $-0.71 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-16 09:41→09:47: $-0.70 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-16 09:50→10:25: $-1.00 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-17 09:35→09:49: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-12-17 09:53→09:56: $-0.45 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-17 10:04→10:06: $-0.33 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-17 10:25→10:28: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-12-18 09:35→09:44: $+0.41 (+0.42R) - EMA EXIT
#   ❌ SHORT 2025-12-18 10:08→10:15: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-12-19 09:41→09:51: $+0.81 (+0.89R) - EMA EXIT
#   ❌ SHORT 2025-12-22 09:44→09:47: $-0.60 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-23 09:44→09:51: $-0.68 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-12-23 10:22→10:32: $+0.38 (+0.86R) - EMA EXIT
#   ❌ LONG 2025-12-24 09:36→09:40: $-0.57 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-12-24 10:22→10:29: $+0.05 (+0.14R) - EMA EXIT
#   ❌ LONG 2025-12-26 09:35→09:59: $-0.74 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-29 09:37→09:51: $-1.28 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-30 09:51→09:56: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-12-31 09:40→09:54: $+0.33 (+0.41R) - EMA EXIT
#
# ======================================================================
#   BACKTEST SUMMARY: NVDA
#   2025-10-01 to 2025-12-31
# ======================================================================
#
#   Total Trades:    98
#   Wins/Losses:     40W / 58L
#   Win Rate:        40.8%
#
#   Total P/L:       $-3.52
#   Total R:         -1.83R
#   Avg R/Trade:     -0.019R
#
#   Avg Win:         $0.66 (0.90R)
#   Avg Loss:        $-0.52 (-0.66R)
#   Profit Factor:   0.88
#   Max Drawdown:    8.24R
#
# ======================================================================

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from orb_backtester import ORBBacktester

bt = ORBBacktester(
    symbol='TSLA',
    start_date='2025-10-01',
    end_date='2025-12-31',
    verbose=True
)
results = bt.run()
# Out:
# ======================================================================
#   ORB BACKTESTER: TSLA
#   2025-10-01 to 2025-12-31
# ======================================================================
#
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching TSLA (1-min bars, 180 days, extended)...
#   ✓ Fetched 115874 bars, cached for next time
# ✓ Loaded 115874 bars for TSLA
# Processing 64 trading days...
#
#   ❌ LONG 2025-10-01 09:37→09:41: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-10-01 09:43→09:49: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-10-01 10:01→10:12: $+2.18 (+1.25R) - TRAILING STOP
#   ❌ SHORT 2025-10-02 09:35→09:39: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-10-03 09:40→09:59: $+1.57 (+0.55R) - EMA EXIT
#   ❌ SHORT 2025-10-06 09:54→10:00: $-3.45 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-07 09:36→09:42: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-10-08 09:35→09:40: $-3.09 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-09 09:35→09:40: $-2.73 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-09 09:41→09:50: $-2.91 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-10 09:35→09:38: $-1.91 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-10 10:13→10:21: $-1.93 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-13 09:35→09:38: $-3.67 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-10-14 09:36→09:52: $+1.26 (+0.41R) - EMA EXIT
#   ❌ SHORT 2025-10-14 09:54→09:56: $-1.14 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-14 10:09→10:13: $-1.70 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-15 09:42→09:57: $-3.19 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-15 10:25→10:31: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-10-16 09:37→09:40: $-2.27 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-16 10:21→10:28: $-1.95 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-17 09:37→09:40: $-2.59 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-10-17 09:51→10:00: $+0.68 (+0.22R) - EMA EXIT
#   ✅ LONG 2025-10-20 09:49→09:58: $+0.68 (+0.24R) - EMA EXIT
#   ❌ LONG 2025-10-21 09:40→09:41: $-1.87 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-22 09:48→09:52: $-1.85 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-10-22 09:56→10:20: $+1.03 (+0.52R) - EMA EXIT
#   ✅ LONG 2025-10-23 09:40→09:59: $+1.01 (+0.22R) - EMA EXIT
#   ❌ SHORT 2025-10-24 09:40→10:06: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-10-24 10:20→10:28: $+0.60 (+0.44R) - EMA EXIT
#   ❌ LONG 2025-10-27 09:39→10:07: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-10-28 09:36→09:47: $+1.58 (+0.62R) - EMA EXIT
#   ✅ SHORT 2025-10-29 09:35→09:43: $+0.83 (+0.45R) - EMA EXIT
#   ❌ LONG 2025-10-29 10:00→10:08: $-2.26 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-29 10:18→10:22: $-1.35 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-10-30 10:04→10:22: $+1.43 (+0.51R) - EMA EXIT
#   ❌ LONG 2025-10-31 09:37→09:44: $-1.97 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-31 10:02→10:04: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-11-03 09:35→09:42: $+4.11 (+2.01R) - TRAILING STOP
#   ✅ SHORT 2025-11-05 09:36→10:06: $+1.20 (+0.34R) - EMA EXIT
#   ❌ LONG 2025-11-06 09:37→09:40: $-3.00 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-11-06 09:43→09:48: $+0.62 (+0.24R) - EMA EXIT
#   ✅ SHORT 2025-11-06 10:02→10:18: $+2.02 (+0.58R) - EMA EXIT
#   ❌ SHORT 2025-11-07 09:36→09:41: $-4.25 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-07 09:46→09:55: $-4.53 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-10 09:35→09:59: $-4.49 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-11-10 10:26→10:38: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-11-11 09:38→09:43: $-2.35 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-11-11 10:06→10:36: $+1.36 (+0.65R) - EMA EXIT
#   ✅ SHORT 2025-11-12 09:46→10:00: $+2.29 (+1.14R) - EMA EXIT
#   ✅ SHORT 2025-11-13 09:36→10:07: $+6.95 (+3.19R) - TRAILING STOP
#   ✅ LONG 2025-11-14 09:36→10:01: $+4.15 (+0.93R) - EMA EXIT
#   ✅ LONG 2025-11-17 09:35→09:59: $+7.93 (+2.69R) - TRAILING STOP
#   ❌ SHORT 2025-11-18 09:41→09:45: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-11-19 09:42→09:47: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-11-20 09:39→09:52: $+2.03 (+0.69R) - EMA EXIT
#   ❌ SHORT 2025-11-21 09:45→09:53: $-4.06 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-21 09:56→10:04: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-11-24 09:35→09:50: $-3.89 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-11-24 09:52→10:11: $+3.13 (+1.12R) - EMA EXIT
#   ❌ SHORT 2025-11-25 09:43→09:52: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-11-25 10:01→10:07: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-11-26 09:35→09:41: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-12-01 09:36→09:39: $-1.92 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-12-01 10:06→10:14: $+1.43 (+0.81R) - EMA EXIT
#   ❌ LONG 2025-12-02 09:36→09:42: $-1.89 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-02 09:53→10:00: $-2.20 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-12-02 10:08→10:15: $+0.97 (+0.55R) - EMA EXIT
#   ❌ LONG 2025-12-02 10:22→10:26: $-0.94 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-12-03 09:41→10:12: $+1.99 (+0.73R) - EMA EXIT
#   ✅ LONG 2025-12-04 09:40→09:54: $+1.62 (+0.60R) - EMA EXIT
#   ❌ LONG 2025-12-05 09:36→09:39: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-12-05 09:45→09:52: $-1.32 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-05 10:02→10:04: $-1.69 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-05 10:09→10:18: $-1.22 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-08 09:36→09:47: $-2.40 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-12-08 09:56→10:03: $+0.40 (+0.42R) - EMA EXIT
#   ✅ LONG 2025-12-09 09:35→09:54: $+1.24 (+0.64R) - EMA EXIT
#   ❌ SHORT 2025-12-10 09:55→10:17: $-2.11 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-12-11 10:25→10:53: $+4.06 (+3.77R) - TRAILING STOP
#   ✅ LONG 2025-12-12 09:35→09:45: $+3.08 (+1.43R) - TRAILING STOP
#   ❌ LONG 2025-12-15 09:40→09:46: $-3.52 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-15 09:53→09:56: $-2.08 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-12-16 09:47→10:03: $+3.70 (+0.93R) - EMA EXIT
#   ✅ LONG 2025-12-16 10:27→10:30: $+0.33 (+0.37R) - EMA EXIT
#   ❌ SHORT 2025-12-17 09:48→09:50: $-3.51 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-18 09:35→09:42: $-3.96 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-18 10:00→10:11: $-3.36 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-12-18 10:27→10:43: $+1.52 (+0.55R) - EMA EXIT
#   ❌ SHORT 2025-12-19 09:35→09:43: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-12-19 09:45→09:50: $+0.54 (+0.53R) - EMA EXIT
#   ❌ LONG 2025-12-22 09:48→09:58: $-3.48 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-22 10:14→10:22: $-2.13 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-22 10:27→10:42: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-12-23 09:38→09:45: $-2.59 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-23 09:46→09:48: $-2.21 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-23 09:56→10:05: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-12-23 10:21→10:33: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-12-24 09:35→09:51: $+2.08 (+0.98R) - EMA EXIT
#   ❌ LONG 2025-12-26 09:35→09:39: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-12-29 09:56→10:26: $-2.91 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-30 09:36→09:44: $+0.00 (+0.00R) - BREAK-EVEN STOP
#
# ======================================================================
#   BACKTEST SUMMARY: TSLA
#   2025-10-01 to 2025-12-31
# ======================================================================
#
#   Total Trades:    101
#   Wins/Losses:     35W / 66L
#   Win Rate:        34.7%
#
#   Total P/L:       $-42.22
#   Total R:         -12.66R
#   Avg R/Trade:     -0.125R
#
#   Avg Win:         $2.05 (0.90R)
#   Avg Loss:        $-1.72 (-0.67R)
#   Profit Factor:   0.63
#   Max Drawdown:    16.20R
#
# ======================================================================

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from orb_backtester import ORBBacktester

bt = ORBBacktester(
    symbol='AAPL',
    start_date='2025-10-01',
    end_date='2025-12-31',
    verbose=True
)
results = bt.run()
# Out:
# ======================================================================
#   ORB BACKTESTER: AAPL
#   2025-10-01 to 2025-12-31
# ======================================================================
#
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 180 days, extended)...
#   ✓ Fetched 89838 bars, cached for next time
# ✓ Loaded 89838 bars for AAPL
# Processing 64 trading days...
#
#   ✅ LONG 2025-10-01 09:35→09:43: $+0.16 (+0.20R) - EMA EXIT
#   ❌ LONG 2025-10-01 10:19→10:22: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-10-02 09:35→09:45: $+0.29 (+0.33R) - EMA EXIT
#   ❌ SHORT 2025-10-02 10:06→10:12: $-0.40 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-10-03 09:35→09:56: $+1.28 (+1.24R) - EMA EXIT
#   ✅ SHORT 2025-10-06 09:37→09:49: $+1.31 (+1.68R) - TRAILING STOP
#   ❌ SHORT 2025-10-07 09:43→09:49: $-0.53 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-07 10:07→10:14: $-0.29 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-07 10:17→10:28: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-10-08 09:38→09:40: $-0.60 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-08 09:51→09:55: $-0.62 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-10-08 10:02→10:18: $+0.08 (+0.13R) - EMA EXIT
#   ✅ SHORT 2025-10-09 09:41→09:47: $+0.06 (+0.09R) - EMA EXIT
#   ❌ LONG 2025-10-10 09:37→09:42: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-10-10 10:00→10:04: $-0.51 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-10 10:10→10:13: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-10-10 10:25→10:28: $-0.31 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-13 09:35→09:37: $-1.47 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-13 09:45→09:51: $-1.04 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-13 10:21→10:36: $-0.71 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-14 09:42→09:45: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-10-14 09:54→09:55: $-0.34 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-15 09:42→09:44: $-0.95 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-10-15 09:55→10:08: $+0.85 (+0.97R) - EMA EXIT
#   ✅ LONG 2025-10-17 10:11→10:18: $+0.25 (+0.36R) - EMA EXIT
#   ❌ LONG 2025-10-20 09:55→09:59: $-1.02 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-20 10:00→10:10: $-1.05 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-10-20 10:27→10:33: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-10-23 09:37→09:56: $-0.73 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-23 09:57→10:14: $-0.74 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-24 09:39→10:13: $-0.91 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-28 09:35→09:40: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-10-28 09:53→09:56: $-0.50 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-10-28 10:01→10:09: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-10-31 09:35→09:46: $+0.83 (+0.49R) - EMA EXIT
#   ❌ LONG 2025-11-04 09:43→09:53: $-0.88 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-11-05 09:56→10:16: $-0.87 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-11-05 10:26→11:42: $+1.01 (+1.73R) - EMA EXIT
#   ❌ LONG 2025-11-06 09:36→09:41: $-0.80 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-11-06 09:45→09:50: $-0.83 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-11-06 09:55→10:07: $+0.29 (+0.51R) - EMA EXIT
#   ❌ LONG 2025-11-07 10:02→10:07: $-0.98 (-1.00R) - INITIAL STOP
#   ✅ LONG 2025-11-07 10:09→10:23: $+0.98 (+1.16R) - EMA EXIT
#   ✅ LONG 2025-11-10 09:35→09:55: $+0.97 (+1.05R) - EMA EXIT
#   ✅ SHORT 2025-11-12 09:37→09:50: $+0.39 (+0.53R) - EMA EXIT
#   ❌ SHORT 2025-11-12 10:13→10:15: $-0.32 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-12 10:27→10:31: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-11-13 09:39→09:46: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-11-13 09:52→10:11: $-0.79 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-11-14 09:53→10:01: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-11-17 09:43→09:58: $+0.40 (+0.34R) - EMA EXIT
#   ❌ LONG 2025-11-17 10:20→10:32: $-0.41 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-18 09:38→09:45: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ LONG 2025-11-20 09:40→09:54: $+0.90 (+0.75R) - EMA EXIT
#   ❌ LONG 2025-11-20 10:22→10:25: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-11-25 09:35→09:38: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-11-25 09:42→09:43: $-0.47 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-11-25 09:56→10:01: $-0.94 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-26 10:03→10:07: $-0.34 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-11-28 09:40→09:49: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-11-28 09:52→11:29: $+0.13 (+0.21R) - EMA EXIT
#   ✅ SHORT 2025-12-01 09:41→09:51: $+0.18 (+0.27R) - EMA EXIT
#   ✅ SHORT 2025-12-01 10:02→10:11: $+0.03 (+0.08R) - EMA EXIT
#   ❌ LONG 2025-12-02 09:36→09:53: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ SHORT 2025-12-04 09:37→09:43: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-12-04 09:44→10:03: $+1.13 (+2.11R) - TRAILING STOP
#   ❌ SHORT 2025-12-05 09:35→09:37: $-0.74 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-05 09:46→09:56: $-0.76 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-08 09:39→10:21: $-0.84 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-09 09:37→09:40: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ✅ SHORT 2025-12-09 10:01→10:41: $+0.19 (+0.29R) - EMA EXIT
#   ❌ SHORT 2025-12-10 09:35→09:38: $-0.69 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-10 09:50→09:57: $-0.64 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-10 10:10→10:22: $-0.52 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-12-11 09:36→10:01: $+3.34 (+5.06R) - TRAILING STOP
#   ❌ LONG 2025-12-12 09:46→09:49: $-0.77 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-12 09:54→10:00: $-0.70 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-12 10:06→10:09: $-0.69 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-12-18 09:35→09:45: $+0.36 (+0.30R) - EMA EXIT
#   ❌ SHORT 2025-12-19 10:18→10:32: $-0.61 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-22 09:45→10:20: $+0.00 (+0.00R) - BREAK-EVEN STOP
#   ❌ LONG 2025-12-23 10:07→10:25: $-0.53 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-24 09:38→09:47: $-0.62 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-24 10:18→10:28: $-0.40 (-1.00R) - INITIAL STOP
#   ❌ LONG 2025-12-26 09:36→09:51: $-0.62 (-1.00R) - INITIAL STOP
#   ❌ SHORT 2025-12-30 09:35→09:37: $-0.61 (-1.00R) - INITIAL STOP
#   ✅ SHORT 2025-12-30 10:24→10:29: $+0.05 (+0.19R) - EMA EXIT
#   ❌ SHORT 2025-12-31 09:41→09:52: $-0.51 (-1.00R) - INITIAL STOP
#
# ======================================================================
#   BACKTEST SUMMARY: AAPL
#   2025-10-01 to 2025-12-31
# ======================================================================
#
#   Total Trades:    88
#   Wins/Losses:     24W / 64L
#   Win Rate:        27.3%
#
#   Total P/L:       $-15.12
#   Total R:         -24.92R
#   Avg R/Trade:     -0.283R
#
#   Avg Win:         $0.64 (0.84R)
#   Avg Loss:        $-0.48 (-0.70R)
#   Profit Factor:   0.51
#   Max Drawdown:    27.38R
#
# ======================================================================
