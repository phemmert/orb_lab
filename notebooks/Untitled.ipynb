# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from orb_optimizer import ORBOptimizer

optimizer = ORBOptimizer(
    symbol='AMD',
    train_start='2025-04-01',
    train_end='2025-09-30',
    test_start='2025-10-01', 
    test_end='2025-12-31',
    n_trials=100
)
results = optimizer.run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')
# ----> 4 from orb_optimizer import ORBOptimizer
#       6 optimizer = ORBOptimizer(
#       7     symbol='AMD',
#       8     train_start='2025-04-01',
#    (...)     12     n_trials=100
#      13 )
#      14 results = optimizer.run()
#
# File ~\orb_lab\src\orb_optimizer.py:25
#       1 """
#       2 ORB Optimizer - Optuna-powered Parameter Search
#       3 ================================================
#    (...)     22     best_params = optimizer.run()
#      23 """
# ---> 25 import optuna
#      26 from optuna.samplers import TPESampler
#      27 import json
#
# ModuleNotFoundError: No module named 'optuna'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\phemm\anaconda3\python.exe
