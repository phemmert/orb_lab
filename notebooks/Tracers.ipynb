# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from single_day_tracer_v4 import SingleDayTracerV4

tracer = SingleDayTracerV4(symbol='TSLA', date='2025-12-03')
tracer.is_trading_window = lambda ts: 9*60+30 <= ts.hour*60+ts.minute < 16*60
tracer.run()
# Out:
# ...
#   SINGLE DAY TRACER v4: TSLA on 2025-12-03
#   (Pine v69 with EXIT LOGIC)
# ...
#
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching TSLA (1-min bars, 120 days, extended)...
#   ⚠ Cache stale (12 hours), refreshing...
#   ✓ Fetched 78079 bars, cached for next time
# ✓ Loaded 933 bars for TSLA on 2025-12-03
# Exit Parameters:
#   Break-even: 0.5R
#   Trailing activates: 2.0R
#   Trail distance: 1.2 ATR
#   EMA confirmation: 1 bar(s)
#
# ──────────────────────────────────────────────────────────────────────
#   BAR-BY-BAR TRACE
# ──────────────────────────────────────────────────────────────────────
#
# [09:30] 🟡 ORB START - H: 434.72, L: 431.57
#
# [09:35] 🟢 ORB COMPLETE - H: 437.45, L: 431.11, ATR: $1.2452
#
# [09:41] 🔺 LONG BREAKOUT - Entry: $437.78, Stop: $435.06, R:R: 1.65, Vol: NORMAL
#          ✅ TRADE TAKEN - Risk: $2.72
# [10:01]    🟣 BREAK-EVEN activated - stop moved to $437.78
#
# [10:12]    ✅ POSITION CLOSED - EMA EXIT
#          Entry: $437.78
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from single_day_tracer_v4 import SingleDayTracerV4

tracer = SingleDayTracerV4(symbol='AMD', date='2025-12-29')
tracer.is_trading_window = lambda ts: 9*60+30 <= ts.hour*60+ts.minute < 16*60
tracer.run()
# Out:
# ...
#   SINGLE DAY TRACER v4: AMD on 2025-12-29
#   (Pine v69 with EXIT LOGIC)
# ...
#
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AMD (1-min bars, 120 days, extended)...
#   ⚠ Cache stale (20 hours), refreshing...
#   ✓ Fetched 68052 bars, cached for next time
# ✓ Loaded 692 bars for AMD on 2025-12-29
# Exit Parameters:
#   Break-even: 0.5R
#   Trailing activates: 2.0R
#   Trail distance: 1.2 ATR
#   EMA confirmation: 1 bar(s)
#
# ──────────────────────────────────────────────────────────────────────
#   BAR-BY-BAR TRACE
# ──────────────────────────────────────────────────────────────────────
#
# [09:30] 🟡 ORB START - H: 211.66, L: 209.63
#
# [09:35] 🟢 ORB COMPLETE - H: 211.66, L: 209.24, ATR: $0.6468
#
# [09:36] 🔺 LONG BREAKOUT - Entry: $213.20, Stop: $211.88, R:R: 1.50, Vol: NORMAL
#          ✅ TRADE TAKEN - Risk: $1.32
# [09:37]    🟣 BREAK-EVEN activated - stop moved to $213.20
#
# [09:45]    ✅ POSITION CLOSED - EMA EXIT
#          Entry: $213.20
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from single_day_tracer_v4 import SingleDayTracerV4

tracer = SingleDayTracerV4(symbol='MU', date='2025-12-31')
tracer.is_trading_window = lambda ts: 9*60+30 <= ts.hour*60+ts.minute < 16*60
tracer.run()
# Out:
# ...
#   SINGLE DAY TRACER v4: MU on 2025-12-31
#   (Pine v69 with EXIT LOGIC)
# ...
#
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching MU (1-min bars, 120 days, extended)...
#   ✓ Fetched 63559 bars, cached for next time
# ✓ Loaded 671 bars for MU on 2025-12-31
# Exit Parameters:
#   Break-even: 0.5R
#   Trailing activates: 2.0R
#   Trail distance: 1.2 ATR
#   EMA confirmation: 1 bar(s)
#
# ──────────────────────────────────────────────────────────────────────
#   BAR-BY-BAR TRACE
# ──────────────────────────────────────────────────────────────────────
#
# [09:30] 🟡 ORB START - H: 293.17, L: 291.25
#
# [09:35] 🟢 ORB COMPLETE - H: 293.17, L: 288.58, ATR: $0.7126
#
# [09:36] 🔻 SHORT BREAKOUT - Entry: $288.20, Stop: $289.67, R:R: 1.50, Vol: NORMAL
#          ✅ TRADE TAKEN - Risk: $1.47
# [09:38]    🟣 BREAK-EVEN activated - stop moved to $288.20
#
# [09:43]    ❌ POSITION CLOSED - BREAK-EVEN STOP
#          Entry: $288.20
#          Exit:  $288.20
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\phemm\orb_lab\src')

from single_day_tracer_v4 import SingleDayTracerV4

tracer = SingleDayTracerV4(symbol='AAPL', date='2025-12-31')
tracer.is_trading_window = lambda ts: 9*60+30 <= ts.hour*60+ts.minute < 16*60
tracer.run()
# Out:
# ...
#   SINGLE DAY TRACER v4: AAPL on 2025-12-31
#   (Pine v69 with EXIT LOGIC)
# ...
#
# [DataCollector] Using cache: C:\Users\phemm\orb_lab\data\cache
# 📊 Fetching AAPL (1-min bars, 120 days, extended)...
#   ⚠ Cache stale (18 hours), refreshing...
#   ✓ Fetched 59263 bars, cached for next time
# ✓ Loaded 549 bars for AAPL on 2025-12-31
# Exit Parameters:
#   Break-even: 0.5R
#   Trailing activates: 2.0R
#   Trail distance: 1.2 ATR
#   EMA confirmation: 1 bar(s)
#
# ──────────────────────────────────────────────────────────────────────
#   BAR-BY-BAR TRACE
# ──────────────────────────────────────────────────────────────────────
#
# [09:30] 🟡 ORB START - H: 273.46, L: 272.68
#
# [09:35] 🟢 ORB COMPLETE - H: 273.68, L: 272.50, ATR: $0.2414
#
# [09:41] 🔻 SHORT BREAKOUT - Entry: $272.40, Stop: $272.91, R:R: 1.50, Vol: LOW
#          ✅ TRADE TAKEN - Risk: $0.51
#
# [09:52]    ❌ POSITION CLOSED - INITIAL STOP
#          Entry: $272.40
#          Exit:  $272.91
#          P/L:   $-0.51 (-1.00R)
# ...
